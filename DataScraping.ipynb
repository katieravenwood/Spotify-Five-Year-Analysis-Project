# %% [markdown]
# # Spotify Song Data Scraping

# %% [markdown]
# ### References:
# #### Based on the following tutorials: <br />
# Max Hilsdorf, "How to Create Large Music Datasets Using Spotipy", <i>Towards Data Science</i>, 25 April 2020: <br />
# https://towardsdatascience.com/how-to-create-large-music-datasets-using-spotipy-40e7242cc6a6 <br />
# Max Tingle, "Getting Started with Spotify’s API & Spotipy", <i>Towards Data Science</i>, 3 Oct 2019: <br />
# https://medium.com/@maxtingle/getting-started-with-spotifys-api-spotipy-197c3dc6353b <br />
# Sandra Radgowska, "How to use Spotify API and what data science opportunities can it open up?", <i>My Journey As A Data Scientist</i>, 18 August 2021:<br />
# https://datascientistdiary.com/index.php/2021/03/04/how-to-use-spotify-api-and-what-data-science-opportunities-can-it-open-up/<br />
# Angelica Dietzel, "How to Extract Any Artist’s Data Using Spotify’s API, Python, and Spotipy", <i>Better Programming</i>, 25 March 2020:<br />
# https://betterprogramming.pub/how-to-extract-any-artists-data-using-spotify-s-api-python-and-spotipy-4c079401bc37

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import packages

# %%
import json
import time
import tqdm
import pandas as pd
import creds
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# ### Spotify Credentials

# %% [markdown]
# #### Load credentials

# %% [markdown]
# Loads the creds.py file, containing the following two lines for variables client_id and secret, which is gitignored for sharing.
#
# client_id = 'Your Client ID Here'<br />
# secret = 'Your secret here'

# %%
# %run -i 'creds.py'

# %% [markdown]
# #### Set credentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ## Functions for data extraction

# %% [markdown]
# ### Get track data including features
# #### Details: uri, name, album, artist name, release date, explicit T/F, duration in mins
# #### Audio features: acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature

# %% [markdown]
# #### Create track container dictionaries
#
# * Note that since tracks variable is no created in cell with function call, subsequent calls will be appended to the same dictionary

# %%
tracks_with_features = []

# %% [markdown]
# #### Function to extract all the track ids from your playlist:

# %%
def get_track_ids(playlist_id):
    music_id_list = []
    playlist = sp.playlist(playlist_id)
    for item in playlist['tracks']['items']:
        music_track = item['track']
        music_id_list.append(music_track['id'])
    return music_id_list

# %% [markdown]
# #### Function to extract all the details and features of each track by passing its ID:

# %%
def get_track_data(track_id):
    meta = sp.track(track_id)
    features = sp.audio_features(track_id)
    analysis = sp.audio_analysis(track_id)
    track_details = {'uri': meta['uri'],
                    'name': meta['name'],
                    'album': meta['album']['name'],
                    'artist': meta['album']['artists'][0]['name'],
                    'release_date': meta['album']['release_date'],
                    'explicit': meta['explicit'],
                    'duration_in_mins': round((meta['duration_ms'] * 0.001) / 60.0, 2),
                    'acousticness' : features[0]['acousticness'],
                    'danceability' : features[0]['danceability'],
                    'energy' : features[0]['energy'],
                    'instrumentalness' : features[0]['instrumentalness'],
                    'liveness' : features[0]['liveness'],
                    'loudness' : features[0]['loudness'],
                    'speechiness' : features[0]['speechiness'],
                    'tempo' : features[0]['tempo'],
                    'time_signature' : features[0]['time_signature'],
                    'track_duration_in_seconds' : analysis['track']['duration'],
                    'end_of_fade_in' : analysis['track']['end_of_fade_in'],
                    'start_of_fade_out' : analysis['track']['start_of_fade_out'],
                    'time_signature' : analysis['track']['time_signature'],
                    'key' : analysis['track']['key'],
                    'mode' : analysis['track']['mode']
                    }
    return track_details

# %% [markdown]
# ####  Extract track data

# %% [markdown]
# Extract info of each track
#
# For testing:  playlist_id = '0qfagBJB5ou0r1kwQDZ8Op'

# %%
# Get the ids for all the songs in your playlist
playlist_id = input('Enter the playlist id')
track_ids = get_track_ids(playlist_id)
print(len(track_ids))
print(track_ids)

#  Loop over track ids and get their data points
for i in range(len(track_ids)):
    time.sleep(.5)
    track = get_track_data(track_ids[i])
    tracks_with_features.append(track)
# Out:
# Enter the playlist id0qfagBJB5ou0r1kwQDZ8Op
# 21
# ['0bXpmJyHHYPk6QBFj25bYF', '0Xy9xPPs2zRRFqljGqKXel', '0RqRN88qFUEeOQZ7VklA14', '1QZJiYulh7ak7GpZ8OAdwI', '0wrBkSiN1Y1StFR1Q3ZC28', '4Q2UM2QSR7Gye03jvl4Rdw', '5urkJ8dcmxtvsnruNfx6ZS', '6ujlgkgbsrPskgWslEcZmR', '3pyTksNccLM1jRvzQ4zTke', '7AiIlhSSVKAyMJTygWuut2', '7pKfPomDEeI4TPT6EOYjn9', '0WWz2AaqxLoO0fa9ou6Fqc', '5qJbIYo8AitajCbnOGPIvI', '7IbMonU3CRITpQ0cRVThsV', '5yEPxDjbbzUzyauGtnmVEC', '2gANywSFYF58YFMPdDSAjC', '29zkoUsOE50f0I3n44LjjU', '6d3geXDfoj6hz882o9Ip9S', '2UKYMN7VnsQo40n0qCt6Sa', '6Prs4p7iVZxODcO62NIiA6', '7kCrYUDtWsPldohOKPTKPL']

# %% [markdown]
# #### Create dataframe

# %%
df_features = pd.DataFrame(tracks_with_features)
df_features
# Out:
#                                      uri  \
# 0   spotify:track:0bXpmJyHHYPk6QBFj25bYF
# 1   spotify:track:0Xy9xPPs2zRRFqljGqKXel
# 2   spotify:track:0RqRN88qFUEeOQZ7VklA14
# 3   spotify:track:1QZJiYulh7ak7GpZ8OAdwI
# 4   spotify:track:0wrBkSiN1Y1StFR1Q3ZC28
# 5   spotify:track:4Q2UM2QSR7Gye03jvl4Rdw
# 6   spotify:track:5urkJ8dcmxtvsnruNfx6ZS
# 7   spotify:track:6ujlgkgbsrPskgWslEcZmR
# 8   spotify:track:3pyTksNccLM1jRvzQ4zTke
# 9   spotify:track:7AiIlhSSVKAyMJTygWuut2
# 10  spotify:track:7pKfPomDEeI4TPT6EOYjn9
# 11  spotify:track:0WWz2AaqxLoO0fa9ou6Fqc
# 12  spotify:track:5qJbIYo8AitajCbnOGPIvI
# 13  spotify:track:7IbMonU3CRITpQ0cRVThsV
# 14  spotify:track:5yEPxDjbbzUzyauGtnmVEC
# 15  spotify:track:2gANywSFYF58YFMPdDSAjC
# 16  spotify:track:29zkoUsOE50f0I3n44LjjU
# 17  spotify:track:6d3geXDfoj6hz882o9Ip9S
# 18  spotify:track:2UKYMN7VnsQo40n0qCt6Sa
# 19  spotify:track:6Prs4p7iVZxODcO62NIiA6
# 20  spotify:track:7kCrYUDtWsPldohOKPTKPL
#
#                                           name  \
# 0                                        Intro
# 1                                         Pyro
# 2                                     Restless
# 3                                      Control
# 4                               All I'm Saying
# 5                               I'm Outta Time
# 6                     Swans (Extended Version)
# 7                       Ballad of the Mighty I
# 8                          Never Tear Us Apart
# 9                                     Hey Jude
# 10                   Imagine - Remastered 2010
# 11                               White Shadows
# 12                               Walk Like You
# 13                   In the Heat of the Moment
# 14                       Bitter Sweet Symphony
# 15                                 Stand by Me
# 16  Comfortably Numb - 2011 Remastered Version
# 17                                   Love Lost
# 18                                   Porcelain
# 19                                        Wait
# 20                               Ordinary Love
#
#                                                 album  \
# 0                                                  xx
# 1                                 Come Around Sundown
# 2                                      Music Complete
# 3                                     After the Disco
# 4                                      La Petite Mort
# 5                                   Dig Out Your Soul
# 6                                    Swans Collection
# 7                                   Chasing Yesterday
# 8                                     INXS Remastered
# 9                                    Back In The U.S.
# 10                                            Imagine
# 11                                                X&Y
# 12                                     La Petite Mort
# 13                                  Chasing Yesterday
# 14                                        Urban Hymns
# 15                                        Be Here Now
# 16  The Wall [2011 - Remaster] (2011 Remastered Ve...
# 17                                         Conditions
# 18                               Play & Play: B Sides
# 19  The Fault In Our Stars: Music From The Motion ...
# 20  Mandela – Long Walk To Freedom (Original Motio...
#
#                                 artist release_date  explicit  \
# 0                               The xx   2009-08-16     False
# 1                        Kings of Leon   2010-10-19     False
# 2                            New Order   2015-09-25     False
# 3                         Broken Bells   2014-01-13     False
# 4                                James   2014-06-02     False
# 5                                Oasis   2008-10-06     False
# 6                            Unkle Bob   2006-10-23     False
# 7   Noel Gallagher's High Flying Birds   2015-02-27     False
# 8                                 INXS   2011-01-01     False
# 9                       Paul McCartney   2003-05-17     False
# 10                         John Lennon   1971-09-09     False
# 11                            Coldplay   2005-06-07     False
# 12                               James   2014-06-02     False
# 13  Noel Gallagher's High Flying Birds   2015-02-27     False
# 14                           The Verve   1997-09-29     False
# 15                               Oasis   1997-08-21     False
# 16                          Pink Floyd   1979-11-30     False
# 17                     The Temper Trap   2009-08-09     False
# 18                                Moby   2008-06-02     False
# 19                     Various Artists   2014-05-19     False
# 20                     Various Artists   2013-01-01     False
#
#     duration_in_mins  acousticness  danceability  energy  ...  liveness  \
# 0               2.13       0.45900         0.617   0.778  ...    0.1280
# 1               4.18       0.00757         0.365   0.606  ...    0.1030
# 2               5.47       0.00595         0.512   0.963  ...    0.0646
# 3               3.69       0.00676         0.741   0.634  ...    0.3370
# 4               4.97       0.24600         0.483   0.781  ...    0.1520
# 5               4.17       0.00107         0.427   0.622  ...    0.4310
# 6               4.12       0.28900         0.486   0.669  ...    0.1050
# 7               5.25       0.00689         0.479   0.874  ...    0.1780
# 8               3.08       0.00309         0.664   0.613  ...    0.1750
# 9               7.02       0.33200         0.267   0.935  ...    0.9670
# 10              3.13       0.90700         0.547   0.257  ...    0.0935
# 11              5.47       0.00521         0.491   0.783  ...    0.0951
# 12              7.11       0.05230         0.407   0.767  ...    0.1040
# 13              3.49       0.00001         0.545   0.836  ...    0.4130
# 14              5.97       0.04150         0.389   0.889  ...    0.4630
# 15              5.94       0.01420         0.214   0.828  ...    0.1610
# 16              6.37       0.15000         0.472   0.366  ...    0.0837
# 17              3.60       0.02490         0.549   0.575  ...    0.1090
# 18              4.02       0.00140         0.297   0.637  ...    0.2470
# 19              5.69       0.20300         0.429   0.243  ...    0.0980
# 20              3.69       0.17400         0.655   0.471  ...    0.1180
#
#     loudness  speechiness    tempo  time_signature  track_duration_in_seconds  \
# 0     -8.871       0.0270  100.363               4                  127.92000
# 1     -7.174       0.0415  114.995               4                  250.53333
# 2     -5.083       0.0498  143.012               4                  328.24000
# 3     -6.625       0.0264  113.999               4                  221.42667
# 4     -6.490       0.0927  118.824               4                  297.93124
# 5     -5.467       0.0280   77.406               4                  250.01334
# 6     -5.611       0.0293  118.464               4                  247.29729
# 7     -4.563       0.0426  121.916               4                  315.09332
# 8     -7.560       0.0273   96.600               3                  184.58667
# 9     -3.016       0.0621  148.390               4                  421.02667
# 10   -12.358       0.0252   75.752               4                  187.86667
# 11    -8.997       0.0484  127.437               4                  328.21982
# 12    -6.217       0.0287  122.126               4                  426.58844
# 13    -4.029       0.0281  105.924               4                  209.48000
# 14    -6.546       0.0442  171.121               4                  358.42667
# 15    -2.660       0.0383  169.876               4                  356.60000
# 16   -12.595       0.0286  127.167               4                  382.29697
# 17    -7.329       0.0350  122.548               4                  216.06667
# 18    -7.926       0.0336   94.730               4                  241.17332
# 19    -9.827       0.0317  147.927               4                  341.20000
# 20    -8.528       0.0303  121.040               4                  221.20000
#
#     end_of_fade_in  start_of_fade_out  key  mode
# 0          2.48454          117.99220    9     0
# 1          0.15075          242.08543    1     0
# 2          1.00227          308.62802   11     0
# 3          0.31011          214.01833    9     0
# 4          0.00000          291.61362    5     1
# 5          0.00000          234.64925    4     0
# 6          0.62707          237.18604   11     0
# 7          0.00000          292.00833    1     1
# 8          0.17324          171.76381    0     1
# 9          0.00000          421.02667    5     1
# 10         1.04499          174.53859    0     1
# 11         0.15642          328.21982    8     0
# 12         0.00000          399.04074    9     0
# 13         0.00000          203.74930    6     1
# 14         0.99832          345.55356    9     1
# 15         0.14512          356.60000    7     1
# 16         0.00000          362.33580   11     0
# 17         1.03882          206.68661    7     1
# 18         0.22472          236.54749    0     0
# 19         0.30259          335.16263    2     1
# 20         0.91687          206.35574    8     0
#
# [21 rows x 21 columns]

# %% [markdown]
# ### Get artist data (id, artist name, genre, popularity, followers)

# %% [markdown]
# #### Create track container dictionaries
#
# * Note that since tracks variable is no created in cell with function call, subsequent calls will be appended to the same dictionary

# %%
artists = []

# %% [markdown]
# #### Function to extract all of the tracks' artist ids from your playlist:

# %%
def get_artist_ids(playlist_id):
    artist_id_list = []
    playlist = sp.playlist(playlist_id)
    for item in playlist['tracks']['items']:
        music_track = item['track']
        artist_id_list.append(music_track['artists'][0]['id'])
    return artist_id_list

# %% [markdown]
# #### Function to extract all the details of each artist by passing their ID:

# %%
def get_artist_data(artist_id):
    meta = sp.artist(artist_id)
    artist_details = {'artist id': meta['id'],
                    'artist name': meta['name'],
                    'genres': meta['genres'],
                    'popularity': meta['popularity'],
                    'followers': meta['followers']['total']
                    }
    return artist_details

# %% [markdown]
# ####  Extract artist data

# %% [markdown]
# Extract artist data of each track
#
# For testing:  playlist_id = '0qfagBJB5ou0r1kwQDZ8Op'

# %%
# Get the ids for all the songs in your playlist
playlist_id = input('Enter the playlist id')
artist_ids = get_artist_ids(playlist_id)
print(len(artist_ids))
print(artist_ids)

#  Loop over track ids and get their data points
for i in range(len(artist_ids)):
    time.sleep(.5)
    artist = get_artist_data(artist_ids[i])
    artists.append(artist)
# Out:
# Enter the playlist id0qfagBJB5ou0r1kwQDZ8Op
# 21
# ['3iOvXCl6edW5Um0fXEBRXy', '2qk9voo8llSGYcZ6xrBzKx', '0yNLKJebCb8Aueb54LYya3', '6dgwEwnK0YtDfS9XhRwBTG', '0qLNsNKm8bQcMoRFkR8Hmh', '2DaxqgrOhkeH0fpeiQq2f4', '3Bf4u6r96pGx1eIbaGqfvf', '7sjttK1WcZeyLPn3IsQ62L', '1eClJfHLoDI4rZe5HxzBFv', '4STHEaNw4mPZ2tzheohgXB', '4x1nvY2FN8jxqAFA0DA02H', '4gzpq5DPGxSnKTe4SA8HAU', '0qLNsNKm8bQcMoRFkR8Hmh', '7sjttK1WcZeyLPn3IsQ62L', '2cGwlqi3k18jFpUyTrsR84', '2DaxqgrOhkeH0fpeiQq2f4', '0k17h0D3J5VfsdmQ1iZtE9', '4W48hZAnAHVOC2c8WH8pcq', '3OsRAKCvk37zwYcnzRf5XF', '63MQldklfxkjYDoUE4Tppz', '51Blml2LZPmy7TTiAg47vQ']

# %% [markdown]
# #### Create dataframe

# %%
artist_df = pd.DataFrame(artists)
artist_df.head()
# Out:
#                 artist id    artist name  \
# 0  3iOvXCl6edW5Um0fXEBRXy         The xx
# 1  2qk9voo8llSGYcZ6xrBzKx  Kings of Leon
# 2  0yNLKJebCb8Aueb54LYya3      New Order
# 3  6dgwEwnK0YtDfS9XhRwBTG   Broken Bells
# 4  0qLNsNKm8bQcMoRFkR8Hmh          James
#
#                                               genres  popularity  followers
# 0               [downtempo, dream pop, indietronica]          70    3788801
# 1                                [modern rock, rock]          78    4896158
# 2  [art rock, dance rock, madchester, new romanti...          69    1617958
# 3  [alternative dance, alternative rock, indie po...          61     514308
# 4  [britpop, madchester, new wave, new wave pop, ...          64     429673

# %% [markdown]
# ### Get track's audio features directly from playlist (for concept only, still a WIP)

# %% [markdown]
# #### Function to extract each track's audio features from a playlist directly

# %%
def get_playlist_tracks(playlist_id):
    track_attributes = sp.playlist_tracks(playlist_id)
    return track_attributes

# %%
playlist_tracks_data = []
playlist_ids = ['0qfagBJB5ou0r1kwQDZ8Op']

#  Loop over playlist ids and get their data points
for i in range(len(playlist_ids)):
    time.sleep(.5)
    playlist_track = get_playlist_tracks(playlist_ids[i])
    playlist_tracks_data.append(playlist_track)

# %%
playlist_df = pd.DataFrame(playlist_tracks_data)
playlist_df
