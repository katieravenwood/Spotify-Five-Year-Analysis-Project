# %% [markdown]
# # Spotify Song Data Scraping Sandbox

# %% [markdown]
# ### References:
# #### Based on techniques from the following tutorials/feeds: <br />
# Max Hilsdorf, "How to Create Large Music Datasets Using Spotipy", <i>Towards Data Science</i>, 25 April 2020: <br />
# https://towardsdatascience.com/how-to-create-large-music-datasets-using-spotipy-40e7242cc6a6 <br />
# Max Tingle, "Getting Started with Spotify’s API & Spotipy", <i>Towards Data Science</i>, 3 Oct 2019: <br />
# https://medium.com/@maxtingle/getting-started-with-spotifys-api-spotipy-197c3dc6353b <br />
# Sandra Radgowska, "How to use Spotify API and what data science opportunities can it open up?", <i>My Journey As A Data Scientist</i>, 18 August 2021:<br />
# https://datascientistdiary.com/index.php/2021/03/04/how-to-use-spotify-api-and-what-data-science-opportunities-can-it-open-up/<br />
# Angelica Dietzel, "How to Extract Any Artist’s Data Using Spotify’s API, Python, and Spotipy", <i>Better Programming</i>, 25 March 2020:<br />
# https://betterprogramming.pub/how-to-extract-any-artists-data-using-spotify-s-api-python-and-spotipy-4c079401bc37<br />
# StackOverflow: Spotipy: How To Read More Than 100 Tracks From A Playlist:<br />
# https://stackoverflow.com/questions/39086287/spotipy-how-to-read-more-than-100-tracks-from-a-playlist<br />
# Github: How Do I Get Every Track of A Playlist:<br /> https://github.com/plamere/spotipy/issues/246

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import packages

# %%
import json
import time
from tqdm import tqdm
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import creds

# %% [markdown]
# ### Set display options

# %%
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ### Spotify Credentials

# %% [markdown]
# #### Load credentials

# %% [markdown]
# Loads the creds.py file, containing the following two lines for variables client_id and secret, which is gitignored for sharing.
#
# client_id = 'Your Client ID Here'<br />
# secret = 'Your secret here'

# %%
# %run -i 'creds.py'

# %% [markdown]
# #### Set credentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ## Functions for data extraction

# %% [markdown]
# ### Get track data including features (updated to ensure retrieval of all artists)
# #### Details: uri, name, album, artist name, release date, explicit T/F, duration in mins
# #### Audio features: acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature

# %% [markdown]
# #### Function to extract all the track ids from your playlist (returns only 100 items)

# %%
def get_track_ids(playlist_id):
    music_id_list = []
    playlist = sp.playlist(playlist_id)
    for item in playlist['tracks']['items']:
        music_track = item['track']
        music_id_list.append(music_track['id'])
    return music_id_list

# %%
music_id_list = get_track_ids('3avCwQPH6DkhMTRsizon7N')
print(len(music_id_list))
# Out:
# 100

# %% [markdown]
# #### Function to extract all album artists given a track id:

# %%
def get_all_album_artists_names(track_id):
    meta = sp.track(track_id)
    album_artist_list = []
    for item in (meta['album']['artists']):
        album_artist = item['name']
        album_artist_list.append(album_artist)
    return album_artist_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_names('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['Future', 'Juice WRLD']

# %% [markdown]
# #### Function to extract all the track artists given the track id:

# %%
def get_all_track_artists_names(track_id):
    meta = sp.track(track_id)
    track_artist_list = []
    for item in (meta['artists']):
        track_artist = item['name']
        track_artist_list.append(track_artist)
    return track_artist_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_names('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['Future', 'Juice WRLD', 'Young Thug']

# %% [markdown]
# #### Function to extract all the track artists' ids given a track id:

# %%
def get_all_track_artists_ids(track_id):
    meta = sp.track(track_id)
    track_artist_id_list = []
    for item in (meta['artists']):
        track_artist = item['id']
        track_artist_id_list.append(track_artist)
    return track_artist_id_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_ids('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['1RyvyyTE3xzB2ZywiAwp0i', '4MCBfE4596Uoi2O4DtmEMz', '50co4Is1HCEo8bhOyUWKpn']

# %% [markdown]
# #### Function to extract all the details and features of each track by passing its ID:

# %%
def get_track_data(track_id):
    meta = sp.track(track_id)
    features = sp.audio_features(track_id)
    analysis = sp.audio_analysis(track_id)
    track_details = {'uri': meta['uri'],
                    'name': meta['name'],
                    'track_artists': get_all_track_artists_names(track_id),
                    'track_artists_ids': get_all_track_artists_ids(track_id),
                    'album': meta['album']['name'],
                    'album_artists': get_all_album_artists_names(track_id),
                    'release_date': meta['album']['release_date'],
                    'explicit': meta['explicit'],
                    'duration_in_mins': round((meta['duration_ms'] * 0.001) / 60.0, 2),
                    'acousticness' : features[0]['acousticness'],
                    'danceability' : features[0]['danceability'],
                    'energy' : features[0]['energy'],
                    'instrumentalness' : features[0]['instrumentalness'],
                    'liveness' : features[0]['liveness'],
                    'loudness' : features[0]['loudness'],
                    'speechiness' : features[0]['speechiness'],
                    'tempo' : features[0]['tempo'],
                    'time_signature' : features[0]['time_signature'],
                    'track_duration_in_seconds' : analysis['track']['duration'],
                    'end_of_fade_in' : analysis['track']['end_of_fade_in'],
                    'start_of_fade_out' : analysis['track']['start_of_fade_out'],
                    'key' : analysis['track']['key'],
                    'mode' : analysis['track']['mode']
                    }
    return track_details

# %% [markdown]
# #### Loop function possibility 1:

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
test_tracks = get_playlist_tracks('katiekellert', '3avCwQPH6DkhMTRsizon7N')

# %%
test_tracks_df = pd.DataFrame(test_tracks)
test_tracks_df
# Out:
#                  added_at                                           added_by  \
# 0    2021-12-28T22:47:43Z  {'external_urls': {'spotify': 'https://open.sp...
# 1    2021-12-28T22:46:26Z  {'external_urls': {'spotify': 'https://open.sp...
# 2    2021-12-28T18:04:19Z  {'external_urls': {'spotify': 'https://open.sp...
# 3    2021-12-28T22:45:24Z  {'external_urls': {'spotify': 'https://open.sp...
# 4    2021-12-28T22:57:11Z  {'external_urls': {'spotify': 'https://open.sp...
# ..                    ...                                                ...
# 195  2021-12-29T03:40:46Z  {'external_urls': {'spotify': 'https://open.sp...
# 196  2021-12-29T03:41:25Z  {'external_urls': {'spotify': 'https://open.sp...
# 197  2021-12-29T03:41:59Z  {'external_urls': {'spotify': 'https://open.sp...
# 198  2021-12-29T03:42:28Z  {'external_urls': {'spotify': 'https://open.sp...
# 199  2021-12-29T03:43:16Z  {'external_urls': {'spotify': 'https://open.sp...
#
#      is_local primary_color  \
# 0       False          None
# 1       False          None
# 2       False          None
# 3       False          None
# 4       False          None
# ..        ...           ...
# 195     False          None
# 196     False          None
# 197     False          None
# 198     False          None
# 199     False          None
#
#                                                  track video_thumbnail
# 0    {'album': {'album_type': 'album', 'artists': [...   {'url': None}
# 1    {'album': {'album_type': 'album', 'artists': [...   {'url': None}
# 2    {'album': {'album_type': 'album', 'artists': [...   {'url': None}
# 3    {'album': {'album_type': 'album', 'artists': [...   {'url': None}
# 4    {'album': {'album_type': 'album', 'artists': [...   {'url': None}
# ..                                                 ...             ...
# 195  {'album': {'album_type': 'album', 'artists': [...   {'url': None}
# 196  {'album': {'album_type': 'album', 'artists': [...   {'url': None}
# 197  {'album': {'album_type': 'album', 'artists': [...   {'url': None}
# 198  {'album': {'album_type': 'album', 'artists': [...   {'url': None}
# 199  {'album': {'album_type': 'album', 'artists': [...   {'url': None}
#
# [200 rows x 6 columns]

# %% [markdown]
# ###  Extract track data

# %% [markdown]
# #### Create track container dictionaries

# %%
tracks_with_allartists = []

# %% [markdown]
# #### Extract info of each track
#
# For testing:  playlist_id = '27Wi4y5VlHr43Q6UpZMVyS'

# %%
# Get the ids for all the songs in your playlist
playlist_id = input('Enter the playlist id')
track_ids = get_track_ids(playlist_id)
print(len(track_ids))
print(track_ids)

#  Loop over track ids and get their data points
for i in tqdm(range(len(track_ids))):
    time.sleep(.5)
    track = get_track_data(track_ids[i])
    tracks_with_allartists.append(track)
# Out:
# Enter the playlist id27Wi4y5VlHr43Q6UpZMVyS
#   0%|          | 0/5 [00:00<?, ?it/s]
# 5
# ['0e7ipj03S05BNilyu5bRzt', '1P17dC1amhFzptugyAO7Il', '3bsycjdQtbcJeR6822SBvd', '3ee8Jmje8o58CHK66QrVC2', '3GCdLUSnKSMJhs4Tj6CV3s']
# 100%|██████████| 5/5 [00:06<00:00,  1.40s/it]

# %% [markdown]
# #### Create dataframe

# %%
df_allartists = pd.DataFrame(tracks_with_allartists)
df_allartists
# Out:
#                                     uri                        name  \
# 0  spotify:track:0e7ipj03S05BNilyu5bRzt  rockstar (feat. 21 Savage)
# 1  spotify:track:1P17dC1amhFzptugyAO7Il    Look What You Made Me Do
# 2  spotify:track:3bsycjdQtbcJeR6822SBvd                   I Like It
# 3  spotify:track:3ee8Jmje8o58CHK66QrVC2                        SAD!
# 4  spotify:track:3GCdLUSnKSMJhs4Tj6CV3s    All The Stars (with SZA)
#
#                     track_artists  \
# 0        [Post Malone, 21 Savage]
# 1                  [Taylor Swift]
# 2  [Cardi B, Bad Bunny, J Balvin]
# 3                  [XXXTENTACION]
# 4           [Kendrick Lamar, SZA]
#
#                                    track_artists_ids  \
# 0   [246dkjvS1zLTtiykXe5h60, 1URnnhqYAYcrqrcwql10ft]
# 1                           [06HL4z0CvFAxyc27GXpf02]
# 2  [4kYSro6naA4h99UJvo89HB, 4q3ewBCX7sLwd24euuV69...
# 3                           [15UsOTVnJzReFVN1VCnxy4]
# 4   [2YZyLoL8N0Wb9xBt1NhZWg, 7tYKF4w9nC0nq9CsPZTHyP]
#
#                                                album          album_artists  \
# 0                               beerbongs & bentleys          [Post Malone]
# 1                                         reputation         [Taylor Swift]
# 2                                Invasion of Privacy              [Cardi B]
# 3                                                  ?         [XXXTENTACION]
# 4  Black Panther The Album Music From And Inspire...  [Kendrick Lamar, SZA]
#
#   release_date  explicit  duration_in_mins  acousticness  ...  liveness  \
# 0   2018-04-27      True              3.64        0.1240  ...    0.1310
# 1   2017-11-10     False              3.53        0.2040  ...    0.1260
# 2   2018-04-05     False              4.22        0.0981  ...    0.3780
# 3   2018-03-16      True              2.78        0.2580  ...    0.1230
# 4   2018-02-09      True              3.87        0.0605  ...    0.0926
#
#    loudness  speechiness    tempo  time_signature  track_duration_in_seconds  \
# 0    -6.136       0.0712  159.801               4                  218.14667
# 1    -6.471       0.1230  128.070               4                  211.85333
# 2    -4.026       0.1360  136.050               4                  253.39029
# 3    -4.880       0.1450   75.023               4                  166.60553
# 4    -4.946       0.0597   96.924               4                  232.18668
#
#    end_of_fade_in  start_of_fade_out  key  mode
# 0         0.00000          215.41151    5     0
# 1         0.34884          209.84454    9     0
# 2         0.15116          241.78938    5     0
# 3         0.00000          155.38794    8     1
# 4         0.00000          227.49170    8     1
#
# [5 rows x 23 columns]

# %%
df_allartists['track_artists'][2]
# Out:
# ['Cardi B', 'Bad Bunny', 'J Balvin']

# %% [markdown]
# ### Get artist data (id, artist name, genre, popularity, followers)

# %% [markdown]
# #### Extract track artist id column

# %%
artist_ids = df_allartists['track_artists_ids']
artist_ids
# Out:
# 0     [246dkjvS1zLTtiykXe5h60, 1URnnhqYAYcrqrcwql10ft]
# 1                             [06HL4z0CvFAxyc27GXpf02]
# 2    [4kYSro6naA4h99UJvo89HB, 4q3ewBCX7sLwd24euuV69...
# 3                             [15UsOTVnJzReFVN1VCnxy4]
# 4     [2YZyLoL8N0Wb9xBt1NhZWg, 7tYKF4w9nC0nq9CsPZTHyP]
# Name: track_artists_ids, dtype: object

# %% [markdown]
# #### Explode column

# %%
splody_ids = artist_ids.explode('track_artists_ids')
id_df= pd.DataFrame(splody_ids)
id_df
# Out:
#         track_artists_ids
# 0  246dkjvS1zLTtiykXe5h60
# 1  1URnnhqYAYcrqrcwql10ft
# 2  06HL4z0CvFAxyc27GXpf02
# 3  4kYSro6naA4h99UJvo89HB
# 4  4q3ewBCX7sLwd24euuV69X
# 5  1vyhD5VmyZ7KMfW5gqLgo5
# 6  15UsOTVnJzReFVN1VCnxy4
# 7  2YZyLoL8N0Wb9xBt1NhZWg
# 8  7tYKF4w9nC0nq9CsPZTHyP

# %% [markdown]
# #### Remove duplicates

# %%
id_df2 = id_df.drop_duplicates(subset=['track_artists_ids'], keep='first')
id_df2
# Out:
#         track_artists_ids
# 0  246dkjvS1zLTtiykXe5h60
# 1  1URnnhqYAYcrqrcwql10ft
# 2  06HL4z0CvFAxyc27GXpf02
# 3  4kYSro6naA4h99UJvo89HB
# 4  4q3ewBCX7sLwd24euuV69X
# 5  1vyhD5VmyZ7KMfW5gqLgo5
# 6  15UsOTVnJzReFVN1VCnxy4
# 7  2YZyLoL8N0Wb9xBt1NhZWg
# 8  7tYKF4w9nC0nq9CsPZTHyP

# %% [markdown]
# #### Convert to list

# %%
artist_id_list = id_df2['track_artists_ids'].tolist()
artist_id_list
# Out:
# ['246dkjvS1zLTtiykXe5h60',
#  '1URnnhqYAYcrqrcwql10ft',
#  '06HL4z0CvFAxyc27GXpf02',
#  '4kYSro6naA4h99UJvo89HB',
#  '4q3ewBCX7sLwd24euuV69X',
#  '1vyhD5VmyZ7KMfW5gqLgo5',
#  '15UsOTVnJzReFVN1VCnxy4',
#  '2YZyLoL8N0Wb9xBt1NhZWg',
#  '7tYKF4w9nC0nq9CsPZTHyP']

# %% [markdown]
# #### Function to extract all the details of each artist by passing their ID:

# %%
def get_artist_data(artist_id):
    meta = sp.artist(artist_id)
    artist_details = {'artist id': meta['id'],
                    'artist name': meta['name'],
                    'genres': meta['genres'],
                    'popularity': meta['popularity'],
                    'followers': meta['followers']['total']
                    }
    return artist_details

# %% [markdown]
# ####  Extract artist data

# %% [markdown]
# Extract artist data from list

# %%
artist_id_list
# Out:
# ['246dkjvS1zLTtiykXe5h60',
#  '1URnnhqYAYcrqrcwql10ft',
#  '06HL4z0CvFAxyc27GXpf02',
#  '4kYSro6naA4h99UJvo89HB',
#  '4q3ewBCX7sLwd24euuV69X',
#  '1vyhD5VmyZ7KMfW5gqLgo5',
#  '15UsOTVnJzReFVN1VCnxy4',
#  '2YZyLoL8N0Wb9xBt1NhZWg',
#  '7tYKF4w9nC0nq9CsPZTHyP']

# %%
artists = []
#  Loop over track ids and get their data points
for i in tqdm(range(len(artist_id_list))):
    time.sleep(.5)
    artist = get_artist_data(artist_id_list[i])
    artists.append(artist)
# Out:
# 100%|██████████| 9/9 [00:05<00:00,  1.65it/s]

# %%
artists
# Out:
# [{'artist id': '246dkjvS1zLTtiykXe5h60',
#   'artist name': 'Post Malone',
#   'genres': ['dfw rap', 'melodic rap', 'rap'],
#   'popularity': 92,
#   'followers': 35378269},
#  {'artist id': '1URnnhqYAYcrqrcwql10ft',
#   'artist name': '21 Savage',
#   'genres': ['atl hip hop', 'rap', 'trap'],
#   'popularity': 89,
#   'followers': 10574549},
#  {'artist id': '06HL4z0CvFAxyc27GXpf02',
#   'artist name': 'Taylor Swift',
#   'genres': ['pop'],
#   'popularity': 100,
#   'followers': 47325018},
#  {'artist id': '4kYSro6naA4h99UJvo89HB',
#   'artist name': 'Cardi B',
#   'genres': ['dance pop', 'pop', 'pop rap', 'rap'],
#   'popularity': 86,
#   'followers': 18844041},
#  {'artist id': '4q3ewBCX7sLwd24euuV69X',
#   'artist name': 'Bad Bunny',
#   'genres': ['latin', 'reggaeton', 'trap latino'],
#   'popularity': 98,
#   'followers': 41495345},
#  {'artist id': '1vyhD5VmyZ7KMfW5gqLgo5',
#   'artist name': 'J Balvin',
#   'genres': ['latin', 'reggaeton', 'reggaeton colombiano', 'trap latino'],
#   'popularity': 94,
#   'followers': 31594653},
#  {'artist id': '15UsOTVnJzReFVN1VCnxy4',
#   'artist name': 'XXXTENTACION',
#   'genres': ['emo rap', 'miami hip hop'],
#   'popularity': 91,
#   'followers': 33440056},
#  {'artist id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist name': 'Kendrick Lamar',
#   'genres': ['conscious hip hop', 'hip hop', 'rap', 'west coast rap'],
#   'popularity': 90,
#   'followers': 18984347},
#  {'artist id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist name': 'SZA',
#   'genres': ['pop', 'r&b', 'rap'],
#   'popularity': 89,
#   'followers': 6871943}]

# %% [markdown]
# #### Create dataframe

# %%
artist_df = pd.DataFrame(artists)
artist_df
# Out:
#                 artist id     artist name  \
# 0  246dkjvS1zLTtiykXe5h60     Post Malone
# 1  1URnnhqYAYcrqrcwql10ft       21 Savage
# 2  06HL4z0CvFAxyc27GXpf02    Taylor Swift
# 3  4kYSro6naA4h99UJvo89HB         Cardi B
# 4  4q3ewBCX7sLwd24euuV69X       Bad Bunny
# 5  1vyhD5VmyZ7KMfW5gqLgo5        J Balvin
# 6  15UsOTVnJzReFVN1VCnxy4    XXXTENTACION
# 7  2YZyLoL8N0Wb9xBt1NhZWg  Kendrick Lamar
# 8  7tYKF4w9nC0nq9CsPZTHyP             SZA
#
#                                               genres  popularity  followers
# 0                        [dfw rap, melodic rap, rap]          92   35378269
# 1                           [atl hip hop, rap, trap]          89   10574549
# 2                                              [pop]         100   47325018
# 3                     [dance pop, pop, pop rap, rap]          86   18844041
# 4                    [latin, reggaeton, trap latino]          98   41495345
# 5  [latin, reggaeton, reggaeton colombiano, trap ...          94   31594653
# 6                           [emo rap, miami hip hop]          91   33440056
# 7  [conscious hip hop, hip hop, rap, west coast rap]          90   18984347
# 8                                    [pop, r&b, rap]          89    6871943

# %% [markdown]
# # =================================================

# %% [markdown]
# ## Self Contained Loop Example

# %% [markdown]
# ### Supporting function definitions

# %% [markdown]
# #### Album artists names function

# %%
def get_all_album_artists_names(track_id):
    meta = sp.track(track_id)
    album_artist_list = []
    for item in (meta['album']['artists']):
        album_artist = item['name']
        album_artist_list.append(album_artist)
    return album_artist_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_names('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['Future', 'Juice WRLD']

# %% [markdown]
# #### Album artists ids function

# %%
def get_all_album_artists_ids(track_id):
    meta = sp.track(track_id)
    album_artist_id_list = []
    for item in (meta['album']['artists']):
        album_artist_id = item['id']
        album_artist_id_list.append(album_artist_id)
    return album_artist_id_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_ids('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['1RyvyyTE3xzB2ZywiAwp0i', '4MCBfE4596Uoi2O4DtmEMz']

# %% [markdown]
# #### Album artists genres function

# %%
def get_all_album_artists_genres(track_id):
    meta = sp.track(track_id)
    album_artist_genre_list = []
    for item in (meta['album']['artists']):
        album_artist_id = item['id']
        album_artist_genres = sp.artist(album_artist_id)['genres']
        album_artist_genre_list.append(album_artist_genres)
    return album_artist_genre_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_genres('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [['atl hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['chicago rap', 'melodic rap']]

# %% [markdown]
# #### Album artists popularity function

# %%
def get_all_album_artists_popularity(track_id):
    meta = sp.track(track_id)
    album_artist_popularity_list = []
    for item in (meta['album']['artists']):
        album_artist_id = item['id']
        album_artist_popularity = sp.artist(album_artist_id)['popularity']
        album_artist_popularity_list.append(album_artist_popularity)
    return album_artist_popularity_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_popularity('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [91, 97]

# %% [markdown]
# #### Album artists followers function

# %%
def get_all_album_artists_followers(track_id):
    meta = sp.track(track_id)
    album_artist_followers_list = []
    for item in (meta['album']['artists']):
        album_artist_id = item['id']
        album_artist_followers = sp.artist(album_artist_id)['followers']['total']
        album_artist_followers_list.append(album_artist_followers)
    return album_artist_followers_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_followers('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [10975511, 21519797]

# %% [markdown]
# #### Track artists names function

# %%
def get_all_track_artists_names(track_id):
    meta = sp.track(track_id)
    track_artist_list = []
    for item in (meta['artists']):
        track_artist = item['name']
        track_artist_list.append(track_artist)
    return track_artist_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_names('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['Future', 'Juice WRLD', 'Young Thug']

# %% [markdown]
# #### Track artists ids function

# %%
def get_all_track_artists_ids(track_id):
    meta = sp.track(track_id)
    track_artist_id_list = []
    for item in (meta['artists']):
        track_artist = item['id']
        track_artist_id_list.append(track_artist)
    return track_artist_id_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_ids('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['1RyvyyTE3xzB2ZywiAwp0i', '4MCBfE4596Uoi2O4DtmEMz', '50co4Is1HCEo8bhOyUWKpn']

# %% [markdown]
# #### Track artists genres function

# %%
def get_all_track_artists_genres(track_id):
    meta = sp.track(track_id)
    track_artist_genre_list = []
    for item in (meta['artists']):
        track_artist_id = item['id']
        track_artist_genres = sp.artist(track_artist_id)['genres']
        track_artist_genre_list.append(track_artist_genres)
    return track_artist_genre_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_genres('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [['atl hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['chicago rap', 'melodic rap'],
#  ['atl hip hop',
#   'atl trap',
#   'gangster rap',
#   'hip hop',
#   'melodic rap',
#   'rap',
#   'trap']]

# %% [markdown]
# #### Track artists popularity function

# %%
def get_all_track_artists_popularity(track_id):
    meta = sp.track(track_id)
    track_artist_popularity_list = []
    for item in (meta['artists']):
        track_artist_id = item['id']
        track_artist_popularity = sp.artist(track_artist_id)['popularity']
        track_artist_popularity_list.append(track_artist_popularity)
    return track_artist_popularity_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_popularity('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [91, 97, 90]

# %% [markdown]
# #### Track artists followers function

# %%
def get_all_track_artists_followers(track_id):
    meta = sp.track(track_id)
    track_artist_followers_list = []
    for item in (meta['artists']):
        track_artist_id = item['id']
        track_artist_followers = sp.artist(track_artist_id)['followers']['total']
        track_artist_followers_list.append(track_artist_followers)
    return track_artist_followers_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_followers('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [10975511, 21519797, 6836202]

# %% [markdown]
# ### Playlist data return function

# %%
def get_playlist_tracks_more_than_100_songs(username, playlist_id):
    results = sp.user_playlist_tracks(username, playlist_id)
    playlist_name = sp.playlist(playlist_id)['name']
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    results = tracks    
    
    pl_id = []
    pl_name = []
    chart_position = []
    album_name = []
    album_id = []
    album_release_date = []
    album_artists = []
    album_artists_ids = []
    album_artists_genres = []
    album_artists_popularity = []
    album_artists_followers = []
    track_name = []
    track_id = []
    track_popularity = []
    track_explicit = []
    track_artists = []
    track_artists_ids = []
    track_artists_genres = []
    track_artists_popularity = []
    track_artists_followers = []

    for i in tqdm(range(len(results))):
        if i == 0:
            pl_id = playlist_id
            pl_name = playlist_name
            chart_position = i + 1
            album_name = results[i]['track']['album']['name']
            album_id = results[i]['track']['album']['id']
            album_release_date = results[i]['track']['album']['release_date']
            album_artists = get_all_album_artists_names(results[i]['track']['id'])
            album_artists_ids = get_all_album_artists_ids(results[i]['track']['id'])
            album_artists_genres = get_all_album_artists_genres(results[i]['track']['id'])
            album_artists_popularity = get_all_album_artists_popularity(results[i]['track']['id'])
            album_artists_followers = get_all_album_artists_followers(results[i]['track']['id'])
            track_name = results[i]['track']['name']
            track_id = results[i]['track']['id']
            track_popularity = results[i]['track']['popularity']
            track_explicit = results[i]['track']['explicit']
            track_artists = get_all_track_artists_names(results[i]['track']['id'])
            track_artists_ids = get_all_album_artists_ids(results[i]['track']['id'])
            track_artists_genres = get_all_album_artists_genres(results[i]['track']['id'])
            track_artists_popularity = get_all_album_artists_popularity(results[i]['track']['id'])
            track_artists_followers = get_all_album_artists_followers(results[i]['track']['id'])
            features = sp.audio_features(track_id)
            features_df = pd.DataFrame(data=features, columns=features[0].keys())
            features_df['playlist_id'] = pl_id
            features_df['playlist_name'] = pl_name
            features_df['position'] = chart_position
            features_df['album_name'] = album_name
            features_df['album_id'] = album_id
            features_df['album_release_date'] = album_release_date
            features_df['album_artists'] = album_artists
            features_df['album_artists_ids'] = album_artists_ids
            features_df['album_artists_genres'] = album_artists_genres
            features_df['album_artists_popularity'] = album_artists_popularity
            features_df['album_artists_followers'] = album_artists_followers
            features_df['track_name'] = track_name
            features_df['track_id'] = track_id
            features_df['track_popularity'] = track_popularity
            features_df['track_explicit'] = track_explicit
            features_df['track_artists'] = track_artists
            features_df['track_artists_ids'] = track_artists_ids
            features_df['track_artists_genres'] = track_artists_genres
            features_df['track_artists_popularity'] = track_artists_popularity
            features_df['track_artists_followers'] = track_artists_followers            
            features_df = features_df[['playlist_id', 'playlist_name', 'position', 
                                       'album_name', 'album_id', 'album_release_date', 'album_artists', 'album_artists_ids',
                                       'album_artists_genres', 'album_artists_popularity', 'album_artists_followers',
                                       'track_name', 'track_id', 'track_popularity', 'track_artists', 
                                       'track_artists_ids', 'track_artists_genres', 'track_artists_popularity', 
                                       'track_explicit', 'track_artists_followers', 'danceability', 'energy', 
                                       'key', 'loudness', 'mode', 'acousticness', 'instrumentalness',
                                       'liveness', 'valence', 'tempo',
                                       'duration_ms', 'time_signature']]
            continue
        else:
            try:
                pl_id = playlist_id
                pl_name = playlist_name
                chart_position = (i + 1)
                album_name = results[i]['track']['album']['name']
                album_id = results[i]['track']['album']['id']
                album_release_date = results[i]['track']['album']['release_date']
                album_artists = get_all_album_artists_names(results[i]['track']['id'])
                album_artists_ids = get_all_album_artists_ids(results[i]['track']['id'])
                album_artists_genres = get_all_album_artists_genres(results[i]['track']['id'])
                album_artists_popularity = get_all_album_artists_popularity(results[i]['track']['id'])
                album_artists_followers = get_all_album_artists_followers(results[i]['track']['id'])
                track_name = results[i]['track']['name']
                track_id = results[i]['track']['id']
                track_popularity = results[i]['track']['popularity']
                track_artists = get_all_track_artists_names(results[i]['track']['id'])
                track_artists_ids = get_all_album_artists_ids(results[i]['track']['id'])
                track_artists_genres = get_all_album_artists_genres(results[i]['track']['id'])
                track_artists_popularity = get_all_album_artists_popularity(results[i]['track']['id'])
                track_explicit = results[i]['track']['explicit']
                track_artists_followers = get_all_album_artists_followers(results[i]['track']['id'])
                features = sp.audio_features(track_id)
                new_row = {'playlist_id': pl_id,
                    'playlist_name': pl_name,
                    'position': chart_position,
                    'album_name': album_name,
                    'album_id': album_id,
                    'album_release_date': album_release_date,
                    'album_artists': album_artists,
                    'album_artists_ids': album_artists_ids,
                    'album_artists_genres': album_artists_genres,
                    'album_artists_popularity': album_artists_popularity,
                    'album_artists_followers': album_artists_followers,
                    'track_name': track_name,
                    'track_id': track_id,
                    'track_popularity': track_popularity,
                    'track_artists': track_artists,
                    'track_artists_ids': track_artists_ids,
                    'track_artists_genres': track_artists_genres,
                    'track_artists_popularity': track_artists_popularity,
                    'track_explicit': track_explicit,
                    'track_artists_followers': track_artists_followers,
                    'danceability':[features[0]['danceability']],
                    'energy':[features[0]['energy']],
                    'key':[features[0]['key']],
                    'loudness':[features[0]['loudness']],
                    'mode':[features[0]['mode']],
                    'acousticness':[features[0]['acousticness']],
                    'instrumentalness':[features[0]['instrumentalness']],
                    'liveness':[features[0]['liveness']],
                    'valence':[features[0]['valence']],
                    'tempo':[features[0]['tempo']],
                    'duration_ms':[features[0]['duration_ms']],
                    'time_signature':[features[0]['time_signature']]
                }

                dfs = [features_df, pd.DataFrame(new_row)]
                features_df = pd.concat(dfs, ignore_index = True)
            except:
                continue
                
    return features_df

# %% [markdown]
# #### Playlist data return test

# %%
chart2021 = get_playlist_tracks_more_than_100_songs('katiekellert', '3avCwQPH6DkhMTRsizon7N')
# Out:
# 100%|██████████| 200/200 [05:42<00:00,  1.71s/it]

# %%
chart2021
# Out:
#                 playlist_id                  playlist_name  position  \
# 0    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         1
# 1    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         2
# 2    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         3
# 3    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         4
# 4    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         7
# ..                      ...                            ...       ...
# 132  3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021       196
# 133  3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021       197
# 134  3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021       198
# 135  3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021       199
# 136  3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021       200
#
#                                album_name                album_id  \
# 0             Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz
# 1                                    SOUR  6s84u2TUpR3wdUv4NgKA2j
# 2    Shoot For The Stars Aim For The Moon  7e7t0MCrNDcJZsPwUKjmOc
# 3                                evermore  2Xoteh7uEpea4TohMxjtaq
# 4            What You See Is What You Get  0S9D5NIDp2YXhYwlvuJzqx
# ..                                    ...                     ...
# 132                         Hybrid Theory  2pKw6GERJVAD61449B1EEM
# 133             The Chaos Chapter: FREEZE  5Zdr9vactwnJH4Vpe9Mid9
# 134                                    21  0Lg1uZvI312TPqxNWShFXL
# 135                          OK ORCHESTRA  1y2AzG31F4CuCKQ1rpIzaI
# 136                             THE ALBUM  71O60S5gIJSIAhdnrDIh3N
#
#     album_release_date        album_artists       album_artists_ids  \
# 0           2021-01-08        Morgan Wallen  4oUHIQIBe0LHzYfvXNW4QM
# 1           2021-05-21       Olivia Rodrigo  1McMsnEElThX1knmY4oliG
# 2           2020-07-03            Pop Smoke  0eDvMgVFoNV3TpwtrVCoTj
# 3           2020-12-11         Taylor Swift  06HL4z0CvFAxyc27GXpf02
# 4           2019-11-08           Luke Combs  718COspgdWOnwOFpJHRZHS
# ..                 ...                  ...                     ...
# 132         2000-10-24          Linkin Park  6XyY86QOPPrYVGvF9ch6wz
# 133         2021-05-31  TOMORROW X TOGETHER  0ghlgldX5Dd6720Q3qFyQB
# 134         2011-01-24                Adele  4dpARuHxo51G3z768sgnrY
# 135         2021-03-26                  AJR  6s22t5Y3prQHyaHWUN1R1C
# 136         2020-10-02            BLACKPINK  41MozSoPIsD1dJM0CLPjZF
#
#                                   album_artists_genres  \
# 0                               [contemporary country]
# 1                                                [pop]
# 2                                     [brooklyn drill]
# 3                                                [pop]
# 4                      [contemporary country, country]
# ..                                                 ...
# 132  [alternative metal, nu metal, post-grunge, rap...
# 133                           [k-pop, k-pop boy group]
# 134              [british soul, pop, pop soul, uk pop]
# 135                             [modern rock, pop rap]
# 136                          [k-pop, k-pop girl group]
#
#      album_artists_popularity  album_artists_followers  \
# 0                          86                  2705213
# 1                          92                 12088661
# 2                          89                  8721767
# 3                         100                 47362363
# 4                          83                  5981206
# ..                        ...                      ...
# 132                        87                 20780804
# 133                        81                  5265446
# 134                        96                 32617041
# 135                        78                  2071839
# 136                        85                 27238124
#
#                                        track_name                track_id  \
# 0                           More Than My Hometown  65mMCEOu5Ll1DBAfEUmerU
# 1                                 drivers license  5wANPM4fQCJwkGd4rN57mH
# 2                         What You Know Bout Love  1tkg4EHVoqnhR6iFEXb60y
# 3                                          willow  0lx2cLdOt3piJbcaXIV74f
# 4                       Beer Never Broke My Heart  7aEtlGHoiPAfRB084NiDmx
# ..                                            ...                     ...
# 132                                    In the End  3tSmXSxaAnU1EPGKa6NytH
# 133  0X1=LOVESONG (I Know I Love You) feat. Seori  1Z8TPHiKeCUyClxV6WTTIf
# 134                              Someone Like You  1zwMYTA5nlNjZxYrvBB2pV
# 135                                         Bang!  5FQPpxOXsvkMN6v18gtpwY
# 136                             How You Like That  4SFknyjLcyTLJFPKD2m96o
#
#      track_popularity        track_artists       track_artists_ids  \
# 0                  34        Morgan Wallen  4oUHIQIBe0LHzYfvXNW4QM
# 1                  92       Olivia Rodrigo  1McMsnEElThX1knmY4oliG
# 2                  85            Pop Smoke  0eDvMgVFoNV3TpwtrVCoTj
# 3                  82         Taylor Swift  06HL4z0CvFAxyc27GXpf02
# 4                  77           Luke Combs  718COspgdWOnwOFpJHRZHS
# ..                ...                  ...                     ...
# 132                66          Linkin Park  6XyY86QOPPrYVGvF9ch6wz
# 133                81  TOMORROW X TOGETHER  0ghlgldX5Dd6720Q3qFyQB
# 134                82                Adele  4dpARuHxo51G3z768sgnrY
# 135                68                  AJR  6s22t5Y3prQHyaHWUN1R1C
# 136                80            BLACKPINK  41MozSoPIsD1dJM0CLPjZF
#
#                                   track_artists_genres  \
# 0                               [contemporary country]
# 1                                                [pop]
# 2                                     [brooklyn drill]
# 3                                                [pop]
# 4                      [contemporary country, country]
# ..                                                 ...
# 132  [alternative metal, nu metal, post-grunge, rap...
# 133                           [k-pop, k-pop boy group]
# 134              [british soul, pop, pop soul, uk pop]
# 135                             [modern rock, pop rap]
# 136                          [k-pop, k-pop girl group]
#
#      track_artists_popularity  track_explicit  track_artists_followers  \
# 0                          86           False                  2705213
# 1                          92            True                 12088661
# 2                          89            True                  8721767
# 3                         100           False                 47362363
# 4                          83           False                  5981206
# ..                        ...             ...                      ...
# 132                        87           False                 20780804
# 133                        81           False                  5265446
# 134                        96           False                 32617041
# 135                        78           False                  2071839
# 136                        85           False                 27238124
#
#      danceability  energy  key  loudness  mode  acousticness  \
# 0           0.621   0.868    6    -5.478     1       0.61700
# 1           0.561   0.431   10    -8.810     1       0.76800
# 2           0.709   0.548   10    -8.493     1       0.65000
# 3           0.392   0.574    7    -9.195     1       0.83300
# 4           0.538   0.863    1    -4.483     1       0.01390
# ..            ...     ...  ...       ...   ...           ...
# 132         0.555   0.844    3    -6.567     0       0.00834
# 133         0.584   0.836    0    -4.925     1       0.05580
# 134         0.556   0.319    9    -8.251     1       0.89300
# 135         0.740   0.517    1    -6.233     0       0.01830
# 136         0.812   0.761   11    -5.222     1       0.04650
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0            0.000000    0.1310    0.594  126.010       216573               4
# 1            0.000014    0.1060    0.137  143.875       242013               4
# 2            0.000002    0.1330    0.543   83.995       160000               4
# 3            0.001790    0.1450    0.529   81.112       214707               4
# 4            0.000000    0.0874    0.637   77.001       186733               4
# ..                ...       ...      ...      ...          ...             ...
# 132          0.000000    0.0895    0.464  105.195       216800               4
# 133          0.000000    0.0663    0.484  104.973       202204               4
# 134          0.000000    0.0996    0.294  135.187       285240               4
# 135          0.000000    0.0558    0.698  139.917       170858               4
# 136          0.000135    0.0601    0.344  130.032       182956               4
#
# [137 rows x 32 columns]

# %%
print(chart2021.columns)
len(chart2021.columns)
# Out:
# Index(['playlist_id', 'playlist_name', 'position', 'album_name', 'album_id',
#        'album_release_date', 'album_artists', 'album_artists_ids',
#        'album_artists_genres', 'album_artists_popularity',
#        'album_artists_followers', 'track_name', 'track_id', 'track_popularity',
#        'track_artists', 'track_artists_ids', 'track_artists_genres',
#        'track_artists_popularity', 'track_explicit', 'track_artists_followers',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'time_signature'],
#       dtype='object')
# 32

# %% [markdown]
# # =====================================================

# %% [markdown]
# # WIP AREA

# %% [markdown]
# ### Get artist IDs from playlists or tracks

# %% [markdown]
# #### Create track container dictionaries
#
# * Note that since artists variable is not created in cell with function call, subsequent calls will be appended to the same dictionary

# %%
artists = []

# %% [markdown]
# #### Function to extract all of the tracks' artist ids from your playlist:

# %%
def get_artist_ids(playlist_id):
    artist_id_list = []
    playlist = sp.playlist(playlist_id)
    for item in playlist['tracks']['items']:
        music_track = item['track']
        artist_id_list.append(music_track['artists'][0]['id'])
    return artist_id_list

# %% [markdown]
# Test with playlist id '27Wi4y5VlHr43Q6UpZMVyS'

# %%
get_artist_ids('27Wi4y5VlHr43Q6UpZMVyS')
# Out:
# ['246dkjvS1zLTtiykXe5h60',
#  '06HL4z0CvFAxyc27GXpf02',
#  '4kYSro6naA4h99UJvo89HB',
#  '15UsOTVnJzReFVN1VCnxy4',
#  '2YZyLoL8N0Wb9xBt1NhZWg']

# %%
def get_all_track_artists_ids(track_id):
    meta = sp.track(track_id)
    track_artist_id_list = []
    for item in (meta['artists']):
        track_artist = item['id']
        track_artist_id_list.append(track_artist)
    return track_artist_id_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_ids('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['1RyvyyTE3xzB2ZywiAwp0i', '4MCBfE4596Uoi2O4DtmEMz', '50co4Is1HCEo8bhOyUWKpn']

# %% [markdown]
# #### Function to extract all the details of each artist by passing their ID:

# %%
def get_artist_data(artist_id):
    meta = sp.artist(artist_id)
    artist_details = {'artist id': meta['id'],
                    'artist name': meta['name'],
                    'genres': meta['genres'],
                    'popularity': meta['popularity'],
                    'followers': meta['followers']['total']
                    }
    return artist_details

# %% [markdown]
# ####  Extract artist data

# %% [markdown]
# Extract artist data of each track
#
# For testing:  playlist_id = '27Wi4y5VlHr43Q6UpZMVyS'

# %%
# Get the ids for all the songs in your playlist
playlist_id = input('Enter the playlist id')
artist_ids = get_artist_ids(playlist_id)
print(len(artist_ids))
print(artist_ids)

#  Loop over track ids and get their data points
for i in tqdm(range(len(artist_ids))):
    time.sleep(.5)
    artist = get_artist_data(artist_ids[i])
    artists.append(artist)
# Out:
# Enter the playlist id27Wi4y5VlHr43Q6UpZMVyS
#   0%|          | 0/5 [00:00<?, ?it/s]
# 5
# ['246dkjvS1zLTtiykXe5h60', '06HL4z0CvFAxyc27GXpf02', '4kYSro6naA4h99UJvo89HB', '15UsOTVnJzReFVN1VCnxy4', '2YZyLoL8N0Wb9xBt1NhZWg']
# 100%|██████████| 5/5 [00:02<00:00,  1.68it/s]

# %% [markdown]
# #### Create dataframe

# %%
artist_df = pd.DataFrame(artists)
artist_df.head()
# Out:
#                 artist id     artist name  \
# 0  246dkjvS1zLTtiykXe5h60     Post Malone
# 1  06HL4z0CvFAxyc27GXpf02    Taylor Swift
# 2  4kYSro6naA4h99UJvo89HB         Cardi B
# 3  15UsOTVnJzReFVN1VCnxy4    XXXTENTACION
# 4  2YZyLoL8N0Wb9xBt1NhZWg  Kendrick Lamar
#
#                                               genres  popularity  followers
# 0                        [dfw rap, melodic rap, rap]          92   35378269
# 1                                              [pop]         100   47325018
# 2                     [dance pop, pop, pop rap, rap]          86   18844041
# 3                           [emo rap, miami hip hop]          91   33440056
# 4  [conscious hip hop, hip hop, rap, west coast rap]          90   18984347

# %% [markdown]
# ### Get track's audio features directly from playlist (for concept only, still a WIP)

# %% [markdown]
# #### Function to extract each track's audio features from a playlist directly

# %%
def get_playlist_tracks(playlist_id):
    track_attributes = sp.playlist_tracks(playlist_id)
    return track_attributes

# %%
playlist_tracks_data = []
playlist_ids = ['0qfagBJB5ou0r1kwQDZ8Op']

#  Loop over playlist ids and get their data points
for i in tqdm(range(len(playlist_ids))):
    time.sleep(.5)
    playlist_track = get_playlist_tracks(playlist_ids[i])
    playlist_tracks_data.append(playlist_track)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.57it/s]

# %%
playlist_df = pd.DataFrame(playlist_tracks_data)
playlist_df
# Out:
#                                                 href  \
# 0  https://api.spotify.com/v1/playlists/0qfagBJB5...
#
#                                                items  limit  next  offset  \
# 0  [{'added_at': '2015-12-04T17:25:30Z', 'added_b...    100  None       0
#
#   previous  total
# 0     None     21

# %% [markdown]
# ### Get track's audio features directly from playlist

# %% [markdown]
# #### Function to extract each track's data from a playlist directly

# %%
def get_playlist_data(playlist_id):
    playlist_tracks = sp.playlist_tracks(playlist_id)
    return playlist_tracks

# %%
playlist_tracks_data = []
playlist_ids = ['0qfagBJB5ou0r1kwQDZ8Op']

#  Loop over playlist ids and get their data points
for i in tqdm(range(len(playlist_ids))):
    time.sleep(.5)
    playlist_track_data = get_playlist_data(playlist_ids[i])
    playlist_tracks_data.append(playlist_track_data)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.47it/s]

# %%
playlist_tracks_data
# Out:
# [{'href': 'https://api.spotify.com/v1/playlists/0qfagBJB5ou0r1kwQDZ8Op/tracks?offset=0&limit=100&additional_types=track',
#   'items': [{'added_at': '2015-12-04T17:25:30Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3iOvXCl6edW5Um0fXEBRXy'},
#         'href': 'https://api.spotify.com/v1/artists/3iOvXCl6edW5Um0fXEBRXy',
#         'id': '3iOvXCl6edW5Um0fXEBRXy',
#         'name': 'The xx',
#         'type': 'artist',
#         'uri': 'spotify:artist:3iOvXCl6edW5Um0fXEBRXy'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2nXJkqkS1tIKIyhBcFMmwz'},
#       'href': 'https://api.spotify.com/v1/albums/2nXJkqkS1tIKIyhBcFMmwz',
#       'id': '2nXJkqkS1tIKIyhBcFMmwz',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273055437bf35e8ba027bed0882',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02055437bf35e8ba027bed0882',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851055437bf35e8ba027bed0882',
#         'width': 64}],
#       'name': 'xx',
#       'release_date': '2009-08-16',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:2nXJkqkS1tIKIyhBcFMmwz'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3iOvXCl6edW5Um0fXEBRXy'},
#        'href': 'https://api.spotify.com/v1/artists/3iOvXCl6edW5Um0fXEBRXy',
#        'id': '3iOvXCl6edW5Um0fXEBRXy',
#        'name': 'The xx',
#        'type': 'artist',
#        'uri': 'spotify:artist:3iOvXCl6edW5Um0fXEBRXy'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 127920,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBBKS0900196'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0bXpmJyHHYPk6QBFj25bYF'},
#      'href': 'https://api.spotify.com/v1/tracks/0bXpmJyHHYPk6QBFj25bYF',
#      'id': '0bXpmJyHHYPk6QBFj25bYF',
#      'is_local': False,
#      'name': 'Intro',
#      'popularity': 4,
#      'preview_url': None,
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:0bXpmJyHHYPk6QBFj25bYF'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2015-12-04T09:03:12Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qk9voo8llSGYcZ6xrBzKx'},
#         'href': 'https://api.spotify.com/v1/artists/2qk9voo8llSGYcZ6xrBzKx',
#         'id': '2qk9voo8llSGYcZ6xrBzKx',
#         'name': 'Kings of Leon',
#         'type': 'artist',
#         'uri': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3GQy3QdRfl7RZUix1rhLtB'},
#       'href': 'https://api.spotify.com/v1/albums/3GQy3QdRfl7RZUix1rhLtB',
#       'id': '3GQy3QdRfl7RZUix1rhLtB',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2731ac63a3c719dd37cab3d51be',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e021ac63a3c719dd37cab3d51be',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048511ac63a3c719dd37cab3d51be',
#         'width': 64}],
#       'name': 'Come Around Sundown',
#       'release_date': '2010-10-19',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:3GQy3QdRfl7RZUix1rhLtB'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qk9voo8llSGYcZ6xrBzKx'},
#        'href': 'https://api.spotify.com/v1/artists/2qk9voo8llSGYcZ6xrBzKx',
#        'id': '2qk9voo8llSGYcZ6xrBzKx',
#        'name': 'Kings of Leon',
#        'type': 'artist',
#        'uri': 'spotify:artist:2qk9voo8llSGYcZ6xrBzKx'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 250533,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USRC11000687'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0Xy9xPPs2zRRFqljGqKXel'},
#      'href': 'https://api.spotify.com/v1/tracks/0Xy9xPPs2zRRFqljGqKXel',
#      'id': '0Xy9xPPs2zRRFqljGqKXel',
#      'is_local': False,
#      'name': 'Pyro',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:0Xy9xPPs2zRRFqljGqKXel'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2015-12-02T15:37:09Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0yNLKJebCb8Aueb54LYya3'},
#         'href': 'https://api.spotify.com/v1/artists/0yNLKJebCb8Aueb54LYya3',
#         'id': '0yNLKJebCb8Aueb54LYya3',
#         'name': 'New Order',
#         'type': 'artist',
#         'uri': 'spotify:artist:0yNLKJebCb8Aueb54LYya3'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3c1pvSBGoHSbtiKWGCSTcp'},
#       'href': 'https://api.spotify.com/v1/albums/3c1pvSBGoHSbtiKWGCSTcp',
#       'id': '3c1pvSBGoHSbtiKWGCSTcp',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27350d0df42049d369c5c97c397',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0250d0df42049d369c5c97c397',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485150d0df42049d369c5c97c397',
#         'width': 64}],
#       'name': 'Music Complete',
#       'release_date': '2015-09-25',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:3c1pvSBGoHSbtiKWGCSTcp'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0yNLKJebCb8Aueb54LYya3'},
#        'href': 'https://api.spotify.com/v1/artists/0yNLKJebCb8Aueb54LYya3',
#        'id': '0yNLKJebCb8Aueb54LYya3',
#        'name': 'New Order',
#        'type': 'artist',
#        'uri': 'spotify:artist:0yNLKJebCb8Aueb54LYya3'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 328240,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBR8R1500214'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0RqRN88qFUEeOQZ7VklA14'},
#      'href': 'https://api.spotify.com/v1/tracks/0RqRN88qFUEeOQZ7VklA14',
#      'id': '0RqRN88qFUEeOQZ7VklA14',
#      'is_local': False,
#      'name': 'Restless',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:0RqRN88qFUEeOQZ7VklA14'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2015-12-02T15:37:24Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6dgwEwnK0YtDfS9XhRwBTG'},
#         'href': 'https://api.spotify.com/v1/artists/6dgwEwnK0YtDfS9XhRwBTG',
#         'id': '6dgwEwnK0YtDfS9XhRwBTG',
#         'name': 'Broken Bells',
#         'type': 'artist',
#         'uri': 'spotify:artist:6dgwEwnK0YtDfS9XhRwBTG'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0cjMGmZKB9ZWzcb0VcASpf'},
#       'href': 'https://api.spotify.com/v1/albums/0cjMGmZKB9ZWzcb0VcASpf',
#       'id': '0cjMGmZKB9ZWzcb0VcASpf',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2739c111e02e4ae7cc0d1caa91d',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e029c111e02e4ae7cc0d1caa91d',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048519c111e02e4ae7cc0d1caa91d',
#         'width': 64}],
#       'name': 'After the Disco',
#       'release_date': '2014-01-13',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:0cjMGmZKB9ZWzcb0VcASpf'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6dgwEwnK0YtDfS9XhRwBTG'},
#        'href': 'https://api.spotify.com/v1/artists/6dgwEwnK0YtDfS9XhRwBTG',
#        'id': '6dgwEwnK0YtDfS9XhRwBTG',
#        'name': 'Broken Bells',
#        'type': 'artist',
#        'uri': 'spotify:artist:6dgwEwnK0YtDfS9XhRwBTG'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 221426,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USSM11305460'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1QZJiYulh7ak7GpZ8OAdwI'},
#      'href': 'https://api.spotify.com/v1/tracks/1QZJiYulh7ak7GpZ8OAdwI',
#      'id': '1QZJiYulh7ak7GpZ8OAdwI',
#      'is_local': False,
#      'name': 'Control',
#      'popularity': 47,
#      'preview_url': 'https://p.scdn.co/mp3-preview/6c8c6759e238f49e1b1487c6798fd73230700b4d?cid=303fd13b2f764be5bf062c320edc2376',
#      'track': True,
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:1QZJiYulh7ak7GpZ8OAdwI'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2015-12-02T15:37:44Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0qLNsNKm8bQcMoRFkR8Hmh'},
#         'href': 'https://api.spotify.com/v1/artists/0qLNsNKm8bQcMoRFkR8Hmh',
#         'id': '0qLNsNKm8bQcMoRFkR8Hmh',
#         'name': 'James',
#         'type': 'artist',
#         'uri': 'spotify:artist:0qLNsNKm8bQcMoRFkR8Hmh'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1m0zaIFvtbs5kb7ZtvWQ0c'},
#       'href': 'https://api.spotify.com/v1/albums/1m0zaIFvtbs5kb7ZtvWQ0c',
#       'id': '1m0zaIFvtbs5kb7ZtvWQ0c',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273aacdb6a4b555b537b050d26e',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02aacdb6a4b555b537b050d26e',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851aacdb6a4b555b537b050d26e',
#         'width': 64}],
#       'name': 'La Petite Mort',
#       'release_date': '2014-06-02',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:1m0zaIFvtbs5kb7ZtvWQ0c'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0qLNsNKm8bQcMoRFkR8Hmh'},
#        'href': 'https://api.spotify.com/v1/artists/0qLNsNKm8bQcMoRFkR8Hmh',
#        'id': '0qLNsNKm8bQcMoRFkR8Hmh',
#        'name': 'James',
#        'type': 'artist',
#        'uri': 'spotify:artist:0qLNsNKm8bQcMoRFkR8Hmh'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 297931,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GB5KW1401014'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0wrBkSiN1Y1StFR1Q3ZC28'},
#      'href': 'https://api.spotify.com/v1/tracks/0wrBkSiN1Y1StFR1Q3ZC28',
#      'id': '0wrBkSiN1Y1StFR1Q3ZC28',
#      'is_local': False,
#      'name': "All I'm Saying",
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 10,
#      'type': 'track',
#      'uri': 'spotify:track:0wrBkSiN1Y1StFR1Q3ZC28'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2016-01-01T21:24:08Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2DaxqgrOhkeH0fpeiQq2f4'},
#         'href': 'https://api.spotify.com/v1/artists/2DaxqgrOhkeH0fpeiQq2f4',
#         'id': '2DaxqgrOhkeH0fpeiQq2f4',
#         'name': 'Oasis',
#         'type': 'artist',
#         'uri': 'spotify:artist:2DaxqgrOhkeH0fpeiQq2f4'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CD',
#        'CG',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DJ',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'FJ',
#        'FM',
#        'GA',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IL',
#        'IN',
#        'IQ',
#        'IT',
#        'JM',
#        'JO',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LV',
#        'LY',
#        'MA',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/75KnF13DIx7GXfz5IesWtT'},
#       'href': 'https://api.spotify.com/v1/albums/75KnF13DIx7GXfz5IesWtT',
#       'id': '75KnF13DIx7GXfz5IesWtT',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273a42d5a90727767ada79f3d85',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02a42d5a90727767ada79f3d85',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851a42d5a90727767ada79f3d85',
#         'width': 64}],
#       'name': 'Dig Out Your Soul',
#       'release_date': '2008-10-06',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:75KnF13DIx7GXfz5IesWtT'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2DaxqgrOhkeH0fpeiQq2f4'},
#        'href': 'https://api.spotify.com/v1/artists/2DaxqgrOhkeH0fpeiQq2f4',
#        'id': '2DaxqgrOhkeH0fpeiQq2f4',
#        'name': 'Oasis',
#        'type': 'artist',
#        'uri': 'spotify:artist:2DaxqgrOhkeH0fpeiQq2f4'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'FJ',
#       'FM',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'IQ',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LV',
#       'LY',
#       'MA',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 250013,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBQCP0800006'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4Q2UM2QSR7Gye03jvl4Rdw'},
#      'href': 'https://api.spotify.com/v1/tracks/4Q2UM2QSR7Gye03jvl4Rdw',
#      'id': '4Q2UM2QSR7Gye03jvl4Rdw',
#      'is_local': False,
#      'name': "I'm Outta Time",
#      'popularity': 46,
#      'preview_url': 'https://p.scdn.co/mp3-preview/a9c25eeea86f7f10bbbb3fe2eac0da1e87a8b1cf?cid=303fd13b2f764be5bf062c320edc2376',
#      'track': True,
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:4Q2UM2QSR7Gye03jvl4Rdw'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2015-12-02T15:37:36Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Bf4u6r96pGx1eIbaGqfvf'},
#         'href': 'https://api.spotify.com/v1/artists/3Bf4u6r96pGx1eIbaGqfvf',
#         'id': '3Bf4u6r96pGx1eIbaGqfvf',
#         'name': 'Unkle Bob',
#         'type': 'artist',
#         'uri': 'spotify:artist:3Bf4u6r96pGx1eIbaGqfvf'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6985jdlB4pjn9PcN7nmRMG'},
#       'href': 'https://api.spotify.com/v1/albums/6985jdlB4pjn9PcN7nmRMG',
#       'id': '6985jdlB4pjn9PcN7nmRMG',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27389e5033708b898301fd06a31',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0289e5033708b898301fd06a31',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485189e5033708b898301fd06a31',
#         'width': 64}],
#       'name': 'Swans Collection',
#       'release_date': '2006-10-23',
#       'release_date_precision': 'day',
#       'total_tracks': 5,
#       'type': 'album',
#       'uri': 'spotify:album:6985jdlB4pjn9PcN7nmRMG'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Bf4u6r96pGx1eIbaGqfvf'},
#        'href': 'https://api.spotify.com/v1/artists/3Bf4u6r96pGx1eIbaGqfvf',
#        'id': '3Bf4u6r96pGx1eIbaGqfvf',
#        'name': 'Unkle Bob',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Bf4u6r96pGx1eIbaGqfvf'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 247297,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBLMM1100005'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5urkJ8dcmxtvsnruNfx6ZS'},
#      'href': 'https://api.spotify.com/v1/tracks/5urkJ8dcmxtvsnruNfx6ZS',
#      'id': '5urkJ8dcmxtvsnruNfx6ZS',
#      'is_local': False,
#      'name': 'Swans (Extended Version)',
#      'popularity': 19,
#      'preview_url': 'https://p.scdn.co/mp3-preview/0cdacb4947fc2ac862c839a531b1ec49dcf13ed1?cid=303fd13b2f764be5bf062c320edc2376',
#      'track': True,
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:5urkJ8dcmxtvsnruNfx6ZS'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2015-12-04T12:41:51Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7sjttK1WcZeyLPn3IsQ62L'},
#         'href': 'https://api.spotify.com/v1/artists/7sjttK1WcZeyLPn3IsQ62L',
#         'id': '7sjttK1WcZeyLPn3IsQ62L',
#         'name': "Noel Gallagher's High Flying Birds",
#         'type': 'artist',
#         'uri': 'spotify:artist:7sjttK1WcZeyLPn3IsQ62L'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5Ngc0q3qKwp8buErZy96vs'},
#       'href': 'https://api.spotify.com/v1/albums/5Ngc0q3qKwp8buErZy96vs',
#       'id': '5Ngc0q3qKwp8buErZy96vs',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2730b1f6ad308db974bf64a4a44',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e020b1f6ad308db974bf64a4a44',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048510b1f6ad308db974bf64a4a44',
#         'width': 64}],
#       'name': 'Chasing Yesterday',
#       'release_date': '2015-02-27',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:5Ngc0q3qKwp8buErZy96vs'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7sjttK1WcZeyLPn3IsQ62L'},
#        'href': 'https://api.spotify.com/v1/artists/7sjttK1WcZeyLPn3IsQ62L',
#        'id': '7sjttK1WcZeyLPn3IsQ62L',
#        'name': "Noel Gallagher's High Flying Birds",
#        'type': 'artist',
#        'uri': 'spotify:artist:7sjttK1WcZeyLPn3IsQ62L'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 315093,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBDZH1400011'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6ujlgkgbsrPskgWslEcZmR'},
#      'href': 'https://api.spotify.com/v1/tracks/6ujlgkgbsrPskgWslEcZmR',
#      'id': '6ujlgkgbsrPskgWslEcZmR',
#      'is_local': False,
#      'name': 'Ballad of the Mighty I',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 10,
#      'type': 'track',
#      'uri': 'spotify:track:6ujlgkgbsrPskgWslEcZmR'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2015-12-04T12:40:29Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1eClJfHLoDI4rZe5HxzBFv'},
#         'href': 'https://api.spotify.com/v1/artists/1eClJfHLoDI4rZe5HxzBFv',
#         'id': '1eClJfHLoDI4rZe5HxzBFv',
#         'name': 'INXS',
#         'type': 'artist',
#         'uri': 'spotify:artist:1eClJfHLoDI4rZe5HxzBFv'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7CJvhqb2PJq5fBcY6eKqjl'},
#       'href': 'https://api.spotify.com/v1/albums/7CJvhqb2PJq5fBcY6eKqjl',
#       'id': '7CJvhqb2PJq5fBcY6eKqjl',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273114b2baa75317b81a8c9c7ca',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02114b2baa75317b81a8c9c7ca',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851114b2baa75317b81a8c9c7ca',
#         'width': 64}],
#       'name': 'INXS Remastered',
#       'release_date': '2011-01-01',
#       'release_date_precision': 'day',
#       'total_tracks': 110,
#       'type': 'album',
#       'uri': 'spotify:album:7CJvhqb2PJq5fBcY6eKqjl'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1eClJfHLoDI4rZe5HxzBFv'},
#        'href': 'https://api.spotify.com/v1/artists/1eClJfHLoDI4rZe5HxzBFv',
#        'id': '1eClJfHLoDI4rZe5HxzBFv',
#        'name': 'INXS',
#        'type': 'artist',
#        'uri': 'spotify:artist:1eClJfHLoDI4rZe5HxzBFv'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 6,
#      'duration_ms': 184586,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAMX8700005'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3pyTksNccLM1jRvzQ4zTke'},
#      'href': 'https://api.spotify.com/v1/tracks/3pyTksNccLM1jRvzQ4zTke',
#      'id': '3pyTksNccLM1jRvzQ4zTke',
#      'is_local': False,
#      'name': 'Never Tear Us Apart',
#      'popularity': 59,
#      'preview_url': None,
#      'track': True,
#      'track_number': 8,
#      'type': 'track',
#      'uri': 'spotify:track:3pyTksNccLM1jRvzQ4zTke'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2016-01-14T10:06:48Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4STHEaNw4mPZ2tzheohgXB'},
#         'href': 'https://api.spotify.com/v1/artists/4STHEaNw4mPZ2tzheohgXB',
#         'id': '4STHEaNw4mPZ2tzheohgXB',
#         'name': 'Paul McCartney',
#         'type': 'artist',
#         'uri': 'spotify:artist:4STHEaNw4mPZ2tzheohgXB'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6yz4gu8dFShSJyO5n71HuW'},
#       'href': 'https://api.spotify.com/v1/albums/6yz4gu8dFShSJyO5n71HuW',
#       'id': '6yz4gu8dFShSJyO5n71HuW',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2736c7bbf0a930a968c029b0a60',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e026c7bbf0a930a968c029b0a60',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048516c7bbf0a930a968c029b0a60',
#         'width': 64}],
#       'name': 'Back In The U.S.',
#       'release_date': '2003-05-17',
#       'release_date_precision': 'day',
#       'total_tracks': 35,
#       'type': 'album',
#       'uri': 'spotify:album:6yz4gu8dFShSJyO5n71HuW'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4STHEaNw4mPZ2tzheohgXB'},
#        'href': 'https://api.spotify.com/v1/artists/4STHEaNw4mPZ2tzheohgXB',
#        'id': '4STHEaNw4mPZ2tzheohgXB',
#        'name': 'Paul McCartney',
#        'type': 'artist',
#        'uri': 'spotify:artist:4STHEaNw4mPZ2tzheohgXB'}],
#      'available_markets': [],
#      'disc_number': 2,
#      'duration_ms': 421026,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBCCS0201283'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/7AiIlhSSVKAyMJTygWuut2'},
#      'href': 'https://api.spotify.com/v1/tracks/7AiIlhSSVKAyMJTygWuut2',
#      'id': '7AiIlhSSVKAyMJTygWuut2',
#      'is_local': False,
#      'name': 'Hey Jude',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 12,
#      'type': 'track',
#      'uri': 'spotify:track:7AiIlhSSVKAyMJTygWuut2'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2016-01-14T10:07:10Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4x1nvY2FN8jxqAFA0DA02H'},
#         'href': 'https://api.spotify.com/v1/artists/4x1nvY2FN8jxqAFA0DA02H',
#         'id': '4x1nvY2FN8jxqAFA0DA02H',
#         'name': 'John Lennon',
#         'type': 'artist',
#         'uri': 'spotify:artist:4x1nvY2FN8jxqAFA0DA02H'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0xzaemKucrJpYhyl7TltAk'},
#       'href': 'https://api.spotify.com/v1/albums/0xzaemKucrJpYhyl7TltAk',
#       'id': '0xzaemKucrJpYhyl7TltAk',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27399581550ef9746ca582bb3cc',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0299581550ef9746ca582bb3cc',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485199581550ef9746ca582bb3cc',
#         'width': 64}],
#       'name': 'Imagine',
#       'release_date': '1971-09-09',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:0xzaemKucrJpYhyl7TltAk'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4x1nvY2FN8jxqAFA0DA02H'},
#        'href': 'https://api.spotify.com/v1/artists/4x1nvY2FN8jxqAFA0DA02H',
#        'id': '4x1nvY2FN8jxqAFA0DA02H',
#        'name': 'John Lennon',
#        'type': 'artist',
#        'uri': 'spotify:artist:4x1nvY2FN8jxqAFA0DA02H'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
# ...
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 356600,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBBQY9700008'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2gANywSFYF58YFMPdDSAjC'},
#      'href': 'https://api.spotify.com/v1/tracks/2gANywSFYF58YFMPdDSAjC',
#      'id': '2gANywSFYF58YFMPdDSAjC',
#      'is_local': False,
#      'name': 'Stand by Me',
#      'popularity': 61,
#      'preview_url': 'https://p.scdn.co/mp3-preview/c65ac84e70d27c651112226518252ce645d993aa?cid=303fd13b2f764be5bf062c320edc2376',
#      'track': True,
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:2gANywSFYF58YFMPdDSAjC'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2016-06-20T20:32:50Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0k17h0D3J5VfsdmQ1iZtE9'},
#         'href': 'https://api.spotify.com/v1/artists/0k17h0D3J5VfsdmQ1iZtE9',
#         'id': '0k17h0D3J5VfsdmQ1iZtE9',
#         'name': 'Pink Floyd',
#         'type': 'artist',
#         'uri': 'spotify:artist:0k17h0D3J5VfsdmQ1iZtE9'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1ITpsfAcoaSe4i1tUXm44D'},
#       'href': 'https://api.spotify.com/v1/albums/1ITpsfAcoaSe4i1tUXm44D',
#       'id': '1ITpsfAcoaSe4i1tUXm44D',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27331f8c6d9e21df18ddcb51e5e',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0231f8c6d9e21df18ddcb51e5e',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485131f8c6d9e21df18ddcb51e5e',
#         'width': 64}],
#       'name': 'The Wall [2011 - Remaster] (2011 Remastered Version)',
#       'release_date': '1979-11-30',
#       'release_date_precision': 'day',
#       'total_tracks': 53,
#       'type': 'album',
#       'uri': 'spotify:album:1ITpsfAcoaSe4i1tUXm44D'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0k17h0D3J5VfsdmQ1iZtE9'},
#        'href': 'https://api.spotify.com/v1/artists/0k17h0D3J5VfsdmQ1iZtE9',
#        'id': '0k17h0D3J5VfsdmQ1iZtE9',
#        'name': 'Pink Floyd',
#        'type': 'artist',
#        'uri': 'spotify:artist:0k17h0D3J5VfsdmQ1iZtE9'}],
#      'available_markets': [],
#      'disc_number': 2,
#      'duration_ms': 382296,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBN9Y1100113'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/29zkoUsOE50f0I3n44LjjU'},
#      'href': 'https://api.spotify.com/v1/tracks/29zkoUsOE50f0I3n44LjjU',
#      'id': '29zkoUsOE50f0I3n44LjjU',
#      'is_local': False,
#      'name': 'Comfortably Numb - 2011 Remastered Version',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:29zkoUsOE50f0I3n44LjjU'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2016-09-28T12:41:01Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4W48hZAnAHVOC2c8WH8pcq'},
#         'href': 'https://api.spotify.com/v1/artists/4W48hZAnAHVOC2c8WH8pcq',
#         'id': '4W48hZAnAHVOC2c8WH8pcq',
#         'name': 'The Temper Trap',
#         'type': 'artist',
#         'uri': 'spotify:artist:4W48hZAnAHVOC2c8WH8pcq'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7cBGSjfw2xMosazpbA0tgp'},
#       'href': 'https://api.spotify.com/v1/albums/7cBGSjfw2xMosazpbA0tgp',
#       'id': '7cBGSjfw2xMosazpbA0tgp',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27302ce546c6d9e29b942b2d9d6',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0202ce546c6d9e29b942b2d9d6',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485102ce546c6d9e29b942b2d9d6',
#         'width': 64}],
#       'name': 'Conditions',
#       'release_date': '2009-08-09',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:7cBGSjfw2xMosazpbA0tgp'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4W48hZAnAHVOC2c8WH8pcq'},
#        'href': 'https://api.spotify.com/v1/artists/4W48hZAnAHVOC2c8WH8pcq',
#        'id': '4W48hZAnAHVOC2c8WH8pcq',
#        'name': 'The Temper Trap',
#        'type': 'artist',
#        'uri': 'spotify:artist:4W48hZAnAHVOC2c8WH8pcq'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 216066,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBZUZ0900010'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6d3geXDfoj6hz882o9Ip9S'},
#      'href': 'https://api.spotify.com/v1/tracks/6d3geXDfoj6hz882o9Ip9S',
#      'id': '6d3geXDfoj6hz882o9Ip9S',
#      'is_local': False,
#      'name': 'Love Lost',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:6d3geXDfoj6hz882o9Ip9S'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2016-10-27T05:17:11Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OsRAKCvk37zwYcnzRf5XF'},
#         'href': 'https://api.spotify.com/v1/artists/3OsRAKCvk37zwYcnzRf5XF',
#         'id': '3OsRAKCvk37zwYcnzRf5XF',
#         'name': 'Moby',
#         'type': 'artist',
#         'uri': 'spotify:artist:3OsRAKCvk37zwYcnzRf5XF'}],
#       'available_markets': ['CA', 'US'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3wRlU7n3LULfjL0e9RtB5Q'},
#       'href': 'https://api.spotify.com/v1/albums/3wRlU7n3LULfjL0e9RtB5Q',
#       'id': '3wRlU7n3LULfjL0e9RtB5Q',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2734964b63a3b440fa58bb9d09e',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e024964b63a3b440fa58bb9d09e',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048514964b63a3b440fa58bb9d09e',
#         'width': 64}],
#       'name': 'Play & Play: B Sides',
#       'release_date': '2008-06-02',
#       'release_date_precision': 'day',
#       'total_tracks': 29,
#       'type': 'album',
#       'uri': 'spotify:album:3wRlU7n3LULfjL0e9RtB5Q'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3OsRAKCvk37zwYcnzRf5XF'},
#        'href': 'https://api.spotify.com/v1/artists/3OsRAKCvk37zwYcnzRf5XF',
#        'id': '3OsRAKCvk37zwYcnzRf5XF',
#        'name': 'Moby',
#        'type': 'artist',
#        'uri': 'spotify:artist:3OsRAKCvk37zwYcnzRf5XF'}],
#      'available_markets': ['CA', 'US'],
#      'disc_number': 1,
#      'duration_ms': 241173,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAJH9900036'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2UKYMN7VnsQo40n0qCt6Sa'},
#      'href': 'https://api.spotify.com/v1/tracks/2UKYMN7VnsQo40n0qCt6Sa',
#      'id': '2UKYMN7VnsQo40n0qCt6Sa',
#      'is_local': False,
#      'name': 'Porcelain',
#      'popularity': 58,
#      'preview_url': 'https://p.scdn.co/mp3-preview/ad672a346d38cdcdb7ea6c246282d43522473968?cid=303fd13b2f764be5bf062c320edc2376',
#      'track': True,
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:2UKYMN7VnsQo40n0qCt6Sa'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2017-01-21T17:56:44Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#         'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#         'id': '0LyfQWJT6nXafLPZqxe9Of',
#         'name': 'Various Artists',
#         'type': 'artist',
#         'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'GA',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7bXOViTvx6EHXuYFuI2yfj'},
#       'href': 'https://api.spotify.com/v1/albums/7bXOViTvx6EHXuYFuI2yfj',
#       'id': '7bXOViTvx6EHXuYFuI2yfj',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273f17ddc825889b0dd22798b9b',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02f17ddc825889b0dd22798b9b',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851f17ddc825889b0dd22798b9b',
#         'width': 64}],
#       'name': 'The Fault In Our Stars: Music From The Motion Picture',
#       'release_date': '2014-05-19',
#       'release_date_precision': 'day',
#       'total_tracks': 16,
#       'type': 'album',
#       'uri': 'spotify:album:7bXOViTvx6EHXuYFuI2yfj'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63MQldklfxkjYDoUE4Tppz'},
#        'href': 'https://api.spotify.com/v1/artists/63MQldklfxkjYDoUE4Tppz',
#        'id': '63MQldklfxkjYDoUE4Tppz',
#        'name': 'M83',
#        'type': 'artist',
#        'uri': 'spotify:artist:63MQldklfxkjYDoUE4Tppz'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 341200,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAT21401451'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6Prs4p7iVZxODcO62NIiA6'},
#      'href': 'https://api.spotify.com/v1/tracks/6Prs4p7iVZxODcO62NIiA6',
#      'id': '6Prs4p7iVZxODcO62NIiA6',
#      'is_local': False,
#      'name': 'Wait',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 15,
#      'type': 'track',
#      'uri': 'spotify:track:6Prs4p7iVZxODcO62NIiA6'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2017-01-21T18:02:33Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/sandzia4'},
#      'href': 'https://api.spotify.com/v1/users/sandzia4',
#      'id': 'sandzia4',
#      'type': 'user',
#      'uri': 'spotify:user:sandzia4'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#         'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#         'id': '0LyfQWJT6nXafLPZqxe9Of',
#         'name': 'Various Artists',
#         'type': 'artist',
#         'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7xEZ5aXtQaAAzN6uBweaC6'},
#       'href': 'https://api.spotify.com/v1/albums/7xEZ5aXtQaAAzN6uBweaC6',
#       'id': '7xEZ5aXtQaAAzN6uBweaC6',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2738054b1a01bae035d2d5cfa9f',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e028054b1a01bae035d2d5cfa9f',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048518054b1a01bae035d2d5cfa9f',
#         'width': 64}],
#       'name': 'Mandela – Long Walk To Freedom (Original Motion Picture Soundtrack) [UK/International]',
#       'release_date': '2013-01-01',
#       'release_date_precision': 'day',
#       'total_tracks': 17,
#       'type': 'album',
#       'uri': 'spotify:album:7xEZ5aXtQaAAzN6uBweaC6'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/51Blml2LZPmy7TTiAg47vQ'},
#        'href': 'https://api.spotify.com/v1/artists/51Blml2LZPmy7TTiAg47vQ',
#        'id': '51Blml2LZPmy7TTiAg47vQ',
#        'name': 'U2',
#        'type': 'artist',
#        'uri': 'spotify:artist:51Blml2LZPmy7TTiAg47vQ'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 221200,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBUM71307263'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/7kCrYUDtWsPldohOKPTKPL'},
#      'href': 'https://api.spotify.com/v1/tracks/7kCrYUDtWsPldohOKPTKPL',
#      'id': '7kCrYUDtWsPldohOKPTKPL',
#      'is_local': False,
#      'name': 'Ordinary Love',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 17,
#      'type': 'track',
#      'uri': 'spotify:track:7kCrYUDtWsPldohOKPTKPL'},
#     'video_thumbnail': {'url': None}}],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 21}]

# %%
playlist_df = pd.DataFrame(playlist_tracks_data)
playlist_df
# Out:
#                                                 href  \
# 0  https://api.spotify.com/v1/playlists/0qfagBJB5...
#
#                                                items  limit  next  offset  \
# 0  [{'added_at': '2015-12-04T17:25:30Z', 'added_b...    100  None       0
#
#   previous  total
# 0     None     21

# %% [markdown]
# # ================================================

# %% [markdown]
# #### Total track number and name count code

# %%
tracks_count = sp.playlist('3avCwQPH6DkhMTRsizon7N')['tracks']['total']
tracks_count
# Out:
# 200

# %% [markdown]
# Extract info of each track
#
# For testing:  playlist_id = '3avCwQPH6DkhMTRsizon7N'

# %%
playlist_id = '3avCwQPH6DkhMTRsizon7N'
tracks_count = sp.playlist(playlist_id)['tracks']['total']
playlist_name = sp.playlist(playlist_id)['name']
print(playlist_name)
print(tracks_count)
# Out:
# Billboard 200 Top Albums 2021
# 200

# %% [markdown]
# #### Loop testing:

# %%
def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
      
      
      
# empty list, batchsize and the counter for None results
rows = []
batchsize = 100
None_counter = 0

for i in range(0,len(df_tracks['track_id']),batchsize):
    batch = df_tracks['track_id'][i:i+batchsize]
    feature_results = sp.audio_features(batch)
    for i, t in enumerate(feature_results):
        if t == None:
            None_counter = None_counter + 1
        else:
            rows.append(t)
            
print('Number of tracks where no audio features were available:',None_counter)







def show_tracks (results, uriArray):
    for i, item in enumerate(results['items']) :
        track = item['track']
        uriArray-append(track['id'])
                              
def get_playlist_track_id (username, playlist_ id):
    trackId = []
    results = sp.user_playlist(username, playlist_id)
    tracks = results['tracks']
    show_tracks (tracks, trackId)
    while tracks['next']:
            tracks = sp.next (tracks)
            show_tracks (tracks, trackId)
        return trackId

# %% [markdown]
# #### Create dataframe

# %%
df_allartists = pd.DataFrame(tracks_with_allartists)
df_allartists
# Out:
#                                     uri                        name  \
# 0  spotify:track:0e7ipj03S05BNilyu5bRzt  rockstar (feat. 21 Savage)
# 1  spotify:track:1P17dC1amhFzptugyAO7Il    Look What You Made Me Do
# 2  spotify:track:3bsycjdQtbcJeR6822SBvd                   I Like It
# 3  spotify:track:3ee8Jmje8o58CHK66QrVC2                        SAD!
# 4  spotify:track:3GCdLUSnKSMJhs4Tj6CV3s    All The Stars (with SZA)
# 5  spotify:track:0e7ipj03S05BNilyu5bRzt  rockstar (feat. 21 Savage)
# 6  spotify:track:1P17dC1amhFzptugyAO7Il    Look What You Made Me Do
# 7  spotify:track:3bsycjdQtbcJeR6822SBvd                   I Like It
# 8  spotify:track:3ee8Jmje8o58CHK66QrVC2                        SAD!
# 9  spotify:track:3GCdLUSnKSMJhs4Tj6CV3s    All The Stars (with SZA)
#
#                     track_artists  \
# 0        [Post Malone, 21 Savage]
# 1                  [Taylor Swift]
# 2  [Cardi B, Bad Bunny, J Balvin]
# 3                  [XXXTENTACION]
# 4           [Kendrick Lamar, SZA]
# 5        [Post Malone, 21 Savage]
# 6                  [Taylor Swift]
# 7  [Cardi B, Bad Bunny, J Balvin]
# 8                  [XXXTENTACION]
# 9           [Kendrick Lamar, SZA]
#
#                                    track_artists_ids  \
# 0   [246dkjvS1zLTtiykXe5h60, 1URnnhqYAYcrqrcwql10ft]
# 1                           [06HL4z0CvFAxyc27GXpf02]
# 2  [4kYSro6naA4h99UJvo89HB, 4q3ewBCX7sLwd24euuV69...
# 3                           [15UsOTVnJzReFVN1VCnxy4]
# 4   [2YZyLoL8N0Wb9xBt1NhZWg, 7tYKF4w9nC0nq9CsPZTHyP]
# 5   [246dkjvS1zLTtiykXe5h60, 1URnnhqYAYcrqrcwql10ft]
# 6                           [06HL4z0CvFAxyc27GXpf02]
# 7  [4kYSro6naA4h99UJvo89HB, 4q3ewBCX7sLwd24euuV69...
# 8                           [15UsOTVnJzReFVN1VCnxy4]
# 9   [2YZyLoL8N0Wb9xBt1NhZWg, 7tYKF4w9nC0nq9CsPZTHyP]
#
#                                                album          album_artists  \
# 0                               beerbongs & bentleys          [Post Malone]
# 1                                         reputation         [Taylor Swift]
# 2                                Invasion of Privacy              [Cardi B]
# 3                                                  ?         [XXXTENTACION]
# 4  Black Panther The Album Music From And Inspire...  [Kendrick Lamar, SZA]
# 5                               beerbongs & bentleys          [Post Malone]
# 6                                         reputation         [Taylor Swift]
# 7                                Invasion of Privacy              [Cardi B]
# 8                                                  ?         [XXXTENTACION]
# 9  Black Panther The Album Music From And Inspire...  [Kendrick Lamar, SZA]
#
#   release_date  explicit  duration_in_mins  acousticness  ...  liveness  \
# 0   2018-04-27      True              3.64        0.1240  ...    0.1310
# 1   2017-11-10     False              3.53        0.2040  ...    0.1260
# 2   2018-04-05     False              4.22        0.0981  ...    0.3780
# 3   2018-03-16      True              2.78        0.2580  ...    0.1230
# 4   2018-02-09      True              3.87        0.0605  ...    0.0926
# 5   2018-04-27      True              3.64        0.1240  ...    0.1310
# 6   2017-11-10     False              3.53        0.2040  ...    0.1260
# 7   2018-04-05     False              4.22        0.0981  ...    0.3780
# 8   2018-03-16      True              2.78        0.2580  ...    0.1230
# 9   2018-02-09      True              3.87        0.0605  ...    0.0926
#
#    loudness  speechiness    tempo  time_signature  track_duration_in_seconds  \
# 0    -6.136       0.0712  159.801               4                  218.14667
# 1    -6.471       0.1230  128.070               4                  211.85333
# 2    -4.026       0.1360  136.050               4                  253.39029
# 3    -4.880       0.1450   75.023               4                  166.60553
# 4    -4.946       0.0597   96.924               4                  232.18668
# 5    -6.136       0.0712  159.801               4                  218.14667
# 6    -6.471       0.1230  128.070               4                  211.85333
# 7    -4.026       0.1360  136.050               4                  253.39029
# 8    -4.880       0.1450   75.023               4                  166.60553
# 9    -4.946       0.0597   96.924               4                  232.18668
#
#    end_of_fade_in  start_of_fade_out  key  mode
# 0         0.00000          215.41151    5     0
# 1         0.34884          209.84454    9     0
# 2         0.15116          241.78938    5     0
# 3         0.00000          155.38794    8     1
# 4         0.00000          227.49170    8     1
# 5         0.00000          215.41151    5     0
# 6         0.34884          209.84454    9     0
# 7         0.15116          241.78938    5     0
# 8         0.00000          155.38794    8     1
# 9         0.00000          227.49170    8     1
#
# [10 rows x 23 columns]
