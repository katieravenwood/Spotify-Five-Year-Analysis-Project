# %% [markdown]
# # Spotify Five Year Analysis Project: Master Chart Table Creation Notebook

# %% [markdown]
# ## Imports and Setup

# %% [markdown]
# ### Imports

# %%
import json
import time
from tqdm import tqdm
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import creds

# %% [markdown]
# ### Set display options

# %%
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ### Spotify Credentials
#
# #### Load credentials

# %% [markdown]
# Loads the creds.py file, containing the following two lines for variables client_id and secret, which is gitignored for sharing.
#
# client_id = 'Your Client ID Here'<br />
# secret = 'Your secret here'

# %%
# %run -i 'creds.py'

# %% [markdown]
# #### Set credentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ## Functions for data extraction

# %% [markdown]
# ### Supporting function definitions

# %% [markdown]
# #### Album artists names function

# %%
def get_all_album_artists_names(track_id):
    '''Return a list of all album artists for the given track'''
    meta = sp.track(track_id)
    album_artist_list = []
    for item in (meta['album']['artists']):
        album_artist = item['name']
        album_artist_list.append(album_artist)
    return album_artist_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_names('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['Future', 'Juice WRLD']

# %% [markdown]
# #### Album artists ids function

# %%
def get_all_album_artists_ids(track_id):
    '''Return a list of all album artsts ids for a given track'''
    meta = sp.track(track_id)
    album_artist_id_list = []
    for item in (meta['album']['artists']):
        album_artist_id = item['id']
        album_artist_id_list.append(album_artist_id)
    return album_artist_id_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_ids('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['1RyvyyTE3xzB2ZywiAwp0i', '4MCBfE4596Uoi2O4DtmEMz']

# %% [markdown]
# #### Album artists genres function

# %%
def get_all_album_artists_genres(track_id):
    meta = sp.track(track_id)
    album_artist_genre_list = []
    for item in (meta['album']['artists']):
        album_artist_id = item['id']
        album_artist_genres = sp.artist(album_artist_id)['genres']
        album_artist_genre_list.append(album_artist_genres)
    return album_artist_genre_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_genres('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [['atl hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['chicago rap', 'melodic rap']]

# %% [markdown]
# #### Album artists popularity function

# %%
def get_all_album_artists_popularity(track_id):
    meta = sp.track(track_id)
    album_artist_popularity_list = []
    for item in (meta['album']['artists']):
        album_artist_id = item['id']
        album_artist_popularity = sp.artist(album_artist_id)['popularity']
        album_artist_popularity_list.append(album_artist_popularity)
    return album_artist_popularity_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_popularity('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [91, 96]

# %% [markdown]
# #### Album artists followers function

# %%
def get_all_album_artists_followers(track_id):
    meta = sp.track(track_id)
    album_artist_followers_list = []
    for item in (meta['album']['artists']):
        album_artist_id = item['id']
        album_artist_followers = sp.artist(album_artist_id)['followers']['total']
        album_artist_followers_list.append(album_artist_followers)
    return album_artist_followers_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_followers('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [11044152, 21889473]

# %% [markdown]
# #### Track artists names function

# %%
def get_all_track_artists_names(track_id):
    meta = sp.track(track_id)
    track_artist_list = []
    for item in (meta['artists']):
        track_artist = item['name']
        track_artist_list.append(track_artist)
    return track_artist_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_names('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['Future', 'Juice WRLD', 'Young Thug']

# %% [markdown]
# #### Track artists ids function

# %%
def get_all_track_artists_ids(track_id):
    meta = sp.track(track_id)
    track_artist_id_list = []
    for item in (meta['artists']):
        track_artist = item['id']
        track_artist_id_list.append(track_artist)
    return track_artist_id_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_ids('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['1RyvyyTE3xzB2ZywiAwp0i', '4MCBfE4596Uoi2O4DtmEMz', '50co4Is1HCEo8bhOyUWKpn']

# %% [markdown]
# #### Track artists genres function

# %%
def get_all_track_artists_genres(track_id):
    meta = sp.track(track_id)
    track_artist_genre_list = []
    for item in (meta['artists']):
        track_artist_id = item['id']
        track_artist_genres = sp.artist(track_artist_id)['genres']
        track_artist_genre_list.append(track_artist_genres)
    return track_artist_genre_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_genres('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [['atl hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['chicago rap', 'melodic rap'],
#  ['atl hip hop',
#   'atl trap',
#   'gangster rap',
#   'hip hop',
#   'melodic rap',
#   'rap',
#   'trap']]

# %% [markdown]
# #### Track artists popularity function

# %%
def get_all_track_artists_popularity(track_id):
    meta = sp.track(track_id)
    track_artist_popularity_list = []
    for item in (meta['artists']):
        track_artist_id = item['id']
        track_artist_popularity = sp.artist(track_artist_id)['popularity']
        track_artist_popularity_list.append(track_artist_popularity)
    return track_artist_popularity_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_popularity('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [91, 96, 90]

# %% [markdown]
# #### Track artists followers function

# %%
def get_all_track_artists_followers(track_id):
    meta = sp.track(track_id)
    track_artist_followers_list = []
    for item in (meta['artists']):
        track_artist_id = item['id']
        track_artist_followers = sp.artist(track_artist_id)['followers']['total']
        track_artist_followers_list.append(track_artist_followers)
    return track_artist_followers_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_followers('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [11044152, 21889473, 6891556]

# %% [markdown]
# ### Playlist data return function

# %%
def get_playlist_tracks_more_than_100_songs(username, playlist_id):
    results = sp.user_playlist_tracks(username, playlist_id)
    playlist_name = sp.playlist(playlist_id)['name']
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    results = tracks    
    
    pl_id = []
    pl_name = []
    chart_position = []
    album_name = []
    album_id = []
    album_release_date = []
    album_artists = []
    album_artists_ids = []
    album_artists_genres = []
    album_artists_popularity = []
    album_artists_followers = []
    track_name = []
    track_id = []
    track_popularity = []
    track_explicit = []
    track_artists = []
    track_artists_ids = []
    track_artists_genres = []
    track_artists_popularity = []
    track_artists_followers = []

    for i in tqdm(range(len(results))):
        if i == 0:
            pl_id = playlist_id
            pl_name = playlist_name
            chart_position = i + 1
            album_name = results[i]['track']['album']['name']
            album_id = results[i]['track']['album']['id']
            album_release_date = results[i]['track']['album']['release_date']
            album_artists = get_all_album_artists_names(results[i]['track']['id'])
            album_artists_ids = get_all_album_artists_ids(results[i]['track']['id'])
            album_artists_genres = get_all_album_artists_genres(results[i]['track']['id'])
            album_artists_popularity = get_all_album_artists_popularity(results[i]['track']['id'])
            album_artists_followers = get_all_album_artists_followers(results[i]['track']['id'])
            track_name = results[i]['track']['name']
            track_id = results[i]['track']['id']
            track_popularity = results[i]['track']['popularity']
            track_explicit = results[i]['track']['explicit']
            track_artists = get_all_track_artists_names(results[i]['track']['id'])
            track_artists_ids = get_all_album_artists_ids(results[i]['track']['id'])
            track_artists_genres = get_all_album_artists_genres(results[i]['track']['id'])
            track_artists_popularity = get_all_album_artists_popularity(results[i]['track']['id'])
            track_artists_followers = get_all_album_artists_followers(results[i]['track']['id'])
            features = sp.audio_features(track_id)
            features_df = pd.DataFrame(data=features, columns=features[0].keys())
            features_df['playlist_id'] = [pl_id]
            features_df['playlist_name'] = [pl_name]
            features_df['position'] = [chart_position]
            features_df['album_name'] = [album_name]
            features_df['album_id'] = [album_id]
            features_df['album_release_date'] = [album_release_date]
            features_df['album_artists'] = album_artists
            features_df['album_artists_ids'] = [album_artists_ids]
            features_df['album_artists_genres'] = [album_artists_genres]
            features_df['album_artists_popularity'] = [album_artists_popularity]
            features_df['album_artists_followers'] = [album_artists_followers]
            features_df['track_name'] = [track_name]
            features_df['track_id'] = [track_id]
            features_df['track_popularity'] = [track_popularity]
            features_df['track_explicit'] = [track_explicit]
            features_df['track_artists'] = [track_artists]
            features_df['track_artists_ids'] = [track_artists_ids]
            features_df['track_artists_genres'] = [track_artists_genres]
            features_df['track_artists_popularity'] = [track_artists_popularity]
            features_df['track_artists_followers'] = [track_artists_followers]           
            features_df = features_df[['playlist_id', 'playlist_name', 'position', 
                                       'album_name', 'album_id', 'album_release_date', 'album_artists', 'album_artists_ids',
                                       'album_artists_genres', 'album_artists_popularity', 'album_artists_followers',
                                       'track_name', 'track_id', 'track_popularity', 'track_artists', 
                                       'track_artists_ids', 'track_artists_genres', 'track_artists_popularity', 
                                       'track_explicit', 'track_artists_followers', 'danceability', 'energy', 
                                       'key', 'speechiness', 'loudness', 'mode', 'acousticness', 'instrumentalness',
                                       'liveness', 'valence', 'tempo',
                                       'duration_ms', 'time_signature']]
            continue
        else:
            try:
                pl_id = playlist_id
                pl_name = playlist_name
                chart_position = (i + 1)
                album_name = results[i]['track']['album']['name']
                album_id = results[i]['track']['album']['id']
                album_release_date = results[i]['track']['album']['release_date']
                album_artists = get_all_album_artists_names(results[i]['track']['id'])
                album_artists_ids = get_all_album_artists_ids(results[i]['track']['id'])
                album_artists_genres = get_all_album_artists_genres(results[i]['track']['id'])
                album_artists_popularity = get_all_album_artists_popularity(results[i]['track']['id'])
                album_artists_followers = get_all_album_artists_followers(results[i]['track']['id'])
                track_name = results[i]['track']['name']
                track_id = results[i]['track']['id']
                track_popularity = results[i]['track']['popularity']
                track_artists = get_all_track_artists_names(results[i]['track']['id'])
                track_artists_ids = get_all_album_artists_ids(results[i]['track']['id'])
                track_artists_genres = get_all_album_artists_genres(results[i]['track']['id'])
                track_artists_popularity = get_all_album_artists_popularity(results[i]['track']['id'])
                track_explicit = results[i]['track']['explicit']
                track_artists_followers = get_all_album_artists_followers(results[i]['track']['id'])
                features = sp.audio_features(track_id)
                new_row = {'playlist_id':[pl_id],
                    'playlist_name': [pl_name],
                    'position': [chart_position],
                    'album_name': [album_name],
                    'album_id': [album_id],
                    'album_release_date': [album_release_date],
                    'album_artists': [album_artists],
                    'album_artists_ids': [album_artists_ids],
                    'album_artists_genres': [album_artists_genres],
                    'album_artists_popularity': [album_artists_popularity],
                    'album_artists_followers': [album_artists_followers],
                    'track_name': [track_name],
                    'track_id': [track_id],
                    'track_popularity': [track_popularity],
                    'track_artists': [track_artists],
                    'track_artists_ids': [track_artists_ids],
                    'track_artists_genres': [track_artists_genres],
                    'track_artists_popularity': [track_artists_popularity],
                    'track_explicit': [track_explicit],
                    'track_artists_followers': [track_artists_followers],
                    'danceability':[features[0]['danceability']],
                    'energy':[features[0]['energy']],
                    'key':[features[0]['key']],
                    'speechiness':[features[0]['speechiness']],
                    'loudness':[features[0]['loudness']],
                    'mode':[features[0]['mode']],
                    'acousticness':[features[0]['acousticness']],
                    'instrumentalness':[features[0]['instrumentalness']],
                    'liveness':[features[0]['liveness']],
                    'valence':[features[0]['valence']],
                    'tempo':[features[0]['tempo']],
                    'duration_ms':[features[0]['duration_ms']],
                    'time_signature':[features[0]['time_signature']]
                }

                dfs = [features_df, pd.DataFrame(new_row)]
                features_df = pd.concat(dfs, ignore_index = True)
            except:
                continue
                
    return features_df

# %% [markdown]
# ## Dataset creation

# %% [markdown]
# ### Billboard 2021 Top Albums chart table

# %% [markdown]
# #### Pull chart data from Spotify

# %%
chart2021 = get_playlist_tracks_more_than_100_songs('katiekellert', '3avCwQPH6DkhMTRsizon7N')
# Out:
# 100%|██████████| 200/200 [05:40<00:00,  1.70s/it]

# %% [markdown]
# #### View the dataset

# %%
chart2021
# Out:
#                 playlist_id                  playlist_name  position  \
# 0    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         1
# 1    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         2
# 2    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         3
# 3    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         4
# 4    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         5
# ..                      ...                            ...       ...
# 195  3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021       196
# 196  3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021       197
# 197  3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021       198
# 198  3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021       199
# 199  3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021       200
#
#                                album_name                album_id  \
# 0             Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz
# 1                                    SOUR  6s84u2TUpR3wdUv4NgKA2j
# 2    Shoot For The Stars Aim For The Moon  7e7t0MCrNDcJZsPwUKjmOc
# 3                                evermore  2Xoteh7uEpea4TohMxjtaq
# 4                     Certified Lover Boy  3SpBlxme9WbeQdI9kx7KAV
# ..                                    ...                     ...
# 195                         Hybrid Theory  2pKw6GERJVAD61449B1EEM
# 196             The Chaos Chapter: FREEZE  5Zdr9vactwnJH4Vpe9Mid9
# 197                                    21  0Lg1uZvI312TPqxNWShFXL
# 198                          OK ORCHESTRA  1y2AzG31F4CuCKQ1rpIzaI
# 199                             THE ALBUM  71O60S5gIJSIAhdnrDIh3N
#
#     album_release_date          album_artists         album_artists_ids  \
# 0           2021-01-08          Morgan Wallen  [4oUHIQIBe0LHzYfvXNW4QM]
# 1           2021-05-21       [Olivia Rodrigo]  [1McMsnEElThX1knmY4oliG]
# 2           2020-07-03            [Pop Smoke]  [0eDvMgVFoNV3TpwtrVCoTj]
# 3           2020-12-11         [Taylor Swift]  [06HL4z0CvFAxyc27GXpf02]
# 4           2021-09-03                [Drake]  [3TVXtAsR1Inumwj472S9r4]
# ..                 ...                    ...                       ...
# 195         2000-10-24          [Linkin Park]  [6XyY86QOPPrYVGvF9ch6wz]
# 196         2021-05-31  [TOMORROW X TOGETHER]  [0ghlgldX5Dd6720Q3qFyQB]
# 197         2011-01-24                [Adele]  [4dpARuHxo51G3z768sgnrY]
# 199                        [[k-pop, k-pop girl group]]
#
#     track_artists_popularity  track_explicit track_artists_followers  \
# 0                       [86]           False               [2789002]
# 1                       [91]            True              [12849364]
# 2                       [89]            True               [8935893]
# 3                       [98]           False              [48097228]
# 4                       [98]            True              [60310746]
# ..                       ...             ...                     ...
# 195                     [86]           False              [20940412]
# 196                     [80]           False               [5419284]
# 197                     [94]           False              [33155274]
# 198                     [78]           False               [2091110]
# 199                     [84]           False              [27659380]
#
#      danceability  energy  key  speechiness  loudness  mode  acousticness  \
# 0           0.621   0.868    6       0.0460    -5.478     1      0.617000
# 1           0.561   0.431   10       0.0578    -8.810     1      0.768000
# 2           0.709   0.548   10       0.3530    -8.493     1      0.650000
# 3           0.392   0.574    7       0.1700    -9.195     1      0.833000
# 4           0.803   0.597   11       0.1410    -6.035     0      0.000619
# ..            ...     ...  ...          ...       ...   ...           ...
# 195         0.555   0.844    3       0.0554    -6.567     0      0.008340
# 196         0.584   0.836    0       0.0790    -4.925     1      0.055800
# 197         0.556   0.319    9       0.0281    -8.251     1      0.893000
# 198         0.740   0.517    1       0.0506    -6.233     0      0.018300
# 199         0.812   0.761   11       0.0812    -5.222     1      0.046500
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0            0.000000    0.1310    0.594  126.010       216573               4
# 1            0.000014    0.1060    0.137  143.875       242013               4
# 2            0.000002    0.1330    0.543   83.995       160000               4
# 3            0.001790    0.1450    0.529   81.112       214707               4
# 4            0.000005    0.3230    0.331  136.008       257605               4
# ..                ...       ...      ...      ...          ...             ...
# 195          0.000000    0.0895    0.464  105.195       216800               4
# 196          0.000000    0.0663    0.484  104.973       202204               4
# 197          0.000000    0.0996    0.294  135.187       285240               4
# 198          0.000000    0.0558    0.698  139.917       170858               4
# 199          0.000135    0.0601    0.344  130.032       182956               4
#
# [200 rows x 33 columns]

# %% [markdown]
# #### Export dataset to csv

# %%
chart2021.to_csv('../data/chart2021.csv', index=False)

# %% [markdown]
# ### Billboard 2020 Top Albums chart table

# %% [markdown]
# #### Pull chart data from Spotify

# %%
chart2020 = get_playlist_tracks_more_than_100_songs('katiekellert', '1EEazdcjH0keT4sttGvH8c')
# Out:
# 100%|██████████| 200/200 [05:40<00:00,  1.70s/it]

# %% [markdown]
# #### View the dataset

# %%
chart2020
# Out:
#                 playlist_id                  playlist_name  position  \
# 0    1EEazdcjH0keT4sttGvH8c  Billboard 200 Top Albums 2020         1
# 1    1EEazdcjH0keT4sttGvH8c  Billboard 200 Top Albums 2020         2
# 2    1EEazdcjH0keT4sttGvH8c  Billboard 200 Top Albums 2020         3
# 3    1EEazdcjH0keT4sttGvH8c  Billboard 200 Top Albums 2020         4
# 4    1EEazdcjH0keT4sttGvH8c  Billboard 200 Top Albums 2020         5
# ..                      ...                            ...       ...
# 195  1EEazdcjH0keT4sttGvH8c  Billboard 200 Top Albums 2020       196
# 196  1EEazdcjH0keT4sttGvH8c  Billboard 200 Top Albums 2020       197
# 197  1EEazdcjH0keT4sttGvH8c  Billboard 200 Top Albums 2020       198
#
#                    track_id  track_popularity  \
# 0    0RiRZpuVRbi7oqRdSMwhQY                82
# 1    02RCbjb9czvQKNGBmEmWob                68
# 2    0nbXyq5TXYPCO7pr3N8S4I                85
# 3    6UelLqGlWMcVH1E5c4H7lY                90
# 4    4LEK9rD7TWIG4FCL1s27XC                53
# ..                      ...               ...
# 195  0kPeZAyIhIfeZNrtfjJGDB                72
# 196  2QpGZOhTCHHiKmpSO9FW4h                75
# 197  23GDQ3aN1e6SJkbjw13K8P                51
# 198  3k4QmEFuzlnhgxT3qstcir                49
# 199  1ayaOin9hxCtyhg4UsBTpg                67
#
#                                   track_artists         track_artists_ids  \
# 0                       [Post Malone, Swae Lee]  [246dkjvS1zLTtiykXe5h60]
# 1                                    [Lil Baby]  [5f7VJjfbwm532GiveGC0ZK]
# 2                                 [Roddy Ricch]  [757aE44tKEUQEqRuT6GnEB]
# 3                                [Harry Styles]  [6KImCVD70vtIoJWnq6nGn3]
# 4                                [Taylor Swift]  [06HL4z0CvFAxyc27GXpf02]
# ..                                          ...                       ...
# 195                           [Miranda Lambert]  [66lH4jAE7pqPlOlzUKbwA0]
# 196                                [Kanye West]  [5K4W6rqBFWDnAN6FQUkS6x]
# 197                       [Vince Guaraldi Trio]  [4ytkhMSAnrDP8XzRNlw9FS]
# 198  [Post Malone, Ozzy Osbourne, Travis Scott]  [6ZLTlhejhndI4Rh53vYhrY]
# 199                                   [NCT 127]  [7f4ignuCJhLXfZ9giKT7rH]
#
#                                   track_artists_genres  \
# 0                        [[dfw rap, melodic rap, rap]]
# 1                 [[atl hip hop, atl trap, rap, trap]]
# 2                           [[melodic rap, rap, trap]]
# 3                                              [[pop]]
# 4                                              [[pop]]
# ..                                                 ...
# 195  [[contemporary country, country, country dawn,...
# 196                               [[chicago rap, rap]]
# 197                     [[adult standards, jazz trio]]
# 198  [[album rock, birmingham metal, hard rock, met...
# 199                         [[k-pop, k-pop boy group]]
#
#     track_artists_popularity  track_explicit track_artists_followers  \
# 0                       [92]           False              [35612420]
# 1                       [92]            True               [9328587]
# 2                       [87]            True               [7408901]
# 3                       [87]           False              [18602679]
# 4                       [98]           False              [48097228]
# ..                       ...             ...                     ...
# 195                     [74]           False               [3010409]
# 196                     [94]           False              [16173510]
# 197                     [74]           False                [108724]
# 198                     [74]           False               [3989377]
# 199                     [76]           False               [4961899]
#
#      danceability  energy  key  speechiness  loudness  mode  acousticness  \
# 0           0.755  0.5220    2       0.0575    -4.368     1      0.533000
# 1           0.883  0.5990   11       0.2480    -5.551     1      0.017700
# 2           0.896  0.5860   10       0.0559    -6.687     0      0.104000
# 3           0.548  0.8160    0       0.0465    -4.209     1      0.122000
# 4           0.613  0.5810    0       0.0424    -8.588     0      0.537000
# ..            ...     ...  ...          ...       ...   ...           ...
# 195         0.661  0.6330    7       0.0348    -5.986     1      0.038000
# 196         0.529  0.9000    1       0.4180    -3.503     1      0.000248
# 197         0.356  0.0955    5       0.0344   -23.171     1      0.985000
# 198         0.495  0.8090    1       0.0533    -2.653     0      0.101000
# 199         0.681  0.8470    7       0.0869    -2.462     1      0.030600
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0            0.000000    0.0685    0.925   89.960       157560               4
# 1            0.000000    0.1790    0.413  142.976       183011               4
# 2            0.000000    0.7900    0.642  116.971       196653               4
# 3            0.000000    0.3350    0.557   95.390       174000               4
# 4            0.000345    0.2500    0.551  130.033       239560               4
# ..                ...       ...      ...      ...          ...             ...
# 195          0.000003    0.1240    0.613   81.984       209760               4
# 196          0.000012    0.0426    0.434  180.291       104591               4
# 197          0.000031    0.1990    0.104   76.140       163773               3
# 198          0.000000    0.1380    0.227  139.885       229580               4
# 199          0.000000    0.0808    0.507  167.031       233013               4
#
# [200 rows x 33 columns]

# %% [markdown]
# #### Export dataset to csv

# %%
chart2020.to_csv('../data/chart2020.csv', index=False)

# %% [markdown]
# ### Billboard 2019 Top Albums chart table

# %% [markdown]
# #### Pull chart data from Spotify

# %%
chart2019 = get_playlist_tracks_more_than_100_songs('katiekellert', '0n3V7u9sMRV7sCDMhWxDtL')
# Out:
# 100%|██████████| 200/200 [05:45<00:00,  1.73s/it]

# %% [markdown]
# #### View the dataset

# %%
chart2019
# Out:
#                 playlist_id                  playlist_name  position  \
# 0    0n3V7u9sMRV7sCDMhWxDtL  Billboard 200 Top Albums 2019         1
# 1    0n3V7u9sMRV7sCDMhWxDtL  Billboard 200 Top Albums 2019         2
# 2    0n3V7u9sMRV7sCDMhWxDtL  Billboard 200 Top Albums 2019         3
# 3    0n3V7u9sMRV7sCDMhWxDtL  Billboard 200 Top Albums 2019         4
# 4    0n3V7u9sMRV7sCDMhWxDtL  Billboard 200 Top Albums 2019         5
# ..                      ...                            ...       ...
# 195  0n3V7u9sMRV7sCDMhWxDtL  Billboard 200 Top Albums 2019       196
# 196  0n3V7u9sMRV7sCDMhWxDtL  Billboard 200 Top Albums 2019       197
# 197  0n3V7u9sMRV7sCDMhWxDtL  Billboard 200 Top Albums 2019       198
# 198  0n3V7u9sMRV7sCDMhWxDtL  Billboard 200 Top Albums 2019       199
# 199  0n3V7u9sMRV7sCDMhWxDtL  Billboard 200 Top Albums 2019       200
#
#                                    album_name                album_id  \
# 0    WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?  0S0KGZnfBGSIssfF54WSJh
# 1                               thank u, next  2fYhqwDWXjbpjaIJPEfKFw
# 2                   A Star Is Born Soundtrack  4sLtOBOzn4s3GDUv3c5oJD
# 3                                       Lover  1NAmidJlEaVgA3MpcPFYGq
# 4                        beerbongs & bentleys  6trNtQUgC8cgbWcqoMYkOR
# ..                                        ...                     ...
# 195                                  Freudian  3xybjP7r2VsWzwvDQipdM0
# 196                       Life of a Dark Rose  0CuYNS755Ow710G2E7aLDE
# 197                    All Time Greatest Hits  7CocMpFkEjPUMkWyPH3s0v
# 198                     Signed to the Streets  0u2zCSmrCPlRZXgXM8wagz
# 199                       Father of the Bride  5WWu3iYAXLgqghjU9696Nk
#
#     album_release_date                album_artists  \
# 0           2019-03-29                Billie Eilish
# 1           2019-02-08              [Ariana Grande]
# 2           2018-10-05  [Lady Gaga, Bradley Cooper]
# 196                72                           [Lil Skies, Landon Cube]
# 197                30                                   [Lynyrd Skynyrd]
# 198                42                                         [Lil Durk]
# 199                49                                  [Vampire Weekend]
#
#                                     track_artists_ids  \
# 0                            [6qqNVTkY8uBg9cP3Jd7DAH]
# 1                            [66CXWjxzNUsdJxJ2JdwvnR]
# 2    [1HY2Jd0NmPuamShAr6KMms, 4VIvfOurcf0vuLRxLkGnIG]
# 3                            [06HL4z0CvFAxyc27GXpf02]
# 4                            [246dkjvS1zLTtiykXe5h60]
# ..                                                ...
# 195                          [20wkVLutqVOYrc0kxFs7rA]
# 196                          [7d3WFRME3vBY2cgoP38RDo]
# 197                          [4MVyzYMgTwdP7Z49wAZHx0]
# 198                          [3hcs9uc56yIGFCSy9leWe7]
# 199                          [5BvJzeQpmsdsFp4HGUYUEx]
#
#                                   track_artists_genres  \
# 0                         [[art pop, electropop, pop]]
# 1                                   [[dance pop, pop]]
# 2             [[art pop, dance pop, pop], [hollywood]]
# 3                                              [[pop]]
# 4                        [[dfw rap, melodic rap, rap]]
# ..                                                 ...
# 195            [[canadian contemporary r&b, pop, r&b]]
# 196                         [[melodic rap, rap, trap]]
# 197  [[album rock, blues rock, classic rock, countr...
# 198  [[chicago drill, chicago rap, drill, hip hop, ...
# 199           [[baroque pop, indie rock, modern rock]]
#
#     track_artists_popularity  track_explicit track_artists_followers  \
# 0                       [93]           False              [55712878]
# 1                       [94]            True              [74818140]
# 2                   [87, 74]           False      [20766418, 193995]
# 3                       [98]           False              [48097228]
# 4                       [92]            True              [35612420]
# ..                       ...             ...                     ...
# 195                     [82]           False               [3063665]
# 196                     [77]            True               [4771056]
# 197                     [74]            True               [3831608]
# 198                     [88]            True               [3489469]
# 199                     [70]           False               [1771812]
#
#      danceability  energy  key  speechiness  loudness  mode  acousticness  \
# 0           0.367   0.111    4       0.0972   -14.084     1         0.978
# 1           0.778   0.317    1       0.3340   -10.732     0         0.592
# 2           0.572   0.385    7       0.0308    -6.362     1         0.371
# 3           0.610   0.830    0       0.0571    -4.105     1         0.033
# 4           0.585   0.520    5       0.0712    -6.136     0         0.124
# ..            ...     ...  ...          ...       ...   ...           ...
# 195         0.524   0.364    7       0.0367   -10.209     1         0.808
# 196         0.745   0.646    6       0.1700    -6.987     0         0.157
# 197         0.606   0.662    7       0.0242   -10.443     1         0.210
# 198         0.751   0.490    7       0.0448    -8.838     0         0.113
# 199         0.652   0.760   11       0.0476    -6.075     1         0.476
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0            0.000040    0.0897    0.198   82.642       196077               4
# 1            0.000000    0.0881    0.327  140.048       178627               4
# 2            0.000000    0.2310    0.323   95.799       215733               4
# 3            0.000000    0.1180    0.728  182.162       193000               4
# 4            0.000070    0.1310    0.129  159.801       218147               4
# ..                ...       ...      ...      ...          ...             ...
# 195          0.000000    0.1000    0.436   75.240       209831               4
# 196          0.000000    0.3380    0.460   79.993       203908               4
# 197          0.000301    0.3230    0.889   97.828       283333               4
# 198          0.000000    0.5410    0.394  127.968       184398               4
# 199          0.000128    0.0999    0.599   98.007       308413               4
#
# [200 rows x 33 columns]

# %% [markdown]
# #### Export dataset to csv

# %%
chart2019.to_csv('../data/chart2019.csv', index=False)

# %% [markdown]
# ### Billboard 2018 Top Albums chart table

# %% [markdown]
# #### Pull chart data from Spotify

# %%
chart2018 = get_playlist_tracks_more_than_100_songs('katiekellert', '34KSLHLGSNqeK6UfxKnLuM')
# Out:
# 100%|██████████| 200/200 [05:41<00:00,  1.71s/it]

# %% [markdown]
# #### View the dataset

# %%
chart2018
# Out:
#                 playlist_id                  playlist_name  position  \
# 0    34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018         1
# 1    34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018         2
# 2    34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018         3
# 3    34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018         4
# 4    34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018         5
# ..                      ...                            ...       ...
# 195  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       196
# 196  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       197
# 197  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       198
# 198  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       199
# 199  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       200
#
#                                             album_name  \
# 0                                           reputation
# 1                                             Scorpion
# 2                                 beerbongs & bentleys
# 3    The Greatest Showman (Original Motion Picture ...
# 4                                           ÷ (Deluxe)
# ..                                                 ...
# 195                                            Revenge
# 196            That's Christmas To Me (Deluxe Edition)
# 197                                              MANIA
# 198                            Live in No Shoes Nation
# 199                                 MEMORIES DON'T DIE
#
#                    album_id album_release_date      album_artists  \
# 0    6DEjYFkNZh67HP7R9PSZvv         2017-11-10       Taylor Swift
# 1    1ATL5GLyefJaxhQzSPVrLX         2018-06-29            [Drake]
# 2    6trNtQUgC8cgbWcqoMYkOR         2018-04-27      [Post Malone]
# 3    7ayBZIe1FHkNv0T5xFCX6F         2017-12-08  [Various Artists]
# 4    3T4tUhGYeRNVUGevb0wThu         2017-03-03       [Ed Sheeran]
# ..                      ...                ...                ...
# 195  3vpXJ54S3MXLyzysw8qq7c         2017-05-16     [XXXTENTACION]
# 196  082VlX7cBth0o8xqDGclNn         2015-10-30       [Pentatonix]
# 197  16xtTZvPH6PXcwSqYqJHHG         2018-01-19     [Fall Out Boy]
# 198  2njb3cHa1yhUMdu8PT2VhY         2017-10-27    [Kenny Chesney]
# 199  4RQIHpmmapmEpOFNi2GvAB         2018-03-02       [Tory Lanez]
#
#             album_artists_ids  \
# 0    [06HL4z0CvFAxyc27GXpf02]
# 1    [3TVXtAsR1Inumwj472S9r4]
# 2    [246dkjvS1zLTtiykXe5h60]
# 3    [0LyfQWJT6nXafLPZqxe9Of]
# 4    [6eUKZXaKkcviH0Ku9w2n3V]
# ..                        ...
# 195  [15UsOTVnJzReFVN1VCnxy4]
# 197                         [[emo, modern rock, rock]]
# 198    [[contemporary country, country, country road]]
# 199  [[canadian hip hop, canadian trap, melodic rap...
#
#     track_artists_popularity  track_explicit track_artists_followers  \
# 0                       [98]           False              [48097228]
# 1                       [98]            True              [60310746]
# 2                       [92]            True              [35612420]
# 3                        [0]           False               [1447145]
# 4                       [96]           False              [91177982]
# ..                       ...             ...                     ...
# 195                     [91]            True              [33973036]
# 196                     [81]           False               [3203902]
# 197                     [81]           False               [9259614]
# 198                     [74]           False               [3737536]
# 199                     [84]            True               [4166369]
#
#      danceability  energy  key  speechiness  loudness  mode  acousticness  \
# 0           0.766   0.709    9       0.1230    -6.471     0       0.20400
# 1           0.754   0.449    7       0.1090    -9.211     1       0.03320
# 2           0.585   0.520    5       0.0712    -6.136     0       0.12400
# 3           0.284   0.704    2       0.1860    -7.276     1       0.00583
# 4           0.825   0.652    1       0.0802    -3.183     0       0.58100
# ..            ...     ...  ...          ...       ...   ...           ...
# 195         0.763   0.726    1       0.2820    -6.405     1       0.25900
# 196         0.497   0.312   11       0.0269    -9.088     0       0.30200
# 197         0.579   0.872    8       0.0443    -5.294     1       0.00594
# 198         0.371   0.988    9       0.1210    -4.790     1       0.01080
# 199         0.639   0.547    7       0.0434    -6.237     0       0.11500
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0            0.000014    0.1260    0.506  128.070       211853               4
# 1            0.000083    0.5520    0.357   77.169       198973               4
# 2            0.000070    0.1310    0.129  159.801       218147               4
# 3            0.000115    0.0424    0.100  191.702       234707               4
# 4            0.000000    0.0931    0.931   95.977       233713               4
# ..                ...       ...      ...      ...          ...             ...
# 195          0.000000    0.0976    0.349  139.059       126346               4
# 196          0.000000    0.0968    0.177  105.036       203373               4
# 197          0.000000    0.1920    0.557  115.043       230400               4
# 198          0.000155    0.9590    0.263  168.035       268093               4
# 199          0.000000    0.3730    0.117  129.939       208173               4
#
# [200 rows x 33 columns]

# %% [markdown]
# #### Drop rows containing placeholders for albums not available on Spotify (Garth Brooks at number 138 )

# %% [markdown]
# View projected rows for drop

# %%
chart2018.iloc[137]
# Out:
# playlist_id                                            34KSLHLGSNqeK6UfxKnLuM
# playlist_name                                   Billboard 200 Top Albums 2018
# position                                                                  138
# album_name                                               Classic Chris Ledoux
# album_id                                               5RfSNpDNdWLrtMs8R23gJf
# album_release_date                                                 2008-01-01
# album_artists                                                  [Chris LeDoux]
# album_artists_ids                                    [4K3DSWzghkGUcQOEZG9gpo]
# album_artists_genres        [[country, country road, country rock, wyoming...
# album_artists_popularity                                                 [57]
# album_artists_followers                                              [387244]
# track_name                                     Whatcha Gonna Do With A Cowboy
# track_id                                               0AHqnfCap92geH5BAB0lJ3
# track_popularity                                                           38
# track_artists                                    [Chris LeDoux, Garth Brooks]
# track_artists_ids                                    [4K3DSWzghkGUcQOEZG9gpo]
# track_artists_genres        [[country, country road, country rock, wyoming...
# track_artists_popularity                                                 [57]
# track_explicit                                                          False
# track_artists_followers                                              [387244]
# danceability                                                            0.723
# energy                                                                  0.811
# key                                                                         9
# speechiness                                                             0.108
# loudness                                                               -4.147
# mode                                                                        1
# acousticness                                                            0.342
# instrumentalness                                                          0.0
# liveness                                                                0.096
# valence                                                                 0.921
# tempo                                                                 127.113
# duration_ms                                                            154000
# time_signature                                                              4
# Name: 137, dtype: object

# %% [markdown]
# Drop selected rows, save into new variable

# %%
chart2018_without_placeholders = chart2018.drop(labels=137, axis=0)

# %% [markdown]
# View updated table

# %%
chart2018_without_placeholders
# Out:
#                 playlist_id                  playlist_name  position  \
# 0    34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018         1
# 1    34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018         2
# 2    34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018         3
# 3    34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018         4
# 4    34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018         5
# ..                      ...                            ...       ...
# 195  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       196
# 196  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       197
# 197  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       198
# 198  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       199
# 199  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       200
#
#                                             album_name  \
# 0                                           reputation
# 1                                             Scorpion
# 2                                 beerbongs & bentleys
# 3    The Greatest Showman (Original Motion Picture ...
# 4                                           ÷ (Deluxe)
# ..                                                 ...
# 195                                            Revenge
# 196            That's Christmas To Me (Deluxe Edition)
# 197                                              MANIA
# 198                            Live in No Shoes Nation
# 199                                 MEMORIES DON'T DIE
#
#                    album_id album_release_date      album_artists  \
# 0    6DEjYFkNZh67HP7R9PSZvv         2017-11-10       Taylor Swift
# 1    1ATL5GLyefJaxhQzSPVrLX         2018-06-29            [Drake]
# 2    6trNtQUgC8cgbWcqoMYkOR         2018-04-27      [Post Malone]
# 3    7ayBZIe1FHkNv0T5xFCX6F         2017-12-08  [Various Artists]
# 4    3T4tUhGYeRNVUGevb0wThu         2017-03-03       [Ed Sheeran]
# ..                      ...                ...                ...
# 195  3vpXJ54S3MXLyzysw8qq7c         2017-05-16     [XXXTENTACION]
# 196  082VlX7cBth0o8xqDGclNn         2015-10-30       [Pentatonix]
# 197  16xtTZvPH6PXcwSqYqJHHG         2018-01-19     [Fall Out Boy]
# 198  2njb3cHa1yhUMdu8PT2VhY         2017-10-27    [Kenny Chesney]
# 199  4RQIHpmmapmEpOFNi2GvAB         2018-03-02       [Tory Lanez]
#
#             album_artists_ids  \
# 0    [06HL4z0CvFAxyc27GXpf02]
# 1    [3TVXtAsR1Inumwj472S9r4]
# 2    [246dkjvS1zLTtiykXe5h60]
# 3    [0LyfQWJT6nXafLPZqxe9Of]
# 4    [6eUKZXaKkcviH0Ku9w2n3V]
# ..                        ...
# 195  [15UsOTVnJzReFVN1VCnxy4]
# 198    [[contemporary country, country, country road]]
# 199  [[canadian hip hop, canadian trap, melodic rap...
#
#     track_artists_popularity  track_explicit track_artists_followers  \
# 0                       [98]           False              [48097228]
# 1                       [98]            True              [60310746]
# 2                       [92]            True              [35612420]
# 3                        [0]           False               [1447145]
# 4                       [96]           False              [91177982]
# ..                       ...             ...                     ...
# 195                     [91]            True              [33973036]
# 196                     [81]           False               [3203902]
# 197                     [81]           False               [9259614]
# 198                     [74]           False               [3737536]
# 199                     [84]            True               [4166369]
#
#      danceability  energy  key  speechiness  loudness  mode  acousticness  \
# 0           0.766   0.709    9       0.1230    -6.471     0       0.20400
# 1           0.754   0.449    7       0.1090    -9.211     1       0.03320
# 2           0.585   0.520    5       0.0712    -6.136     0       0.12400
# 3           0.284   0.704    2       0.1860    -7.276     1       0.00583
# 4           0.825   0.652    1       0.0802    -3.183     0       0.58100
# ..            ...     ...  ...          ...       ...   ...           ...
# 195         0.763   0.726    1       0.2820    -6.405     1       0.25900
# 196         0.497   0.312   11       0.0269    -9.088     0       0.30200
# 197         0.579   0.872    8       0.0443    -5.294     1       0.00594
# 198         0.371   0.988    9       0.1210    -4.790     1       0.01080
# 199         0.639   0.547    7       0.0434    -6.237     0       0.11500
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0            0.000014    0.1260    0.506  128.070       211853               4
# 1            0.000083    0.5520    0.357   77.169       198973               4
# 2            0.000070    0.1310    0.129  159.801       218147               4
# 3            0.000115    0.0424    0.100  191.702       234707               4
# 4            0.000000    0.0931    0.931   95.977       233713               4
# ..                ...       ...      ...      ...          ...             ...
# 195          0.000000    0.0976    0.349  139.059       126346               4
# 196          0.000000    0.0968    0.177  105.036       203373               4
# 197          0.000000    0.1920    0.557  115.043       230400               4
# 198          0.000155    0.9590    0.263  168.035       268093               4
# 199          0.000000    0.3730    0.117  129.939       208173               4
#
# [199 rows x 33 columns]

# %% [markdown]
# View dropped row location range

# %%
chart2018_without_placeholders.iloc[135:140]
# Out:
#                 playlist_id                  playlist_name  position  \
# 135  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       136
# 136  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       137
# 138  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       139
# 139  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       140
# 140  34KSLHLGSNqeK6UfxKnLuM  Billboard 200 Top Albums 2018       141
#
#                                album_name                album_id  \
# 135                            Lil Boat 2  4nHOF3neSo6Y7OG5OAflkC
# 136                             Woodstock  4VzzEviJGYUtAeSsJlI9QB
# 138  If You're Reading This It's Too Late  0ptlfJfwGTy0Yvrk14JK1I
# 139                       KIDS SEE GHOSTS  6pwuKxMUkNg673KETsXPUV
# 140                            Issa Album  1GeQZeg77rUX8s0pEiz8jS
#
#     album_release_date                            album_artists  \
# 135         2018-03-09                             [Lil Yachty]
# 136         2017-06-16                      [Portugal. The Man]
# 138         2015-02-12                                  [Drake]
# 139         2018-06-08  [KIDS SEE GHOSTS, Kanye West, Kid Cudi]
# 140         2017-09-21                              [21 Savage]
#
#                                      album_artists_ids  \
# 135                           [6icQOAFXDZKsumw3YXyusw]
# 136                           [4kI8Ie27vjvonwaB2ePh8T]
# 138                           [3TVXtAsR1Inumwj472S9r4]
# 139  [2hPgGN4uhvXAxiXQBIXOmE, 5K4W6rqBFWDnAN6FQUkS6...
# 140                           [1URnnhqYAYcrqrcwql10ft]
#
#                                   album_artists_genres  \
# 135  [[atl hip hop, hip hop, melodic rap, rap, trap...
# 136  [[indie rock, modern alternative rock, modern ...
# 138  [[canadian hip hop, canadian pop, hip hop, rap...
# 139  [[hip hop, rap], [chicago rap, rap], [hip hop,...
# 140                         [[atl hip hop, rap, trap]]
#
#     album_artists_popularity      album_artists_followers     track_name  \
# 135                     [82]                    [7759637]             66
# 136                     [69]                    [1287224]  Feel It Still
# 138                     [98]                   [60310746]         Energy
# 139             [66, 94, 86]  [871101, 16173510, 5458632]         Reborn
# 140                     [89]                   [10663592]   Bank Account
#
#                    track_id  track_popularity               track_artists  \
# 135  6tarvNiKnEjYMj1VZhlDqR                65  [Lil Yachty, Trippie Redd]
# 136  6QgjcU0zLnzq5OrUoSZ3OK                79         [Portugal. The Man]
# 138  79XrkTOfV1AqySNjVlygpW                72                     [Drake]
# 139  4RVbK6cV0VqWdpCDcx3hiT                74           [KIDS SEE GHOSTS]
# 140  675NeQd7AKLNLzXFqZtF51                48                 [21 Savage]
#
#                                      track_artists_ids  \
# 135                           [6icQOAFXDZKsumw3YXyusw]
# 136                           [4kI8Ie27vjvonwaB2ePh8T]
# 138                           [3TVXtAsR1Inumwj472S9r4]
# 139  [2hPgGN4uhvXAxiXQBIXOmE, 5K4W6rqBFWDnAN6FQUkS6...
# 140                           [1URnnhqYAYcrqrcwql10ft]
#
#                                   track_artists_genres  \
# 135  [[atl hip hop, hip hop, melodic rap, rap, trap...
# 136  [[indie rock, modern alternative rock, modern ...
# 138  [[canadian hip hop, canadian pop, hip hop, rap...
# 139  [[hip hop, rap], [chicago rap, rap], [hip hop,...
# 140                         [[atl hip hop, rap, trap]]
#
#     track_artists_popularity  track_explicit      track_artists_followers  \
# 135                     [82]            True                    [7759637]
# 136                     [69]           False                    [1287224]
# 138                     [98]            True                   [60310746]
# 139             [66, 94, 86]            True  [871101, 16173510, 5458632]
# 140                     [89]           False                   [10663592]
#
#      danceability  energy  key  speechiness  loudness  mode  acousticness  \
# 135         0.667   0.723    5       0.2700    -4.310     0        0.0455
# 136         0.801   0.795    1       0.0504    -5.115     0        0.0417
# 138         0.747   0.571   11       0.4780    -7.916     1        0.3800
# 139         0.585   0.597    0       0.0370    -7.499     1        0.3390
# 140         0.881   0.336    8       0.3520    -8.734     0        0.0223
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 135          0.000193    0.2130    0.251  148.058       153475               4
# 136          0.000113    0.0717    0.754   79.028       163253               4
# 138          0.000000    0.5340    0.553  172.104       181933               4
# 139          0.040400    0.1950    0.227  100.051       324674               4
# 140          0.000024    0.0930    0.342   75.025       220307               4

# %% [markdown]
# #### Export dataset to csv

# %%
chart2018_without_placeholders.to_csv('../data/chart2018.csv', index=False)

# %% [markdown]
# ### Billboard 2017 Top Albums chart table

# %% [markdown]
# Spotiy Chart URL: https://open.spotify.com/playlist/1N9WQ0C6m7n1TVeLXdUoNb

# %% [markdown]
# #### Pull chart data from Spotify

# %%
chart2017 = get_playlist_tracks_more_than_100_songs('katiekellert', '1N9WQ0C6m7n1TVeLXdUoNb')
# Out:
# 100%|██████████| 200/200 [05:41<00:00,  1.71s/it]

# %% [markdown]
# #### View the dataset

# %%
chart2017
# Out:
#                 playlist_id                  playlist_name  position  \
# 0    1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017         1
# 1    1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017         2
# 2    1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017         3
# 3    1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017         4
# 4    1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017         5
# ..                      ...                            ...       ...
# 195  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       196
# 196  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       197
# 197  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       198
# 198  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       199
# 199  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       200
#
#                              album_name                album_id  \
# 0                                 DAMN.  4eLPsYPBmXABThSJ821sqY
# 1                             24K Magic  4PgleR09JVnm3zY1fW3XBA
# 2                               Starboy  2ODvWsOgouMbaA5xf0RkJe
# 3                            ÷ (Deluxe)  3T4tUhGYeRNVUGevb0wThu
# 4                             More Life  1lXY618HWkwYKJWBRYR4MK
# ..                                  ...                     ...
# 195  Sing It Now: Songs Of Faith & Hope  3zSyGvLk5FcLhC3BtbKr9z
# 196          BEYONCÉ [Platinum Edition]  2UJwKSBUz6rtW4QLK74kQu
# 197      Whatcha Gonna Do With A Cowboy  6He4j8heX7l96p8y2FMjbz
# 198                         The Breaker  2aQOzEjLzPkffXDwREXdAh
# 199                         Heart Break  4WZZDzGqjvw4bRwrp56U24
#
#     album_release_date      album_artists         album_artists_ids  \
# 0           2017-04-14     Kendrick Lamar  [2YZyLoL8N0Wb9xBt1NhZWg]
# 1           2016-11-17       [Bruno Mars]  [0du5cEVh5yTK9QJze8zA0C]
# 2           2016-11-25       [The Weeknd]  [1Xyo4u8uXC1ZmMpatF05PJ]
# 3           2017-03-03       [Ed Sheeran]  [6eUKZXaKkcviH0Ku9w2n3V]
# 4           2017-03-18            [Drake]  [3TVXtAsR1Inumwj472S9r4]
# ..                 ...                ...                       ...
# 195         2017-02-03    [Reba McEntire]  [02rd0anEWfMtF7iMku9uor]
# 196         2014-11-24          [Beyoncé]  [6vWDO969PvNqNYHIOW5v0m]
# 197         1992-01-01     [Chris LeDoux]  [4K3DSWzghkGUcQOEZG9gpo]
# 198         2017-02-24  [Little Big Town]  [3CygdxquGHurS7f9LjNLkv]
# 199         2017-06-09           [Lady A]  [32WkQRZEVKSzVAAYqukAEA]
#
#                                   album_artists_genres  \
# 0    [[conscious hip hop, hip hop, rap, west coast ...
# 1                                   [[dance pop, pop]]
# 2     [[canadian contemporary r&b, canadian pop, pop]]
# 3                                      [[pop, uk pop]]
# 4    [[canadian hip hop, canadian pop, hip hop, rap...
# ..                                                 ...
# 195  [[contemporary country, country, country dawn,...
# 196                            [[dance pop, pop, r&b]]
# 197  [[country, country road, country rock, wyoming...
# 198  [[contemporary country, country, country dawn,...
# 199  [[contemporary country, country, country dawn,...
#
#     album_artists_popularity album_artists_followers  \
# 0                       [90]              [19114324]
# 1                       [92]              [37300396]
# 2                      [100]              [40930648]
# 3                       [96]              [91177982]
# 4                       [98]              [60310746]
# ..                       ...                     ...
# 195                     [66]               [1548058]
# 196                     [86]              [30095227]
# 197                     [57]                [387244]
# 198                     [69]               [2325885]
# 199                     [73]               [3438950]
#
#                          track_name                track_id  track_popularity  \
# 0                           HUMBLE.  7KXjTSCq5nL1LoYtL7XAwS                84
# 1                That's What I Like  0KKkJNfGyhkQ5aFogxQAPU                84
# 2                           Starboy  7MXVkk9YMctZqd1Srtv4MB                86
# 3                      Shape of You  7qiZfU4dY1lWllzX7mPBI3                87
# 4                      Passionfruit  5mCPDVBb16L4XQwDdbRUpz                83
# ..                              ...                     ...               ...
# 195                     Back To God  3W29VxuZ2AZNkPPJwVmD3a                34
# 196                            7/11  02M6vucOvmRfMxTXDUwRXu                72
# 197  Whatcha Gonna Do With A Cowboy  6UBvhlms1M16oUYZkEfqpy                50
# 198                      Better Man  23TxRN09aR1RB0G0tFoT0b                68
# 199                     Heart Break  3YZ5TNGA10oTLaADq4zuNV                50
#
#                     track_artists         track_artists_ids  \
# 0                [Kendrick Lamar]  [2YZyLoL8N0Wb9xBt1NhZWg]
# 1                    [Bruno Mars]  [0du5cEVh5yTK9QJze8zA0C]
# 2         [The Weeknd, Daft Punk]  [1Xyo4u8uXC1ZmMpatF05PJ]
# 3                    [Ed Sheeran]  [6eUKZXaKkcviH0Ku9w2n3V]
# 4                         [Drake]  [3TVXtAsR1Inumwj472S9r4]
# ..                            ...                       ...
# 195               [Reba McEntire]  [02rd0anEWfMtF7iMku9uor]
# 196                     [Beyoncé]  [6vWDO969PvNqNYHIOW5v0m]
# 197  [Chris LeDoux, Garth Brooks]  [4K3DSWzghkGUcQOEZG9gpo]
# 198             [Little Big Town]  [3CygdxquGHurS7f9LjNLkv]
# 199                      [Lady A]  [32WkQRZEVKSzVAAYqukAEA]
#
#                                   track_artists_genres  \
# 0    [[conscious hip hop, hip hop, rap, west coast ...
# 1                                   [[dance pop, pop]]
# 2     [[canadian contemporary r&b, canadian pop, pop]]
# 3                                      [[pop, uk pop]]
# 4    [[canadian hip hop, canadian pop, hip hop, rap...
# ..                                                 ...
# 195  [[contemporary country, country, country dawn,...
# 196                            [[dance pop, pop, r&b]]
# 197  [[country, country road, country rock, wyoming...
# 198  [[contemporary country, country, country dawn,...
# 199  [[contemporary country, country, country dawn,...
#
#     track_artists_popularity  track_explicit track_artists_followers  \
# 0                       [90]            True              [19114324]
# 1                       [92]           False              [37300396]
# 2                      [100]            True              [40930648]
# 3                       [96]           False              [91177982]
# 4                       [98]            True              [60310746]
# ..                       ...             ...                     ...
# 195                     [66]           False               [1548058]
# 196                     [86]           False              [30095227]
# 197                     [57]           False                [387244]
# 198                     [69]           False               [2325885]
# 199                     [73]           False               [3438950]
#
#      danceability  energy  key  speechiness  loudness  mode  acousticness  \
# 0           0.908   0.621    1       0.1020    -6.638     0      0.000282
# 1           0.853   0.560    1       0.0406    -4.961     1      0.013000
# 2           0.679   0.587    7       0.2760    -7.015     1      0.141000
# 3           0.825   0.652    1       0.0802    -3.183     0      0.581000
# 4           0.809   0.463   11       0.0396   -11.377     1      0.256000
# ..            ...     ...  ...          ...       ...   ...           ...
# 195         0.501   0.674    6       0.0315    -5.666     1      0.039000
# 196         0.747   0.705    9       0.1260    -5.137     0      0.012800
# 197         0.735   0.709    2       0.0988    -7.632     1      0.349000
# 198         0.514   0.836    5       0.0381    -3.663     1      0.112000
# 199         0.549   0.883    7       0.0346    -5.525     1      0.042300
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0            0.000054    0.0958    0.421  150.011       177000               4
# 1            0.000000    0.0944    0.860  134.066       206693               4
# 2            0.000006    0.1370    0.486  186.003       230453               4
# 3            0.000000    0.0931    0.931   95.977       233713               4
# 4            0.085000    0.1090    0.364  111.980       298941               4
# ..                ...       ...      ...      ...          ...             ...
# 195          0.000003    0.0783    0.359  147.931       289840               4
# 196          0.000000    0.1260    0.560  136.024       213507               4
# 197          0.000000    0.0944    0.909  127.241       155000               4
# 198          0.000000    0.0878    0.501  143.888       263120               4
# 199          0.000013    0.3230    0.668   83.994       188293               4
#
# [200 rows x 33 columns]

# %% [markdown]
# #### Drop rows containing placeholders for albums not available on Spotify (Chart positions 125,147,159,185,192,198 )

# %% [markdown]
# View projected rows for drop

# %%
chart2017.iloc[[124,146,158,184,191,197]]
# Out:
#                 playlist_id                  playlist_name  position  \
# 124  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       125
# 146  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       147
# 158  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       159
# 184  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       185
# 191  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       192
# 197  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       198
#
#                                             album_name  \
# 124  Guardians Of The Galaxy - Hooked On A Feeling ...
# 146                     Whatcha Gonna Do With A Cowboy
# 158                              The RCA-List (Vol. 6)
# 184                     Whatcha Gonna Do With A Cowboy
# 191                              The RCA-List (Vol. 6)
# 197                     Whatcha Gonna Do With A Cowboy
#
#                    album_id album_release_date      album_artists  \
# 124  7wOszSJfnz3o8kz2cD7Z2O         2019-01-26       [Geek Music]
# 146  6He4j8heX7l96p8y2FMjbz         1992-01-01     [Chris LeDoux]
# 158  7p72D0X2mvTqwUpqSIVDal         2017-05-26  [Various Artists]
# 184  6He4j8heX7l96p8y2FMjbz         1992-01-01     [Chris LeDoux]
# 191  7p72D0X2mvTqwUpqSIVDal         2017-05-26  [Various Artists]
# 197  6He4j8heX7l96p8y2FMjbz         1992-01-01     [Chris LeDoux]
#
#             album_artists_ids  \
# 124  [4TkCMPznXOjlsYLfzIU1rw]
# 146  [4K3DSWzghkGUcQOEZG9gpo]
# 158  [0LyfQWJT6nXafLPZqxe9Of]
# 184  [4K3DSWzghkGUcQOEZG9gpo]
# 191  [0LyfQWJT6nXafLPZqxe9Of]
# 197  [4K3DSWzghkGUcQOEZG9gpo]
#
#                                   album_artists_genres  \
# 124                                               [[]]
# 146  [[country, country road, country rock, wyoming...
# 158                                               [[]]
# 184  [[country, country road, country rock, wyoming...
# 191                                               [[]]
# 197  [[country, country road, country rock, wyoming...
#
#     album_artists_popularity album_artists_followers  \
# 124                     [65]                 [75235]
# 146                     [57]                [387244]
# 158                      [0]               [1447145]
# 184                     [57]                [387244]
# 191                      [0]               [1447145]
# 197                     [57]                [387244]
#
#                                             track_name  \
# 124  Guardians Of The Galaxy - Hooked On A Feeling ...
# 146                     Whatcha Gonna Do With A Cowboy
# 158                                             Malibu
# 184                     Whatcha Gonna Do With A Cowboy
# 191                                             Malibu
# 197                     Whatcha Gonna Do With A Cowboy
#
#                    track_id  track_popularity                 track_artists  \
# 124  2ITtbGn8Tta9Q9uGhGsFVr                37                  [Geek Music]
# 146  6UBvhlms1M16oUYZkEfqpy                50  [Chris LeDoux, Garth Brooks]
# 158  2HH6nWc0OHIUC5NWkpluv0                 4                 [Miley Cyrus]
# 184  6UBvhlms1M16oUYZkEfqpy                50  [Chris LeDoux, Garth Brooks]
# 191  2HH6nWc0OHIUC5NWkpluv0                 4                 [Miley Cyrus]
# 197  6UBvhlms1M16oUYZkEfqpy                50  [Chris LeDoux, Garth Brooks]
#
#             track_artists_ids  \
# 124  [4TkCMPznXOjlsYLfzIU1rw]
# 146  [4K3DSWzghkGUcQOEZG9gpo]
# 158  [0LyfQWJT6nXafLPZqxe9Of]
# 184  [4K3DSWzghkGUcQOEZG9gpo]
# 191  [0LyfQWJT6nXafLPZqxe9Of]
# 197  [4K3DSWzghkGUcQOEZG9gpo]
#
#                                   track_artists_genres  \
# 124                                               [[]]
# 146  [[country, country road, country rock, wyoming...
# 158                                               [[]]
# 184  [[country, country road, country rock, wyoming...
# 191                                               [[]]
# 197  [[country, country road, country rock, wyoming...
#
#     track_artists_popularity  track_explicit track_artists_followers  \
# 124                     [65]           False                 [75235]
# 146                     [57]           False                [387244]
# 158                      [0]           False               [1447145]
# 184                     [57]           False                [387244]
# 191                      [0]           False               [1447145]
# 197                     [57]           False                [387244]
#
#      danceability  energy  key  speechiness  loudness  mode  acousticness  \
# 124         0.590   0.428    8       0.0838   -10.236     1        0.8520
# 146         0.735   0.709    2       0.0988    -7.632     1        0.3490
# 158         0.565   0.782    8       0.0506    -6.413     1        0.0577
# 184         0.735   0.709    2       0.0988    -7.632     1        0.3490
# 191         0.565   0.782    8       0.0506    -6.413     1        0.0577
# 197         0.735   0.709    2       0.0988    -7.632     1        0.3490
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 124          0.000000    0.1500    0.843  118.663       168666               4
# 146          0.000000    0.0944    0.909  127.241       155000               4
# 158          0.000042    0.0757    0.400  140.004       231906               4
# 184          0.000000    0.0944    0.909  127.241       155000               4
# 191          0.000042    0.0757    0.400  140.004       231906               4
# 197          0.000000    0.0944    0.909  127.241       155000               4

# %% [markdown]
# Drop selected rows, save into new variable

# %%
chart2017_without_placeholders = chart2017.drop(labels=[124,146,158,184,191,197], axis=0)

# %% [markdown]
# View updated table

# %%
chart2017_without_placeholders
# Out:
#                 playlist_id                  playlist_name  position  \
# 0    1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017         1
# 1    1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017         2
# 2    1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017         3
# 3    1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017         4
# 4    1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017         5
# ..                      ...                            ...       ...
# 194  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       195
# 195  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       196
# 196  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       197
# 198  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       199
# 199  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2
# 4    5mCPDVBb16L4XQwDdbRUpz                83                  [Drake]
# ..                      ...               ...                      ...
# 194  1VdZ0vKfR5jneCmWIUAMxK                77             [Ed Sheeran]
# 195  3W29VxuZ2AZNkPPJwVmD3a                34          [Reba McEntire]
# 196  02M6vucOvmRfMxTXDUwRXu                72                [Beyoncé]
# 198  23TxRN09aR1RB0G0tFoT0b                68        [Little Big Town]
# 199  3YZ5TNGA10oTLaADq4zuNV                50                 [Lady A]
#
#             track_artists_ids  \
# 0    [2YZyLoL8N0Wb9xBt1NhZWg]
# 1    [0du5cEVh5yTK9QJze8zA0C]
# 2    [1Xyo4u8uXC1ZmMpatF05PJ]
# 3    [6eUKZXaKkcviH0Ku9w2n3V]
# 4    [3TVXtAsR1Inumwj472S9r4]
# ..                        ...
# 194  [6eUKZXaKkcviH0Ku9w2n3V]
# 195  [02rd0anEWfMtF7iMku9uor]
# 196  [6vWDO969PvNqNYHIOW5v0m]
# 198  [3CygdxquGHurS7f9LjNLkv]
# 199  [32WkQRZEVKSzVAAYqukAEA]
#
#                                   track_artists_genres  \
# 0    [[conscious hip hop, hip hop, rap, west coast ...
# 1                                   [[dance pop, pop]]
# 2     [[canadian contemporary r&b, canadian pop, pop]]
# 3                                      [[pop, uk pop]]
# 4    [[canadian hip hop, canadian pop, hip hop, rap...
# ..                                                 ...
# 194                                    [[pop, uk pop]]
# 195  [[contemporary country, country, country dawn,...
# 196                            [[dance pop, pop, r&b]]
# 198  [[contemporary country, country, country dawn,...
# 199  [[contemporary country, country, country dawn,...
#
#     track_artists_popularity  track_explicit track_artists_followers  \
# 0                       [90]            True              [19114324]
# 1                       [92]           False              [37300396]
# 2                      [100]            True              [40930648]
# 3                       [96]           False              [91177982]
# 4                       [98]            True              [60310746]
# ..                       ...             ...                     ...
# 194                     [96]           False              [91177982]
# 195                     [66]           False               [1548058]
# 196                     [86]           False              [30095227]
# 198                     [69]           False               [2325885]
# 199                     [73]           False               [3438950]
#
#      danceability  energy  key  speechiness  loudness  mode  acousticness  \
# 0           0.908   0.621    1       0.1020    -6.638     0      0.000282
# 1           0.853   0.560    1       0.0406    -4.961     1      0.013000
# 2           0.679   0.587    7       0.2760    -7.015     1      0.141000
# 3           0.825   0.652    1       0.0802    -3.183     0      0.581000
# 4           0.809   0.463   11       0.0396   -11.377     1      0.256000
# ..            ...     ...  ...          ...       ...   ...           ...
# 194         0.642   0.289    9       0.0367    -9.918     1      0.669000
# 195         0.501   0.674    6       0.0315    -5.666     1      0.039000
# 196         0.747   0.705    9       0.1260    -5.137     0      0.012800
# 198         0.514   0.836    5       0.0381    -3.663     1      0.112000
# 199         0.549   0.883    7       0.0346    -5.525     1      0.042300
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0            0.000054    0.0958    0.421  150.011       177000               4
# 1            0.000000    0.0944    0.860  134.066       206693               4
# 2            0.000006    0.1370    0.486  186.003       230453               4
# 3            0.000000    0.0931    0.931   95.977       233713               4
# 4            0.085000    0.1090    0.364  111.980       298941               4
# ..                ...       ...      ...      ...          ...             ...
# 194          0.000000    0.1800    0.407   84.996       258373               4
# 195          0.000003    0.0783    0.359  147.931       289840               4
# 196          0.000000    0.1260    0.560  136.024       213507               4
# 198          0.000000    0.0878    0.501  143.888       263120               4
# 199          0.000013    0.3230    0.668   83.994       188293               4
#
# [194 rows x 33 columns]

# %% [markdown]
# View dropped row location range

# %%
chart2017_without_placeholders.iloc[123:125]
# Out:
#                 playlist_id                  playlist_name  position  \
# 123  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       124
# 125  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       126
#
#                         album_name                album_id album_release_date  \
# 123             Rather You Than Me  08XXyTmAv1vNghZS4p0ng2         2017-03-17
# 125  The Essential Michael Jackson  77dNyQA0z8dV33M4so4eRY         2005-07-19
#
#          album_artists         album_artists_ids  \
# 123        [Rick Ross]  [1sBkRIssrMs1AbVkOJbc7a]
# 125  [Michael Jackson]  [3fMbdgg4jU18AjLCKBhRSm]
#
#                                   album_artists_genres  \
# 123  [[dirty south rap, gangster rap, hip hop, pop ...
# 125                                 [[pop, r&b, soul]]
#
#     album_artists_popularity album_artists_followers  \
# 123                     [82]               [5495865]
# 125                     [85]              [21343094]
#
#                                    track_name                track_id  \
# 123  Trap Trap Trap (feat. Young Thug & Wale)  1KZ0Xo6Mmeprp1Sw5xCHYz
# 125                               Billie Jean  4WSfyC9pFp0nc8OD0rHyaD
#
#      track_popularity                  track_artists  \
# 123                48  [Rick Ross, Young Thug, Wale]
# 125                40              [Michael Jackson]
#
#             track_artists_ids  \
# 123  [1sBkRIssrMs1AbVkOJbc7a]
# 125  [3fMbdgg4jU18AjLCKBhRSm]
#
#                                   track_artists_genres  \
# 123  [[dirty south rap, gangster rap, hip hop, pop ...
# 125                                 [[pop, r&b, soul]]
#
#     track_artists_popularity  track_explicit track_artists_followers  \
# 123                     [82]            True               [5495865]
# 125                     [85]           False              [21343094]
#
#      danceability  energy  key  speechiness  loudness  mode  acousticness  \
# 123         0.729   0.838    8       0.3130    -4.476     0       0.00612
# 125         0.920   0.559   11       0.0427    -5.667     0       0.01910
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 123            0.0000    0.0721    0.349  136.869       275720               4
# 125            0.0424    0.0444    0.819  117.167       292960               4

# %% [markdown]
# #### Export dataset to csv

# %%
chart2017_without_placeholders.to_csv('../data/chart2017.csv', index=False)

# %% [markdown]
# ## Combine yearly charts into a master table

# %% [markdown]
# Append tables ignoring index values without sorting

# %%
master_chart_table = chart2021.append([chart2020, chart2019, chart2018_without_placeholders, chart2017_without_placeholders], ignore_index=True, sort=False)

# %% [markdown]
# View dataframe

# %%
master_chart_table
# Out:
#                 playlist_id                  playlist_name  position  \
# 0    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         1
# 1    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         2
# 2    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         3
# 3    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         4
# 4    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         5
# ..                      ...                            ...       ...
# 988  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       195
# 989  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       196
# 990  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       197
# 991  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       199
# 992  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       200
#
#                                album_name                album_id  \
# 0             Dangerous: The Double Album  1qW1C4kDOXnrly22daHbx
# 1                  92             [Olivia Rodrigo]  [1McMsnEElThX1knmY4oliG]
# 2                  85                  [Pop Smoke]  [0eDvMgVFoNV3TpwtrVCoTj]
# 3                  82               [Taylor Swift]  [06HL4z0CvFAxyc27GXpf02]
# 4                  88  [Drake, Future, Young Thug]  [3TVXtAsR1Inumwj472S9r4]
# ..                ...                          ...                       ...
# 988                77                 [Ed Sheeran]  [6eUKZXaKkcviH0Ku9w2n3V]
# 989                34              [Reba McEntire]  [02rd0anEWfMtF7iMku9uor]
# 990                72                    [Beyoncé]  [6vWDO969PvNqNYHIOW5v0m]
# 991                68            [Little Big Town]  [3CygdxquGHurS7f9LjNLkv]
# 992                50                     [Lady A]  [32WkQRZEVKSzVAAYqukAEA]
#
#                                   track_artists_genres  \
# 0                             [[contemporary country]]
# 1                                              [[pop]]
# 2                                   [[brooklyn drill]]
# 3                                              [[pop]]
# 4    [[canadian hip hop, canadian pop, hip hop, rap...
# ..                                                 ...
# 988                                    [[pop, uk pop]]
# 989  [[contemporary country, country, country dawn,...
# 990                            [[dance pop, pop, r&b]]
# 991  [[contemporary country, country, country dawn,...
# 992  [[contemporary country, country, country dawn,...
#
#     track_artists_popularity  track_explicit track_artists_followers  \
# 0                       [86]           False               [2789002]
# 1                       [91]            True              [12849364]
# 2                       [89]            True               [8935893]
# 3                       [98]           False              [48097228]
# 4                       [98]            True              [60310746]
# ..                       ...             ...                     ...
# 988                     [96]           False              [91177982]
# 989                     [66]           False               [1548058]
# 990                     [86]           False              [30095227]
# 991                     [69]           False               [2325885]
# 992                     [73]           False               [3438950]
#
#      danceability  energy  key  speechiness  loudness  mode  acousticness  \
# 0           0.621   0.868    6       0.0460    -5.478     1      0.617000
# 1           0.561   0.431   10       0.0578    -8.810     1      0.768000
# 2           0.709   0.548   10       0.3530    -8.493     1      0.650000
# 3           0.392   0.574    7       0.1700    -9.195     1      0.833000
# 4           0.803   0.597   11       0.1410    -6.035     0      0.000619
# ..            ...     ...  ...          ...       ...   ...           ...
# 988         0.642   0.289    9       0.0367    -9.918     1      0.669000
# 989         0.501   0.674    6       0.0315    -5.666     1      0.039000
# 990         0.747   0.705    9       0.1260    -5.137     0      0.012800
# 991         0.514   0.836    5       0.0381    -3.663     1      0.112000
# 992         0.549   0.883    7       0.0346    -5.525     1      0.042300
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0            0.000000    0.1310    0.594  126.010       216573               4
# 1            0.000014    0.1060    0.137  143.875       242013               4
# 2            0.000002    0.1330    0.543   83.995       160000               4
# 3            0.001790    0.1450    0.529   81.112       214707               4
# 4            0.000005    0.3230    0.331  136.008       257605               4
# ..                ...       ...      ...      ...          ...             ...
# 988          0.000000    0.1800    0.407   84.996       258373               4
# 989          0.000003    0.0783    0.359  147.931       289840               4
# 990          0.000000    0.1260    0.560  136.024       213507               4
# 991          0.000000    0.0878    0.501  143.888       263120               4
# 992          0.000013    0.3230    0.668   83.994       188293               4
#
# [993 rows x 33 columns]

# %% [markdown]
# Export master chart table to csv

# %%
master_chart_table.to_csv('../data/mastercharttable.csv', index=False)
