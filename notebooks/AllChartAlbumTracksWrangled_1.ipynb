# %%
import pandas as pd
pd.set_option("display.max_columns",None)

# %%
df = pd.read_csv("../data/allchartalbumtracks.csv")
df.head()
# Out:
#                track_name                track_id  track_popularity  \
# 0        Sand In My Boots  4qeMbs55QlONyrE9YBMA93                42
# 1           Wasted On You  4xv9BDq764NSKG3geku9X2                42
# 2      Somebody’s Problem  7cWMnSxmQfKFsIIoRWifbb                35
# 3  More Surprised Than Me  6Mn2GFiNNadK0G2ZXRK1fd                35
# 4                     865  3lb2f27695Iuyd82khwU9k                38
#
#        track_artists           track_artists_ids        track_artists_genres  \
# 0  ['Morgan Wallen']  ['4oUHIQIBe0LHzYfvXNW4QM']  [['contemporary country']]
# 1  ['Morgan Wallen']  ['4oUHIQIBe0LHzYfvXNW4QM']  [['contemporary country']]
# 2  ['Morgan Wallen']  ['4oUHIQIBe0LHzYfvXNW4QM']  [['contemporary country']]
# 3  ['Morgan Wallen']  ['4oUHIQIBe0LHzYfvXNW4QM']  [['contemporary country']]
# 4  ['Morgan Wallen']  ['4oUHIQIBe0LHzYfvXNW4QM']  [['contemporary country']]
#
#   track_artists_popularity  track_explicit track_artists_followers  \
# 0                     [86]           False               [2789002]
# 1                     [86]           False               [2789002]
# 2                     [86]           False               [2789002]
# 3                     [86]           False               [2789002]
# 4                     [86]           False               [2789002]
#
#                     album_name                album_id  danceability  energy  \
# 0  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.354   0.540
# 1  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.505   0.658
# 2  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.658   0.539
# 3  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.488   0.748
# 4  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.454   0.586
#
#    key  speechiness  loudness  mode  acousticness  instrumentalness  liveness  \
# 0    3       0.0323    -6.625     1         0.587           0.00000     0.112
# 1   11       0.0318    -5.240     0         0.371           0.00136     0.121
# 2    5       0.0289    -7.674     1         0.665           0.00000     0.123
# 3    6       0.0297    -6.049     1         0.244           0.00000     0.124
# 4    8       0.0253    -5.254     1         0.729           0.00000     0.101
#
#    valence    tempo  duration_ms  time_signature
# 0    0.416   69.970       202133               4
# 1    0.255  196.002       178520               3
# 2    0.622  136.959       161773               4
# 3    0.431   84.938       157440               4
# 4    0.366   87.891       190680               4

# %%
df["track_artists_genres"] = df["track_artists_genres"].apply(lambda l: l[1:-1])
df.head()
# Out:
#                track_name                track_id  track_popularity  \
# 0        Sand In My Boots  4qeMbs55QlONyrE9YBMA93                42
# 1           Wasted On You  4xv9BDq764NSKG3geku9X2                42
# 2      Somebody’s Problem  7cWMnSxmQfKFsIIoRWifbb                35
# 3  More Surprised Than Me  6Mn2GFiNNadK0G2ZXRK1fd                35
# 4                     865  3lb2f27695Iuyd82khwU9k                38
#
#        track_artists           track_artists_ids      track_artists_genres  \
# 0  ['Morgan Wallen']  ['4oUHIQIBe0LHzYfvXNW4QM']  ['contemporary country']
# 1  ['Morgan Wallen']  ['4oUHIQIBe0LHzYfvXNW4QM']  ['contemporary country']
# 2  ['Morgan Wallen']  ['4oUHIQIBe0LHzYfvXNW4QM']  ['contemporary country']
# 3  ['Morgan Wallen']  ['4oUHIQIBe0LHzYfvXNW4QM']  ['contemporary country']
# 4  ['Morgan Wallen']  ['4oUHIQIBe0LHzYfvXNW4QM']  ['contemporary country']
#
#   track_artists_popularity  track_explicit track_artists_followers  \
# 0                     [86]           False               [2789002]
# 1                     [86]           False               [2789002]
# 2                     [86]           False               [2789002]
# 3                     [86]           False               [2789002]
# 4                     [86]           False               [2789002]
#
#                     album_name                album_id  danceability  energy  \
# 0  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.354   0.540
# 1  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.505   0.658
# 2  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.658   0.539
# 3  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.488   0.748
# 4  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.454   0.586
#
#    key  speechiness  loudness  mode  acousticness  instrumentalness  liveness  \
# 0    3       0.0323    -6.625     1         0.587           0.00000     0.112
# 1   11       0.0318    -5.240     0         0.371           0.00136     0.121
# 2    5       0.0289    -7.674     1         0.665           0.00000     0.123
# 3    6       0.0297    -6.049     1         0.244           0.00000     0.124
# 4    8       0.0253    -5.254     1         0.729           0.00000     0.101
#
#    valence    tempo  duration_ms  time_signature
# 0    0.416   69.970       202133               4
# 1    0.255  196.002       178520               3
# 2    0.622  136.959       161773               4
# 3    0.431   84.938       157440               4
# 4    0.366   87.891       190680               4

# %%
df.to_csv("../data/allchartalbumtracks2.csv", index=False)
