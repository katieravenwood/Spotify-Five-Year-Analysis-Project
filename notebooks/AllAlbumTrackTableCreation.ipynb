# %% [markdown]
# # Spotify Five Year Analysis Project: <br />All Album Track Table Creation Notebook

# %% [markdown]
# ## Imports and Setup

# %% [markdown]
# ### Imports

# %%
import json
import time
from tqdm import tqdm
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import creds

# %% [markdown]
# ### Set display options

# %%
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ### Spotify Credentials
#
# #### Load credentials

# %% [markdown]
# Loads the creds.py file, containing the following two lines for variables client_id and secret, which is gitignored for sharing.
#
# client_id = 'Your Client ID Here'<br />
# secret = 'Your secret here'

# %%
# %run -i 'creds.py'

# %% [markdown]
# #### Set credentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### Album List Creation

# %% [markdown]
# #### Import master chart table

# %%
master_chart_table = pd.read_csv('../data/mastercharttable.csv')
master_chart_table
# Out:
#                 playlist_id                  playlist_name  position  \
# 0    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         1
# 1    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         2
# 2    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         3
# 3    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         4
# 4    3avCwQPH6DkhMTRsizon7N  Billboard 200 Top Albums 2021         5
# ..                      ...                            ...       ...
# 988  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       195
# 989  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       196
# 990  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       197
# 991  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       199
# 992  1N9WQ0C6m7n1TVeLXdUoNb  Billboard 200 Top Albums 2017       200
#
#                                album_name                album_id  \
# 0             Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz
# 1                                    SOUR  6s84u2TUpR3wdUv4NgKA2j
# 2    Shoot For The Stars Aim For The Moon  7e7t0MCrNDcJZsPwUKjmOc
# 3                                evermore  2Xoteh7uEpea4TohMxjtaq
# 4                     Certified Lover Boy  3SpBlxme9WbeQdI9kx7KAV
# ..                                    ...                     ...
# 988                                     +  0W5GGnapMz0VwemQvJDqa7
# 989    Sing It Now: Songs Of Faith & Hope  3zSyGvLk5FcLhC3BtbKr9z
# 990            BEYONCÉ [Platinum Edition]  2UJwKSBUz6rtW4QLK74kQu
# 991                           The Breaker  2aQOzEjLzPkffXDwREXdAh
# 992                           Heart Break  4WZZDzGqjvw4bRwrp56U24
#
#     album_release_date        album_artists           album_artists_ids  \
# 0           2021-01-08        Morgan Wallen  ['4oUHIQIBe0LHzYfvXNW4QM']
# 1           2021-05-21   ['Olivia Rodrigo']  ['1McMsnEElThX1knmY4oliG']
# 2           2020-07-03        ['Pop Smoke']  ['0eDvMgVFoNV3TpwtrVCoTj']
# 3           2020-12-11     ['Taylor Swift']  ['06HL4z0CvFAxyc27GXpf02']
# 4           2021-09-03            ['Drake']  ['3TVXtAsR1Inumwj472S9r4']
# ..                 ...                  ...                         ...
# 988         2011-09-09       ['Ed Sheeran']  ['6eUKZXaKkcviH0Ku9w2n3V']
# 989         2017-02-03    ['Reba McEntire']  ['02rd0anEWfMtF7iMku9uor']
# 990         2014-11-24          ['Beyoncé']  ['6vWDO969PvNqNYHIOW5v0m']
# 991         2017-02-24  ['Little Big Town']  ['3CygdxquGHurS7f9LjNLkv']
# 992         2017-06-09           ['Lady A']  ['32WkQRZEVKSzVAAYqukAEA']
#
#                                   album_artists_genres  \
# 0                           [['contemporary country']]
# 1                                            [['pop']]
# 2                                 [['brooklyn drill']]
# 3                                            [['pop']]
# 4    [['canadian hip hop', 'canadian pop', 'hip hop...
# ..                                                 ...
# 988                                [['pop', 'uk pop']]
# 989  [['contemporary country', 'country', 'country ...
# 990                      [['dance pop', 'pop', 'r&b']]
# 991  [['contemporary country', 'country', 'country ...
# 992  [['contemporary country', 'country', 'country ...
#
#     album_artists_popularity album_artists_followers  \
# 0                       [86]               [2789002]
# 1                       [91]              [12849364]
# 2                       [89]               [8935893]
# 3                       [98]              [48097228]
# 4                       [98]              [60310746]
# ..                       ...                     ...
# 988                     [96]              [91177982]
# 989                     [66]               [1548058]
# 990                     [86]              [30095227]
# 991                     [69]               [2325885]
# 992                     [73]               [3438950]
#
#                                 track_name                track_id  \
# 0                    More Than My Hometown  65mMCEOu5Ll1DBAfEUmerU
# 1                          drivers license  5wANPM4fQCJwkGd4rN57mH
# 2                  What You Know Bout Love  1tkg4EHVoqnhR6iFEXb60y
# 3                                   willow  0lx2cLdOt3piJbcaXIV74f
# 4    Way 2 Sexy (with Future & Young Thug)  0k1WUmIRnG3xU6fvvDVfRG
# ..                                     ...                     ...
# 988                             The A Team  1VdZ0vKfR5jneCmWIUAMxK
# 989                            Back To God  3W29VxuZ2AZNkPPJwVmD3a
# 990                                   7/11  02M6vucOvmRfMxTXDUwRXu
# 991                             Better Man  23TxRN09aR1RB0G0tFoT0b
# 992                            Heart Break  3YZ5TNGA10oTLaADq4zuNV
#
#      track_popularity                      track_artists  \
# 0                  34                  ['Morgan Wallen']
# 1                  92                 ['Olivia Rodrigo']
# 2                  85                      ['Pop Smoke']
# 3                  82                   ['Taylor Swift']
# 4                  88  ['Drake', 'Future', 'Young Thug']
# ..                ...                                ...
# 988                77                     ['Ed Sheeran']
# 989                34                  ['Reba McEntire']
# 990                72                        ['Beyoncé']
# 991                68                ['Little Big Town']
# 992                50                         ['Lady A']
#
#               track_artists_ids  \
# 0    ['4oUHIQIBe0LHzYfvXNW4QM']
# 1    ['1McMsnEElThX1knmY4oliG']
# 2    ['0eDvMgVFoNV3TpwtrVCoTj']
# 3    ['06HL4z0CvFAxyc27GXpf02']
# 4    ['3TVXtAsR1Inumwj472S9r4']
# ..                          ...
# 988  ['6eUKZXaKkcviH0Ku9w2n3V']
# 989  ['02rd0anEWfMtF7iMku9uor']
# 990  ['6vWDO969PvNqNYHIOW5v0m']
# 991  ['3CygdxquGHurS7f9LjNLkv']
# 992  ['32WkQRZEVKSzVAAYqukAEA']
#
#                                   track_artists_genres  \
# 0                           [['contemporary country']]
# 1                                            [['pop']]
# 2                                 [['brooklyn drill']]
# 3                                            [['pop']]
# 4    [['canadian hip hop', 'canadian pop', 'hip hop...
# ..                                                 ...
# 988                                [['pop', 'uk pop']]
# 989  [['contemporary country', 'country', 'country ...
# 990                      [['dance pop', 'pop', 'r&b']]
# 991  [['contemporary country', 'country', 'country ...
# 992  [['contemporary country', 'country', 'country ...
#
#     track_artists_popularity  track_explicit track_artists_followers  \
# 0                       [86]           False               [2789002]
# 1                       [91]            True              [12849364]
# 2                       [89]            True               [8935893]
# 3                       [98]           False              [48097228]
# 4                       [98]            True              [60310746]
# ..                       ...             ...                     ...
# 988                     [96]           False              [91177982]
# 989                     [66]           False               [1548058]
# 990                     [86]           False              [30095227]
# 991                     [69]           False               [2325885]
# 992                     [73]           False               [3438950]
#
#      danceability  energy  key  speechiness  loudness  mode  acousticness  \
# 0           0.621   0.868    6       0.0460    -5.478     1      0.617000
# 1           0.561   0.431   10       0.0578    -8.810     1      0.768000
# 2           0.709   0.548   10       0.3530    -8.493     1      0.650000
# 3           0.392   0.574    7       0.1700    -9.195     1      0.833000
# 4           0.803   0.597   11       0.1410    -6.035     0      0.000619
# ..            ...     ...  ...          ...       ...   ...           ...
# 988         0.642   0.289    9       0.0367    -9.918     1      0.669000
# 989         0.501   0.674    6       0.0315    -5.666     1      0.039000
# 990         0.747   0.705    9       0.1260    -5.137     0      0.012800
# 991         0.514   0.836    5       0.0381    -3.663     1      0.112000
# 992         0.549   0.883    7       0.0346    -5.525     1      0.042300
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0            0.000000    0.1310    0.594  126.010       216573               4
# 1            0.000014    0.1060    0.137  143.875       242013               4
# 2            0.000002    0.1330    0.543   83.995       160000               4
# 3            0.001790    0.1450    0.529   81.112       214707               4
# 4            0.000005    0.3230    0.331  136.008       257605               4
# ..                ...       ...      ...      ...          ...             ...
# 988          0.000000    0.1800    0.407   84.996       258373               4
# 989          0.000003    0.0783    0.359  147.931       289840               4
# 990          0.000000    0.1260    0.560  136.024       213507               4
# 991          0.000000    0.0878    0.501  143.888       263120               4
# 992          0.000013    0.3230    0.668   83.994       188293               4
#
# [993 rows x 33 columns]

# %% [markdown]
# #### Create album id table

# %%
album_id_table = master_chart_table[['album_name','album_id']].copy()
album_id_table
# Out:
#                                album_name                album_id
# 0             Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz
# 1                                    SOUR  6s84u2TUpR3wdUv4NgKA2j
# 2    Shoot For The Stars Aim For The Moon  7e7t0MCrNDcJZsPwUKjmOc
# 3                                evermore  2Xoteh7uEpea4TohMxjtaq
# 4                     Certified Lover Boy  3SpBlxme9WbeQdI9kx7KAV
# ..                                    ...                     ...
# 988                                     +  0W5GGnapMz0VwemQvJDqa7
# 989    Sing It Now: Songs Of Faith & Hope  3zSyGvLk5FcLhC3BtbKr9z
# 990            BEYONCÉ [Platinum Edition]  2UJwKSBUz6rtW4QLK74kQu
# 991                           The Breaker  2aQOzEjLzPkffXDwREXdAh
# 992                           Heart Break  4WZZDzGqjvw4bRwrp56U24
#
# [993 rows x 2 columns]

# %% [markdown]
# #### Remove duplicates

# %%
album_ids_no_dupes = album_id_table.drop_duplicates(subset=['album_id'], keep='first')
album_ids_no_dupes
# Out:
#                                album_name                album_id
# 0             Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz
# 1                                    SOUR  6s84u2TUpR3wdUv4NgKA2j
# 2    Shoot For The Stars Aim For The Moon  7e7t0MCrNDcJZsPwUKjmOc
# 3                                evermore  2Xoteh7uEpea4TohMxjtaq
# 4                     Certified Lover Boy  3SpBlxme9WbeQdI9kx7KAV
# ..                                    ...                     ...
# 988                                     +  0W5GGnapMz0VwemQvJDqa7
# 989    Sing It Now: Songs Of Faith & Hope  3zSyGvLk5FcLhC3BtbKr9z
# 990            BEYONCÉ [Platinum Edition]  2UJwKSBUz6rtW4QLK74kQu
# 991                           The Breaker  2aQOzEjLzPkffXDwREXdAh
# 992                           Heart Break  4WZZDzGqjvw4bRwrp56U24
#
# [560 rows x 2 columns]

# %% [markdown]
# #### Create list of albums ids

# %%
album_id_list = album_ids_no_dupes['album_id'].tolist()
album_id_list
# Out:
# ['1qW1C4kDOXnrly22daHbxz',
#  '6s84u2TUpR3wdUv4NgKA2j',
#  '7e7t0MCrNDcJZsPwUKjmOc',
#  '2Xoteh7uEpea4TohMxjtaq',
#  '3SpBlxme9WbeQdI9kx7KAV',
#  '6RuwGwQcAureaOraKJNFQG',
#  '0S9D5NIDp2YXhYwlvuJzqx',
#  '3BSzygCIET0gzTTIs7iB3y',
#  '7fJJK56U9fHixgO0HQkhtI',
#  '1ynyQdPQiXdYJNQEDL1S3d',
#  '6n9DKpOxwifT5hOXtgLZSL',
#  '0xS0iOtxQRoJvfcFcJA5Gv',
#  '4g1ZRSobMefqF6nelkgibi',
#  '03NCvBIGqzLPhLoi4pDb3L',
#  '5dGWwsZ9iB2Xc3UKR0gif2',
#  '7xV2TzoaVc0ycW7fwBwAml',
#  '2d9BCZeAAhiZWPpbX9aPCW',
#  '7lQouCmPggSsg1972D3TiE',
#  '1Gonl2Jwl4WeJM6qUomM8s',
#  '1nAQbHeOWTfQzbOoFrvndW',
#  '4FY0HCt6PEbOF1RqUbYVzq',
#  '6tkjU4Umpo79wwkgPMV3nZ',
#  '6a8nlV9V8kPUbTTCJNVSsh',
#  '3DvW6xTKba1sol3kkj4JoB',
#  '1kCHru7uhxBUdzkm4gzRQc',
#  '5ffogo3K3fYibGWa93IzUe',
#  '0S0KGZnfBGSIssfF54WSJh',
#  '4JAvwK4APPArjIsOdGoJXX',
#  '1lhNch5NkOONvFhRPh8qaj',
#  '0wTx7qk1I85v3WSKyXWTNc',
#  '5L5evi5tJPh8WaEFAQp7Tp',
#  '0sOeI7pbAmIc8aDFyvkBUW',
#  '4hDok0OAJd57SGIT8xuWJH',
#  '0BwWUstDMUbgq2NYONRqlu',
#  '5lJqux7orBlA1QzyiBGti1',
#  '1IR2nlwX6YVTXXeu2qzoWO',
#  '55WCJ7ddhO0SFk8DXaKWMx',
#  '6CvBb1XqN0igtQrWrbXD80',
#  '5CnpZV3q5BcESefcB3WJmz',
#  '6nYfHQnvkvOTNHnOhDT3sr',
#  '0JGOiO34nwfUdDrD612dOp',
#  '1GYVNOzwhx1nMcIJDogSNp',
#  '1uzIyRT1QxDx4fMIX0UiAE',
#  '1MmVkhiwTH0BkNOU3nw5d3',
#  '41GuZcammIkupMPKH2OJ6I',
#  '4otkd9As6YaxxEkIjXPiZ6',
#  '03GKkfyog7hnllilFS3jIV',
#  '3eFDUa0q5bS0bYMp9LGJLk',
#  '4PocDl8UW41nVHOUntALFu',
#  '6trNtQUgC8cgbWcqoMYkOR',
#  '5g2INX6dnMIJG0xKygXwF3',
#  '623PL2MBg50Br5dLXC9E9e',
#  '2GIrLP0PWskhZAJaHQtDux',
#  '51KZKzPd3OQT1r46a55VTt',
#  '6074OsmUN1PdFgy0zTP4Fn',
#  '2zTNj92GTDDMzWSXEWdLyu',
#  '19ZAQw6Iah26CVL8jxprAQ',
#  '5gQtvMHA7yqdzKXrHpe63C',
#  '2bn6QpvG94QJkQTETzjTCs',
#  '02sEJTj1sye1JaqxqpcSCp',
#  '5M8gr5RV2eR6UkztC69ogB',
#  '1ozpmkWcCHwsQ4QTnxOOdT',
#  '4Rk63Jz61wwbmQru0PdltI',
#  '6sUOosXuYt0oUeczJRbedZ',
#  '6KMkuqIwKkwUhUYRPL6dUc',
#  '5MH765pytbQasmDxXArTah',
#  '7ycBtnsMtyVbbwTfJwRjSP',
#  '3V2zK11kl50LP3hGsnb2WJ',
#  '6VFETcEfjilkAng073KLt9',
#  '4smRLX0wglNhMXGyahWuUf',
#  '0VyKwpqF4igJx843PFYAO3',
#  '5L1fa5sInW8EeKIXAGycMD',
#  '7xMjYDrgPLp1ReFGAOyS1O',
#  '2x7pNYipWSrkKUnjzP9GhN',
#  '19EwdZNJYi92XMSKEyhnO9',
#  '36oUYFrslZeAVScyb7IOCj',
#  '0W5GGnapMz0VwemQvJDqa7',
#  '3zSyGvLk5FcLhC3BtbKr9z',
#  '2UJwKSBUz6rtW4QLK74kQu',
#  '2aQOzEjLzPkffXDwREXdAh',
#  '4WZZDzGqjvw4bRwrp56U24']

# %%
print(len(album_id_list))
# Out:
# 560

# %% [markdown]
# #### Create list of all album tracks from album id list

# %%
albums_track_ids = []
#  Loop over album ids and get their track ids
for i in tqdm(range(len(album_id_list))):
    time.sleep(.5)
    album_items = sp.album_tracks(album_id_list[i])['items']
    for track in album_items:
        album_tracks = track['id']
        albums_track_ids.append(album_tracks)
# Out:
# 100%|██████████| 560/560 [05:48<00:00,  1.61it/s]

# %%
print(len(albums_track_ids))
# Out:
# 8996

# %% [markdown]
# ## Functions for data extraction

# %% [markdown]
# ### Supporting function definitions

# %% [markdown]
# #### Album artists names function

# %%
def get_all_album_artists_names(track_id):
    meta = sp.track(track_id)
    album_artist_list = []
    for item in (meta['album']['artists']):
        album_artist = item['name']
        album_artist_list.append(album_artist)
    return album_artist_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_names('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['Future', 'Juice WRLD']

# %% [markdown]
# #### Album artists ids function

# %%
def get_all_album_artists_ids(track_id):
    meta = sp.track(track_id)
    album_artist_id_list = []
    for item in (meta['album']['artists']):
        album_artist_id = item['id']
        album_artist_id_list.append(album_artist_id)
    return album_artist_id_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_ids('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['1RyvyyTE3xzB2ZywiAwp0i', '4MCBfE4596Uoi2O4DtmEMz']

# %% [markdown]
# #### Album artists genres function

# %%
def get_all_album_artists_genres(track_id):
    meta = sp.track(track_id)
    album_artist_genre_list = []
    for item in (meta['album']['artists']):
        album_artist_id = item['id']
        album_artist_genres = sp.artist(album_artist_id)['genres']
        album_artist_genre_list.append(album_artist_genres)
    return album_artist_genre_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_genres('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [['atl hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['chicago rap', 'melodic rap']]

# %% [markdown]
# #### Album artists popularity function

# %%
def get_all_album_artists_popularity(track_id):
    meta = sp.track(track_id)
    album_artist_popularity_list = []
    for item in (meta['album']['artists']):
        album_artist_id = item['id']
        album_artist_popularity = sp.artist(album_artist_id)['popularity']
        album_artist_popularity_list.append(album_artist_popularity)
    return album_artist_popularity_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_popularity('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [91, 96]

# %% [markdown]
# #### Album artists followers function

# %%
def get_all_album_artists_followers(track_id):
    meta = sp.track(track_id)
    album_artist_followers_list = []
    for item in (meta['album']['artists']):
        album_artist_id = item['id']
        album_artist_followers = sp.artist(album_artist_id)['followers']['total']
        album_artist_followers_list.append(album_artist_followers)
    return album_artist_followers_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_album_artists_followers('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [11044152, 21889473]

# %% [markdown]
# #### Track artists names function

# %%
def get_all_track_artists_names(track_id):
    meta = sp.track(track_id)
    track_artist_list = []
    for item in (meta['artists']):
        track_artist = item['name']
        track_artist_list.append(track_artist)
    return track_artist_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_names('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['Future', 'Juice WRLD', 'Young Thug']

# %% [markdown]
# #### Track artists ids function

# %%
def get_all_track_artists_ids(track_id):
    meta = sp.track(track_id)
    track_artist_id_list = []
    for item in (meta['artists']):
        track_artist = item['id']
        track_artist_id_list.append(track_artist)
    return track_artist_id_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_ids('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# ['1RyvyyTE3xzB2ZywiAwp0i', '4MCBfE4596Uoi2O4DtmEMz', '50co4Is1HCEo8bhOyUWKpn']

# %% [markdown]
# #### Track artists genres function

# %%
def get_all_track_artists_genres(track_id):
    meta = sp.track(track_id)
    track_artist_genre_list = []
    for item in (meta['artists']):
        track_artist_id = item['id']
        track_artist_genres = sp.artist(track_artist_id)['genres']
        track_artist_genre_list.append(track_artist_genres)
    return track_artist_genre_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_genres('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [['atl hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap'],
#  ['chicago rap', 'melodic rap'],
#  ['atl hip hop',
#   'atl trap',
#   'gangster rap',
#   'hip hop',
#   'melodic rap',
#   'rap',
#   'trap']]

# %% [markdown]
# #### Track artists popularity function

# %%
def get_all_track_artists_popularity(track_id):
    meta = sp.track(track_id)
    track_artist_popularity_list = []
    for item in (meta['artists']):
        track_artist_id = item['id']
        track_artist_popularity = sp.artist(track_artist_id)['popularity']
        track_artist_popularity_list.append(track_artist_popularity)
    return track_artist_popularity_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_popularity('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [91, 96, 90]

# %% [markdown]
# #### Track artists followers function

# %%
def get_all_track_artists_followers(track_id):
    meta = sp.track(track_id)
    track_artist_followers_list = []
    for item in (meta['artists']):
        track_artist_id = item['id']
        track_artist_followers = sp.artist(track_artist_id)['followers']['total']
        track_artist_followers_list.append(track_artist_followers)
    return track_artist_followers_list

# %% [markdown]
# Test with track id '3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a'

# %%
get_all_track_artists_followers('3fFBZvG777xoKyvcrBq7lc?si=f241a44d776b451a')
# Out:
# [11044152, 21889473, 6891556]

# %% [markdown]
# ### Album track data return function

# %%
def get_all_album_tracks_more_than_100_songs(album_track_id_list):
    track_name = []
    track_id = []
    track_popularity = []
    track_explicit = []
    track_artists = []
    track_artists_ids = []
    track_artists_genres = []
    track_artists_popularity = []
    track_artists_followers = []
    album_name = []
    album_id = []

    for i in tqdm(range(len(album_track_id_list))):
        track = sp.track(album_track_id_list[i])
        this_id = track['id']
        if i == 0:
            track_name = track['name']
            track_id = this_id
            track_popularity = track['popularity']
            track_explicit = track['explicit']
            track_artists = get_all_track_artists_names(this_id)
            track_artists_ids = get_all_album_artists_ids(this_id)
            track_artists_genres = get_all_album_artists_genres(this_id)
            track_artists_popularity = get_all_album_artists_popularity(this_id)
            track_artists_followers = get_all_album_artists_followers(this_id)
            album_name = track['album']['name']
            album_id = track['album']['id']
            features = sp.audio_features(this_id)
            features_df = pd.DataFrame(data=features, columns=features[0].keys())
            features_df['track_name'] = [track_name]
            features_df['track_id'] = [track_id]
            features_df['track_popularity'] = [track_popularity]
            features_df['track_explicit'] = [track_explicit]
            features_df['track_artists'] = [track_artists]
            features_df['track_artists_ids'] = [track_artists_ids]
            features_df['track_artists_genres'] = [track_artists_genres]
            features_df['track_artists_popularity'] = [track_artists_popularity]
            features_df['track_artists_followers'] = [track_artists_followers]           
            features_df['album_name'] = [album_name]
            features_df['album_id'] = [album_id]
            features_df = features_df[['track_name', 'track_id', 'track_popularity', 'track_artists', 
                                       'track_artists_ids', 'track_artists_genres', 'track_artists_popularity', 
                                       'track_explicit', 'track_artists_followers', 
                                       'album_name', 'album_id', 'danceability', 'energy', 
                                       'key', 'speechiness', 'loudness', 'mode', 'acousticness', 'instrumentalness',
                                       'liveness', 'valence', 'tempo',
                                       'duration_ms', 'time_signature']]
            continue
        else:
            try:
                track_name = track['name']
                track_id = this_id
                track_popularity = track['popularity']
                track_explicit = track['explicit']
                track_artists = get_all_track_artists_names(this_id)
                track_artists_ids = get_all_album_artists_ids(this_id)
                track_artists_genres = get_all_album_artists_genres(this_id)
                track_artists_popularity = get_all_album_artists_popularity(this_id)
                track_artists_followers = get_all_album_artists_followers(this_id)
                album_name = track['album']['name']
                album_id = track['album']['id']
                features = sp.audio_features(this_id)
                new_row = {'track_name': [track_name],
                    'track_id': [track_id],
                    'track_popularity': [track_popularity],
                    'track_artists': [track_artists],
                    'track_artists_ids': [track_artists_ids],
                    'track_artists_genres': [track_artists_genres],
                    'track_artists_popularity': [track_artists_popularity],
                    'track_explicit': [track_explicit],
                    'track_artists_followers': [track_artists_followers],
                    'album_name': [album_name],
                    'album_id': [album_id],
                    'danceability':[features[0]['danceability']],
                    'energy':[features[0]['energy']],
                    'key':[features[0]['key']],
                    'speechiness':[features[0]['speechiness']],
                    'loudness':[features[0]['loudness']],
                    'mode':[features[0]['mode']],
                    'acousticness':[features[0]['acousticness']],
                    'instrumentalness':[features[0]['instrumentalness']],
                    'liveness':[features[0]['liveness']],
                    'valence':[features[0]['valence']],
                    'tempo':[features[0]['tempo']],
                    'duration_ms':[features[0]['duration_ms']],
                    'time_signature':[features[0]['time_signature']]
                }

                dfs = [features_df, pd.DataFrame(new_row)]
                features_df = pd.concat(dfs, ignore_index = True)
            except:
                continue
                
    return features_df

# %% [markdown]
# Create test set from albums list

# %%
albums_track_ids_test = albums_track_ids[0:15]
albums_track_ids_test
# Out:
# ['4qeMbs55QlONyrE9YBMA93',
#  '4xv9BDq764NSKG3geku9X2',
#  '7cWMnSxmQfKFsIIoRWifbb',
#  '6Mn2GFiNNadK0G2ZXRK1fd',
#  '3lb2f27695Iuyd82khwU9k',
#  '6o6jHTdTaqQilpLLY1q8AG',
#  '5WP1LPI7kLIQqEVEZKhnoo',
#  '6Vfl4qLFPMY73whXRef8Mk',
#  '4kPLqNab6ZMGxbzsg423iX',
#  '7fgKAJlw9WNLoBORPAwBoB',
#  '2JsDkPZtdgs21JWfKIkIeH',
#  '7MVGhr6Gfg0Wx959PN2LxL',
#  '5jKqR3BfRMAUnE7gAIq1Fh',
#  '23V03OIpI0BpblCZredJGe',
#  '65mMCEOu5Ll1DBAfEUmerU']

# %% [markdown]
# Test with test set

# %%
testing_album_tracks = get_all_album_tracks_more_than_100_songs(albums_track_ids_test)
# Out:
# 100%|██████████| 15/15 [00:14<00:00,  1.04it/s]

# %% [markdown]
# View test dataframe

# %%
testing_album_tracks
# Out:
#                                         track_name                track_id  \
# 0                                 Sand In My Boots  4qeMbs55QlONyrE9YBMA93
# 1                                    Wasted On You  4xv9BDq764NSKG3geku9X2
# 2                               Somebody’s Problem  7cWMnSxmQfKFsIIoRWifbb
# 3                           More Surprised Than Me  6Mn2GFiNNadK0G2ZXRK1fd
# 4                                              865  3lb2f27695Iuyd82khwU9k
# 5                                          Warning  6o6jHTdTaqQilpLLY1q8AG
# 6                                        Neon Eyes  5WP1LPI7kLIQqEVEZKhnoo
# 7                       Outlaw (feat. Ben Burgess)  6Vfl4qLFPMY73whXRef8Mk
# 8                                 Whiskey’d My Way  4kPLqNab6ZMGxbzsg423iX
# 9                          Wonderin’ Bout The Wind  7fgKAJlw9WNLoBORPAwBoB
# 10                                  Your Bartender  2JsDkPZtdgs21JWfKIkIeH
# 11  Only Thing That’s Gone (feat. Chris Stapleton)  7MVGhr6Gfg0Wx959PN2LxL
# 12                                     Cover Me Up  5jKqR3BfRMAUnE7gAIq1Fh
# 13                                       7 Summers  23V03OIpI0BpblCZredJGe
# 14                           More Than My Hometown  65mMCEOu5Ll1DBAfEUmerU
#
#     track_popularity                     track_artists  \
# 0                 42                   [Morgan Wallen]
# 1                 42                   [Morgan Wallen]
# 2                 35                   [Morgan Wallen]
# 3                 35                   [Morgan Wallen]
# 4                 38                   [Morgan Wallen]
# 5                 37                   [Morgan Wallen]
# 6                 36                   [Morgan Wallen]
# 7                 34      [Morgan Wallen, Ben Burgess]
# 8                 36                   [Morgan Wallen]
# 9                 34                   [Morgan Wallen]
# 10                35                   [Morgan Wallen]
# 11                35  [Morgan Wallen, Chris Stapleton]
# 12                36                   [Morgan Wallen]
# 13                35                   [Morgan Wallen]
# 14                34                   [Morgan Wallen]
#
#            track_artists_ids      track_artists_genres  \
# 0   [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
# 1   [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
# 2   [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
# 3   [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
# 4   [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
# 5   [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
# 6   [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
# 7   [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
# 8   [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
# 9   [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
# 10  [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
# 11  [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
# 12  [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
# 13  [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
# 14  [4oUHIQIBe0LHzYfvXNW4QM]  [[contemporary country]]
#
#    track_artists_popularity  track_explicit track_artists_followers  \
# 0                      [86]           False               [2789002]
# 1                      [86]           False               [2789002]
# 2                      [86]           False               [2789002]
# 3                      [86]           False               [2789002]
# 4                      [86]           False               [2789002]
# 5                      [86]           False               [2789002]
# 6                      [86]           False               [2789002]
# 7                      [86]           False               [2789002]
# 8                      [86]           False               [2789002]
# 9                      [86]           False               [2789002]
# 10                     [86]           False               [2789002]
# 11                     [86]           False               [2789002]
# 12                     [86]           False               [2789002]
# 13                     [86]           False               [2789002]
# 14                     [86]           False               [2789002]
#
#                      album_name                album_id  danceability  energy  \
# 0   Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.354   0.540
# 1   Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.505   0.658
# 2   Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.658   0.539
# 3   Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.488   0.748
# 4   Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.454   0.586
# 5   Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.633   0.663
# 6   Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.592   0.847
# 7   Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.506   0.633
# 8   Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.449   0.518
# 9   Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.481   0.714
# 10  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.554   0.774
# 11  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.503   0.799
# 12  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.531   0.438
# 13  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.467   0.793
# 14  Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.621   0.868
#
#     key  speechiness  loudness  mode  acousticness  instrumentalness  \
# 0     3       0.0323    -6.625     1        0.5870          0.000000
# 1    11       0.0318    -5.240     0        0.3710          0.001360
# 2     5       0.0289    -7.674     1        0.6650          0.000000
# 3     6       0.0297    -6.049     1        0.2440          0.000000
# 4     8       0.0253    -5.254     1        0.7290          0.000000
# 5    10       0.0294    -5.049     1        0.4630          0.000000
# 6    11       0.0285    -5.232     0        0.0102          0.000040
# 7     7       0.0275    -5.755     1        0.5830          0.000000
# 8     2       0.0271    -6.370     1        0.5990          0.002490
# 9     6       0.0335    -5.624     1        0.2500          0.000000
# 10    4       0.0281    -5.236     1        0.2470          0.000067
# 11    2       0.0314    -4.593     1        0.1120          0.000036
# 12    2       0.0271    -8.099     1        0.2310          0.000008
# 13    0       0.0329    -5.125     1        0.4110          0.000059
# 14    6       0.0460    -5.478     1        0.6170          0.000000
#
#     liveness  valence    tempo  duration_ms  time_signature
# 0     0.1120    0.416   69.970       202133               4
# 1     0.1210    0.255  196.002       178520               3
# 2     0.1230    0.622  136.959       161773               4
# 3     0.1240    0.431   84.938       157440               4
# 4     0.1010    0.366   87.891       190680               4
# 5     0.1080    0.253  115.052       156747               4
# 6     0.1580    0.652  126.010       226147               4
# 7     0.1210    0.244   85.050       229747               4
# 8     0.0984    0.314  185.879       180787               3
# 9     0.1330    0.384   90.984       182227               4
# 10    0.1500    0.442  139.963       185093               4
# 11    0.2960    0.464  150.070       196707               4
# 12    0.1070    0.223  127.915       293707               3
# 13    0.1250    0.574  203.926       210507               4
# 14    0.1310    0.594  126.010       216573               4

# %% [markdown]
# ## Dataset creation

# %% [markdown]
# ### Pull track data from Spotify API

# %%
# Commenting out pull code so it doens't get run accidentally-- it takes a while!
all_album_tracks = get_all_album_tracks_more_than_100_songs(albums_track_ids)
# Out:
# 100%|██████████| 8996/8996 [2:39:18<00:00,  1.06s/it]

# %% [markdown]
# View dataset, check output row count

# %%
all_album_tracks
# Out:
#                     track_name                track_id  track_popularity  \
# 0             Sand In My Boots  4qeMbs55QlONyrE9YBMA93                42
# 1                Wasted On You  4xv9BDq764NSKG3geku9X2                42
# 2           Somebody’s Problem  7cWMnSxmQfKFsIIoRWifbb                35
# 3       More Surprised Than Me  6Mn2GFiNNadK0G2ZXRK1fd                35
# 4                          865  3lb2f27695Iuyd82khwU9k                38
# ...                        ...                     ...               ...
# 8987  Big Love In A Small Town  1VwuDXLQdyTWvieBIPWkNt                36
# 8988                 The Stars  2gFkkpMs7rakuCCi9UepP0                37
# 8989             Teenage Heart  7G2BnhS46nEiPucLNvE0G3                35
# 8990                      Home  32zF5eXrb8QrUu5qNdYmIO                35
# 8991                    Famous  5xeo7Mr6638HYaEontltHV                34
#
#         track_artists         track_artists_ids  \
# 0     [Morgan Wallen]  [4oUHIQIBe0LHzYfvXNW4QM]
# 1     [Morgan Wallen]  [4oUHIQIBe0LHzYfvXNW4QM]
# 2     [Morgan Wallen]  [4oUHIQIBe0LHzYfvXNW4QM]
# 3     [Morgan Wallen]  [4oUHIQIBe0LHzYfvXNW4QM]
# 4     [Morgan Wallen]  [4oUHIQIBe0LHzYfvXNW4QM]
# ...               ...                       ...
# 8987         [Lady A]  [32WkQRZEVKSzVAAYqukAEA]
# 8988         [Lady A]  [32WkQRZEVKSzVAAYqukAEA]
# 8989         [Lady A]  [32WkQRZEVKSzVAAYqukAEA]
# 8990         [Lady A]  [32WkQRZEVKSzVAAYqukAEA]
# 8991         [Lady A]  [32WkQRZEVKSzVAAYqukAEA]
#
#                                    track_artists_genres  \
# 0                              [[contemporary country]]
# 1                              [[contemporary country]]
# 2                              [[contemporary country]]
# 3                              [[contemporary country]]
# 4                              [[contemporary country]]
# ...                                                 ...
# 8987  [[contemporary country, country, country dawn,...
# 8988  [[contemporary country, country, country dawn,...
# 8989  [[contemporary country, country, country dawn,...
# 8990  [[contemporary country, country, country dawn,...
# 8991  [[contemporary country, country, country dawn,...
#
#      track_artists_popularity  track_explicit track_artists_followers  \
# 0                        [86]           False               [2789002]
# 1                        [86]           False               [2789002]
# 2                        [86]           False               [2789002]
# 3                        [86]           False               [2789002]
# 4                        [86]           False               [2789002]
# ...                       ...             ...                     ...
# 8987                     [73]           False               [3439689]
# 8988                     [73]           False               [3439689]
# 8989                     [73]           False               [3439689]
# 8990                     [73]           False               [3439689]
# 8991                     [73]           False               [3439689]
#
#                        album_name                album_id  danceability  \
# 0     Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.354
# 1     Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.505
# 2     Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.658
# 3     Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.488
# 4     Dangerous: The Double Album  1qW1C4kDOXnrly22daHbxz         0.454
# ...                           ...                     ...           ...
# 8987                  Heart Break  4WZZDzGqjvw4bRwrp56U24         0.524
# 8988                  Heart Break  4WZZDzGqjvw4bRwrp56U24         0.576
# 8989                  Heart Break  4WZZDzGqjvw4bRwrp56U24         0.572
# 8990                  Heart Break  4WZZDzGqjvw4bRwrp56U24         0.559
# 8991                  Heart Break  4WZZDzGqjvw4bRwrp56U24         0.557
#
#       energy  key  speechiness  loudness  mode  acousticness  \
# 0      0.540    3       0.0323    -6.625     1       0.58700
# 1      0.658   11       0.0318    -5.240     0       0.37100
# 2      0.539    5       0.0289    -7.674     1       0.66500
# 3      0.748    6       0.0297    -6.049     1       0.24400
# 4      0.586    8       0.0253    -5.254     1       0.72900
# ...      ...  ...          ...       ...   ...           ...
# 8987   0.523    1       0.0268    -5.150     1       0.64500
# 8988   0.766    1       0.0304    -4.594     1       0.26300
# 8989   0.840    2       0.0341    -6.227     1       0.00323
# 8990   0.692    7       0.0385    -7.797     1       0.48600
# 8991   0.621    0       0.0308    -6.355     0       0.59700
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000000    0.1120    0.416   69.970       202133
# 1             0.001360    0.1210    0.255  196.002       178520
# 2             0.000000    0.1230    0.622  136.959       161773
# 3             0.000000    0.1240    0.431   84.938       157440
# 4             0.000000    0.1010    0.366   87.891       190680
# ...                ...       ...      ...      ...          ...
# 8987          0.000000    0.1010    0.313  144.012       226013
# 8988          0.000004    0.1020    0.407  143.029       202347
# 8989          0.000013    0.5590    0.505  133.474       220227
# 8990          0.000004    0.1250    0.567   89.954       177200
# 8991          0.000098    0.0864    0.680   76.994       232613
#
#       time_signature
# 0                  4
# 1                  3
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 8987               4
# 8988               4
# 8989               4
# 8990               4
# 8991               4
#
# [8992 rows x 24 columns]

# %% [markdown]
# #### Find the missing values

# %% [markdown]
# Create list of output track ids

# %%
output_track_ids = all_album_tracks['track_id'].tolist()
output_track_ids
print(len(output_track_ids))
# Out:
# 8992

# %% [markdown]
# Compare input list and output list

# %%
missing_tracks = [item for item in albums_track_ids if item not in output_track_ids]
missing_tracks
# Out:
# ['2MIBAmYwiuGoKUlpq9B9sZ',
#  '0giiXonRhODYy4J1iy4Lb3',
#  '5VKJr18j5O5Bl4KeYrBH0K',
#  '4f6PUDRYJI51UrZy0jDAxD']

# %% [markdown]
# Missing tracks are missing audio feature values at the time of dataset creation and so will not be appended as they represent a non-significant portion of the data.

# %% [markdown]
# #### Export all chart album tracks table to csv

# %%
all_album_tracks.to_csv('../data/allchartalbumtracks.csv', index=False)
