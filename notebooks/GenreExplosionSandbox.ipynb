# %% [markdown]
# # Genre Explosion

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/allchartalbumtracks.csv')

# %%
df
# Out:
#       Unnamed: 0                  track_name                track_id  \
# 0              0            Sand In My Boots  4qeMbs55QlONyrE9YBMA93
# 1              1               Wasted On You  4xv9BDq764NSKG3geku9X2
# 2              2          Somebody’s Problem  7cWMnSxmQfKFsIIoRWifbb
# 3              3      More Surprised Than Me  6Mn2GFiNNadK0G2ZXRK1fd
# 4              4                         865  3lb2f27695Iuyd82khwU9k
# ...          ...                         ...                     ...
# 8991        8991                        Home  32zF5eXrb8QrUu5qNdYmIO
# 8992        8992                      Famous  5xeo7Mr6638HYaEontltHV
# 8993        8993                Coming Clean  3p5JBbqJpfHqPpSdkjZbfX
# 8994        8994                    Perfecto  0Xcy81PsJCOO6mhLZaQyQ4
# 8995        8995  One Jump Ahead (Reprise 2)  5VKJr18j5O5Bl4KeYrBH0K
#
#       track_popularity      track_artists           track_artists_ids  \
# ...

# %%
TestTracks = df[100:130]
TestTracksArtists = pd.DataFrame(TestTracks['track_artists'])

# %%
TestTracksArtistsExploded = TestTracksArtists.explode('track_artists')

# %%
TestTracksArtistsExploded
# Out:
#                        track_artists
# 100      ['The Kid LAROI', 'Corbin']
# 101                ['The Kid LAROI']
# 102  ['The Kid LAROI', 'Juice WRLD']
# 103                ['The Kid LAROI']
# 104                ['The Kid LAROI']
# 105                ['The Kid LAROI']
# 106                ['The Kid LAROI']
# 107                ['The Kid LAROI']
# 108                ['The Kid LAROI']
# 109                ['The Kid LAROI']
# 110                ['The Kid LAROI']
# 111                   ['Luke Combs']
# 112                   ['Luke Combs']
# 113                   ['Luke Combs']
# 114                   ['Luke Combs']
# 115                   ['Luke Combs']
# 116  ['Luke Combs', 'Brooks & Dunn']
# 117                   ['Luke Combs']
# 118                   ['Luke Combs']
# 119                   ['Luke Combs']
# 120                   ['Luke Combs']
# 121                   ['Luke Combs']
# 122                   ['Luke Combs']
# 123    ['Luke Combs', 'Eric Church']
# ...

# %%
def unnesting(df, explode):
    idx = df.index.repeat(df[explode[0]].str.len())
    df1 = pd.concat([pd.DataFrame({x: np.concatenate(df[x].values)}) for x in explode], axis=1)
    df1.index = idx

    return df1.join(df.drop(explode, 1), how='left')

# %%
TestGenresExploded = unnesting(TestTracks,['track_artists'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-c38d43d9ac0c> in <module>
# ----> 1 TestGenresExploded = unnesting(TestTracks,['track_artists'])
#
# <ipython-input-92-ceb83269401c> in unnesting(df, explode)
#       1 def unnesting(df, explode):
#       2     idx = df.index.repeat(df[explode[0]].str.len())
# ----> 3     df1 = pd.concat([pd.DataFrame({x: np.concatenate(df[x].values)}) for x in explode], axis=1)
#       4     df1.index = idx
#       5
#
# <ipython-input-92-ceb83269401c> in <listcomp>(.0)
#       1 def unnesting(df, explode):
#       2     idx = df.index.repeat(df[explode[0]].str.len())
# ----> 3     df1 = pd.concat([pd.DataFrame({x: np.concatenate(df[x].values)}) for x in explode], axis=1)
#       4     df1.index = idx
#       5
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ...

# %%
TestGenresExploded
# Out:
#      Unnamed: 0                      track_name                track_id  \
# 100         100         NOT FAIR (feat. Corbin)  2HrMDMckfCyM4OcZxXuiRn
# 101         101                 BATHROOM (skit)  5nJAbkLqdC83h1Hemmdtsf
# 102         102           GO (feat. Juice WRLD)  2rPHUAeUPbNgTmK18FPTiZ
# 103         103                     TELL ME WHY  3jlxX3VXPiY3lvBBbppQD3
# 104         104                      SAME THING  0jtsTHyFUH1p5sBC1J77NV
# 105         105                  NEW GUY (skit)  5lJB7lecnEcVZnS8NiQ3ci
# 106         106                         ERASE U  3IyqvaNhDG8xBXHDkaJKMV
# 107         107                         RUNNING  1onmFJfN0YdkQ5Rrb3tLXN
# 108         108            WISH YOU WELL (skit)  6iHYvsvoNv8SIW7QS6IFL2
# 109         109         NEED YOU MOST (So Sick)  2DsdZx34mT4jVtnPk1eoFM
# 110         110                         SELFISH  57tln4G33fhp8mrFbeM3IJ
# 111         111       Beer Never Broke My Heart  7aEtlGHoiPAfRB084NiDmx
# ...
